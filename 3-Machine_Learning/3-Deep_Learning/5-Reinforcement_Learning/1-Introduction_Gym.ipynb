# %% [markdown]
# ## Intro Aprendizaje por Refuerzo

# %% [markdown]
# Considera el escenario de enseñarle nuevos trucos a un perro. El perro no entiende nuestro lenguaje, así que no podemos decirle qué hacer. En cambio, seguimos una estrategia diferente. Emulamos una situación (o una señal), y el perro intenta responder de muchas maneras diferentes. Si la respuesta del perro es la deseada, lo recompensamos con golosinas. Ahora, adivina qué, la próxima vez que el perro se enfrenta a la misma situación, ejecuta una acción similar con aún más entusiasmo esperando más comida. Esto es como aprender "qué hacer" a partir de experiencias positivas. De manera similar, los perros tienden a aprender qué no hacer cuando se enfrentan a experiencias negativas.

# %% [markdown]
# ## Entendiendo cómo funciona el Aprendizaje por Refuerzo
#
# En un sentido más amplio, así es como funciona el Aprendizaje por Refuerzo:
#
# * Tu perro es un "agente" que está expuesto al entorno. El entorno podría ser tu casa, contigo.
# * Las situaciones que encuentran son análogas a un estado. Un ejemplo de un estado podría ser tu perro de pie y tú usando una palabra específica con cierto tono en tu sala de estar.
# * Nuestros agentes reaccionan realizando una acción para pasar de un "estado" a otro "estado"; por ejemplo, tu perro pasa de estar de pie a sentarse.
# * Después de la transición, pueden recibir una recompensa o una penalización a cambio. ¡Les das una golosina! O un "No" como penalización.
# * La política es la estrategia de elegir una acción dada un estado en espera de mejores resultados.

# %% [markdown]
# El Aprendizaje por Refuerzo se encuentra entre el espectro del Aprendizaje Supervisado y el No Supervisado, y hay algunas cosas importantes que tener en cuenta:
#
# #### No siempre es beneficioso ser codicioso
#
# **Ser codicioso no siempre funciona:**
#
# * Hay cosas que son fáciles de hacer para obtener una gratificación instantánea, y hay cosas que proporcionan recompensas a largo plazo. El objetivo no es ser codicioso buscando las recompensas inmediatas, sino optimizar las recompensas máximas durante todo el entrenamiento.
#
# #### La secuencia importa en el Aprendizaje por Refuerzo
#
# **La secuencia importa en el Aprendizaje por Refuerzo:**
#
# * La recompensa del agente no solo depende del estado actual, sino de toda la historia de estados. A diferencia del aprendizaje supervisado y no supervisado, el tiempo es importante aquí.

# %% [markdown]
# ## El proceso

# %% [markdown]
# <img src="./img/Reinforcement-Learning-Animation.gif" alt="drawing" width="650"/>

# %% [markdown]
# En cierto sentido, el Aprendizaje por Refuerzo es la ciencia de tomar decisiones óptimas utilizando experiencias. Desglosándolo, el proceso de Aprendizaje por Refuerzo involucra estos pasos simples:
#
# 1. Observación del entorno.
# 2. Decidir cómo actuar utilizando alguna estrategia.
# 3. Actuar en consecuencia.
# 4. Recibir una recompensa o penalización.
# 5. Aprender de las experiencias y refinar nuestra estrategia.
# 6. Iterar hasta encontrar una estrategia óptima.
#
# Ahora vamos a entender el Aprendizaje por Refuerzo desarrollando un agente para aprender a jugar un juego automáticamente por sí mismo.

# %% [markdown]
# ## Comenzando con Gym
#
# Gym es un conjunto de herramientas para desarrollar y comparar algoritmos de aprendizaje por refuerzo. No hace suposiciones sobre la estructura de tu agente y es compatible con cualquier biblioteca de cálculo numérico, como TensorFlow o Theano.
#
# La biblioteca Gym es una colección de problemas de prueba, o entornos, que puedes usar para desarrollar tus algoritmos de aprendizaje por refuerzo. Estos entornos tienen una interfaz compartida, lo que te permite escribir algoritmos generales.

# %%
# %pip install gymnasium[classic_control]
# %pip install pygame
# Out:
# Collecting gymnasium[classic_control]
#   Downloading gymnasium-1.3.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\tifaw\appdata\local\programs\python\python311\lib\site-packages (from gymnasium[classic_control]) (2.3.5)
# Collecting cloudpickle>=1.2.0 (from gymnasium[classic_control])
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\tifaw\appdata\local\programs\python\python311\lib\site-packages (from gymnasium[classic_control]) (4.15.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium[classic_control])
#   Downloading farama_notifications-0.0.6-py3-none-any.whl.metadata (729 bytes)
# Collecting pygame-ce>=2.1.3 (from gymnasium[classic_control])
#   Downloading pygame_ce-2.5.7-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading farama_notifications-0.0.6-py3-none-any.whl (2.9 kB)
# Downloading pygame_ce-2.5.7-cp311-cp311-win_amd64.whl (10.4 MB)
#    ---------------------------------------- 0.0/10.4 MB ? eta -:--:--
#     --------------------------------------- 0.2/10.4 MB 3.5 MB/s eta 0:00:03
#    - -------------------------------------- 0.4/10.4 MB 3.8 MB/s eta 0:00:03
#    -- ------------------------------------- 0.6/10.4 MB 3.9 MB/s eta 0:00:03
#    -- ------------------------------------- 0.8/10.4 MB 4.1 MB/s eta 0:00:03
#    --- ------------------------------------ 0.9/10.4 MB 4.0 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.1/10.4 MB 4.0 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.3/10.4 MB 3.9 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.5/10.4 MB 4.0 MB/s eta 0:00:03
#    ------ --------------------------------- 1.7/10.4 MB 4.1 MB/s eta 0:00:03
#    ------- -------------------------------- 2.0/10.4 MB 4.1 MB/s eta 0:00:03
#    -------- ------------------------------- 2.1/10.4 MB 4.1 MB/s eta 0:00:03
#    -------- ------------------------------- 2.2/10.4 MB 3.9 MB/s eta 0:00:03
#    -------- ------------------------------- 2.3/10.4 MB 3.9 MB/s eta 0:00:03
#    --------- ------------------------------ 2.5/10.4 MB 3.9 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.8/10.4 MB 3.9 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.0/10.4 MB 4.0 MB/s eta 0:00:02
#    ------------ --------------------------- 3.3/10.4 MB 4.2 MB/s eta 0:00:02
#    ------------- -------------------------- 3.5/10.4 MB 4.1 MB/s eta 0:00:02
#    -------------- ------------------------- 3.7/10.4 MB 4.2 MB/s eta 0:00:02
#    -------------- ------------------------- 3.9/10.4 MB 4.2 MB/s eta 0:00:02
#    --------------- ------------------------ 4.1/10.4 MB 4.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.2/10.4 MB 4.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.6/10.4 MB 4.3 MB/s eta 0:00:02
#    ------------------ --------------------- 4.9/10.4 MB 4.4 MB/s eta 0:00:02
#    ------------------- -------------------- 5.2/10.4 MB 4.5 MB/s eta 0:00:02
#    --------------------- ------------------ 5.6/10.4 MB 4.6 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.8/10.4 MB 4.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.2/10.4 MB 4.8 MB/s eta 0:00:01
#    ------------------------- -------------- 6.6/10.4 MB 4.9 MB/s eta 0:00:01
#    -------------------------- ------------- 6.9/10.4 MB 5.0 MB/s eta 0:00:01
#    --------------------------- ------------ 7.2/10.4 MB 5.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.4/10.4 MB 5.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.6/10.4 MB 5.0 MB/s eta 0:00:01
#    ------------------------------ --------- 7.9/10.4 MB 5.0 MB/s eta 0:00:01
#    ------------------------------- -------- 8.2/10.4 MB 5.0 MB/s eta 0:00:01
#    -------------------------------- ------- 8.6/10.4 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.9/10.4 MB 5.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.2/10.4 MB 5.2 MB/s eta 0:00:01
#    ------------------------------------ --- 9.6/10.4 MB 5.3 MB/s eta 0:00:01
#    -------------------------------------- - 10.0/10.4 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  10.4/10.4 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 10.4/10.4 MB 5.5 MB/s eta 0:00:00
# Downloading gymnasium-1.3.0-py3-none-any.whl (953 kB)
#    ---------------------------------------- 0.0/953.9 kB ? eta -:--:--
#    ---------- ----------------------------- 256.0/953.9 kB 5.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 686.1/953.9 kB 7.2 MB/s eta 0:00:01
#    ---------------------------------------- 953.9/953.9 kB 7.5 MB/s eta 0:00:00
# Installing collected packages: farama-notifications, pygame-ce, cloudpickle, gymnasium
# Successfully installed cloudpickle-3.1.2 farama-notifications-0.0.6 gymnasium-1.3.0 pygame-ce-2.5.7
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting pygame
#   Downloading pygame-2.6.1-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Downloading pygame-2.6.1-cp311-cp311-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/10.6 MB 975.2 kB/s eta 0:00:11
#    - -------------------------------------- 0.4/10.6 MB 3.3 MB/s eta 0:00:04
#    -- ------------------------------------- 0.6/10.6 MB 4.1 MB/s eta 0:00:03
#    --- ------------------------------------ 1.0/10.6 MB 5.1 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.2/10.6 MB 4.7 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.5/10.6 MB 5.4 MB/s eta 0:00:02
#    ------- -------------------------------- 1.9/10.6 MB 5.6 MB/s eta 0:00:02
#    -------- ------------------------------- 2.3/10.6 MB 6.0 MB/s eta 0:00:02
#    --------- ------------------------------ 2.6/10.6 MB 6.1 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.0/10.6 MB 6.4 MB/s eta 0:00:02
#    ------------ --------------------------- 3.4/10.6 MB 6.5 MB/s eta 0:00:02
#    ------------- -------------------------- 3.7/10.6 MB 6.6 MB/s eta 0:00:02
#    --------------- ------------------------ 4.2/10.6 MB 6.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.4/10.6 MB 6.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.7/10.6 MB 6.6 MB/s eta 0:00:01
#    ------------------- -------------------- 5.2/10.6 MB 6.9 MB/s eta 0:00:01
#    -------------------- ------------------- 5.5/10.6 MB 6.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.9/10.6 MB 7.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.4/10.6 MB 7.1 MB/s eta 0:00:01
#    ------------------------- -------------- 6.7/10.6 MB 7.3 MB/s eta 0:00:01
#    -------------------------- ------------- 7.0/10.6 MB 7.2 MB/s eta 0:00:01
#    --------------------------- ------------ 7.4/10.6 MB 7.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.7/10.6 MB 7.2 MB/s eta 0:00:01
#    ------------------------------ --------- 8.1/10.6 MB 7.2 MB/s eta 0:00:01
#    ------------------------------- -------- 8.5/10.6 MB 7.2 MB/s eta 0:00:01
#    --------------------------------- ------ 8.9/10.6 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.2/10.6 MB 7.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.4/10.6 MB 7.2 MB/s eta 0:00:01
#    ------------------------------------ --- 9.6/10.6 MB 7.1 MB/s eta 0:00:01
#    ------------------------------------ --- 9.8/10.6 MB 7.1 MB/s eta 0:00:01
#    -------------------------------------- - 10.2/10.6 MB 7.1 MB/s eta 0:00:01
#    -------------------------------------- - 10.3/10.6 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 7.3 MB/s eta 0:00:00
# Installing collected packages: pygame
# Successfully installed pygame-2.6.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install numpy==1.23.5
# Out:
# Collecting numpy==1.23.5
#   Downloading numpy-1.23.5-cp311-cp311-win_amd64.whl.metadata (2.3 kB)
# Downloading numpy-1.23.5-cp311-cp311-win_amd64.whl (14.6 MB)
#    ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.6 MB 330.3 kB/s eta 0:00:45
#    ---------------------------------------- 0.1/14.6 MB 656.4 kB/s eta 0:00:23
#    ---------------------------------------- 0.2/14.6 MB 1.5 MB/s eta 0:00:10
#    - -------------------------------------- 0.5/14.6 MB 2.8 MB/s eta 0:00:06
#    -- ------------------------------------- 0.8/14.6 MB 3.6 MB/s eta 0:00:04
#    --- ------------------------------------ 1.1/14.6 MB 4.3 MB/s eta 0:00:04
#    --- ------------------------------------ 1.4/14.6 MB 4.5 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.8/14.6 MB 4.9 MB/s eta 0:00:03
#    ----- ---------------------------------- 2.1/14.6 MB 5.1 MB/s eta 0:00:03
#    ------ --------------------------------- 2.4/14.6 MB 5.4 MB/s eta 0:00:03
#    ------- -------------------------------- 2.8/14.6 MB 5.5 MB/s eta 0:00:03
#    -------- ------------------------------- 3.1/14.6 MB 5.6 MB/s eta 0:00:03
#    --------- ------------------------------ 3.4/14.6 MB 5.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.8/14.6 MB 5.9 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.3/14.6 MB 6.2 MB/s eta 0:00:02
#    ------------ --------------------------- 4.6/14.6 MB 6.3 MB/s eta 0:00:02
#    ------------- -------------------------- 5.1/14.6 MB 6.6 MB/s eta 0:00:02
#    -------------- ------------------------- 5.3/14.6 MB 6.5 MB/s eta 0:00:02
#    --------------- ------------------------ 5.6/14.6 MB 6.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.9/14.6 MB 6.5 MB/s eta 0:00:02
#    ----------------- ---------------------- 6.3/14.6 MB 6.6 MB/s eta 0:00:02
#    ------------------ --------------------- 6.7/14.6 MB 6.7 MB/s eta 0:00:02
#    ------------------- -------------------- 7.1/14.6 MB 6.8 MB/s eta 0:00:02
#    -------------------- ------------------- 7.5/14.6 MB 6.8 MB/s eta 0:00:02
#    --------------------- ------------------ 7.7/14.6 MB 6.8 MB/s eta 0:00:02
#    --------------------- ------------------ 8.0/14.6 MB 6.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 8.5/14.6 MB 6.8 MB/s eta 0:00:01
#    ------------------------ --------------- 8.8/14.6 MB 6.9 MB/s eta 0:00:01
#    ------------------------- -------------- 9.2/14.6 MB 6.9 MB/s eta 0:00:01
#    ------------------------- -------------- 9.4/14.6 MB 6.9 MB/s eta 0:00:01
#    ------------------------- -------------- 9.4/14.6 MB 6.9 MB/s eta 0:00:01
#    -------------------------- ------------- 9.7/14.6 MB 6.6 MB/s eta 0:00:01
#    --------------------------- ------------ 10.1/14.6 MB 6.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 10.5/14.6 MB 7.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 10.9/14.6 MB 7.3 MB/s eta 0:00:01
#    ------------------------------ --------- 11.2/14.6 MB 7.2 MB/s eta 0:00:01
#    ------------------------------- -------- 11.5/14.6 MB 7.3 MB/s eta 0:00:01
#    -------------------------------- ------- 11.9/14.6 MB 7.3 MB/s eta 0:00:01
#    --------------------------------- ------ 12.2/14.6 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 12.5/14.6 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 12.8/14.6 MB 7.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 12.9/14.6 MB 7.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.2/14.6 MB 7.0 MB/s eta 0:00:01
#    ------------------------------------ --- 13.3/14.6 MB 6.9 MB/s eta 0:00:01
#    ------------------------------------- -- 13.6/14.6 MB 6.8 MB/s eta 0:00:01
#    ------------------------------------- -- 13.9/14.6 MB 6.9 MB/s eta 0:00:01
#    -------------------------------------- - 14.2/14.6 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------  14.4/14.6 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------  14.6/14.6 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 14.6/14.6 MB 6.5 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.5
#     Uninstalling numpy-2.3.5:
#       Successfully uninstalled numpy-2.3.5
# Successfully installed numpy-1.23.5
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# contourpy 1.3.3 requires numpy>=1.25, but you have numpy 1.23.5 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.23.5 which is incompatible.
# pywavelets 1.9.0 requires numpy<3,>=1.25, but you have numpy 1.23.5 which is incompatible.
# scikit-image 0.26.0 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.
# scikit-learn 1.8.0 requires numpy>=1.24.1, but you have numpy 1.23.5 which is incompatible.
# scipy 1.16.3 requires numpy<2.6,>=1.25.2, but you have numpy 1.23.5 which is incompatible.
# tensorflow 2.21.0 requires numpy>=1.26.0, but you have numpy 1.23.5 which is incompatible.
#
# [notice] A new release of pip is available: 24.0 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Entornos
#
# Aquí tienes un ejemplo mínimo para comenzar a ejecutar algo. Esto ejecutará una instancia del entorno CartPole-v0 durante 1000 pasos de tiempo, representando el entorno en cada paso.

# %% [markdown]
#  Consiste en equilibrar un poste (péndulo) montado en la parte superior de un carrito móvil:
#  * El **objetivo** es mantener el poste en posición vertical mientras el carrito se mueve hacia adelante y hacia atrás en una pista.
#  * El **agente** (o jugador) tiene dos acciones disponibles en cada paso de tiempo: empujar el carrito hacia la izquierda o hacia la derecha.
#  * El **desafío** radica en tomar decisiones adecuadas para evitar que el poste caiga mientras se mueve el carrito.
#
#  Este problema es un ejemplo comúnmente utilizado para probar algoritmos de aprendizaje por refuerzo debido a su simplicidad y naturaleza desafiante.

# %% [markdown]
# https://gymnasium.farama.org/api/env/

# %%
import gymnasium as gym
import warnings
warnings.filterwarnings("ignore")
import time
import numpy as np

# %% [markdown]
# Crea un entorno de simulación llamado MountainCar-v0.
# Este es un entorno clásico en gym en el que un coche debe moverse hacia arriba de una colina empinada.
# El objetivo es aplicar fuerza en las direcciones izquierda o derecha para ganar impulso suficiente y alcanzar la cima.

# %%
env = gym.make('MountainCar-v0')

# %% [markdown]
# Reinicia el entorno a su estado inicial.
# Esto es útil para comenzar una nueva simulación. Devuelve el estado inicial del entorno.

# %%
env.reset()
# Out:
# (array([-0.5013776,  0.       ], dtype=float32), {})

# %% [markdown]
# A continuación: se ejecuta un bucle con 300 pasos dentro del entorno.

# %% [markdown]
# ``env.render()`` dibuja el entorno en una ventana gráfica para que puedas visualizar lo que está sucediendo (por ejemplo, el carro moviéndose).

# %% [markdown]
# ``env.action_space.sample()``
# Toma una acción aleatoria en el espacio de acciones del entorno. En este caso, las acciones posibles son:
#
# * 0: Aplicar fuerza hacia la izquierda.
# * 1: No aplicar fuerza.
# * 2: Aplicar fuerza hacia la derecha.

# %%
#for i in range(300):
#    env.render()
#    time.sleep(0.1)
#    env.step(env.action_space.sample()) # take a random action
#env.close()

# %%
#numpy.__version__

# %%
import gymnasium as gym
import warnings
import numpy

warnings.filterwarnings("ignore")

# Crear el entorno
env = gym.make('MountainCar-v0')
env.reset()

# Loop para ejecutar pasos en el entorno
for i in range(300):
    env.render()  # Renderizar el entorno
    env.step(env.action_space.sample())  # Tomar una acción aleatoria

env.close()

# %%
#numpy.__version__

# %% [markdown]
# Normalmente, terminaremos la simulación antes de que el carrito-péndulo tenga permitido salir de la pantalla. Más sobre eso después. Por ahora, por favor ignora la advertencia sobre llamar a `step()` aunque este entorno ya haya devuelto `done = True`.
#
# Si deseas ver otros entornos en acción, intenta reemplazar `CartPole-v0` arriba con algo como `MountainCar-v0`, `MsPacman-v0` (requiere la dependencia de Atari), o `Hopper-v1` (requiere las dependencias de MuJoCo). Todos los entornos descienden de la clase base `Env`.
#
# Ten en cuenta que si te faltan dependencias, deberías recibir un mensaje de error útil que te diga qué te falta. (Avísanos si alguna dependencia te causa problemas sin una instrucción clara para solucionarlo). Instalar una dependencia faltante generalmente es bastante simple. También necesitarás una licencia de MuJoCo para `Hopper-v1`.

# %% [markdown]
# ## Observaciones
#
# Si queremos hacer algo mejor que tomar acciones aleatorias en cada paso, probablemente sería bueno saber realmente qué están haciendo nuestras acciones en el entorno.
#
# La función `step` del entorno devuelve exactamente lo que necesitamos. De hecho, `step` devuelve cuatro valores. Estos son:
#
# * `observation` (object): un objeto específico del entorno que representa tu observación del entorno. Por ejemplo, datos de píxeles de una cámara, ángulos de articulación y velocidades de articulación de un robot, o el estado del tablero en un juego de mesa.
# * `reward` (float): cantidad de recompensa lograda por la acción anterior. La escala varía entre entornos, pero el objetivo es siempre aumentar tu recompensa total.
# * `done` (bool): si es hora de restablecer el entorno nuevamente. La mayoría (pero no todos) de las tareas están divididas en episodios bien definidos, y `done` siendo True indica que el episodio ha terminado. (Por ejemplo, tal vez el poste se inclinó demasiado, o perdiste tu última vida).
# * `truncated` (bool): True si el episodio se trunca debido a un límite de tiempo o una razón que no está definida.
# * `info` (dict): información de diagnóstico útil para la depuración. A veces puede ser útil para el aprendizaje (por ejemplo, podría contener las probabilidades crudas detrás del último cambio de estado del entorno). Sin embargo, no se permite usar esto para el aprendizaje en las evaluaciones oficiales de tu agente.
#
# Esto es simplemente una implementación del clásico "bucle agente-entorno". En cada paso de tiempo, el agente elige una acción, y el entorno devuelve una observación y una recompensa.

# %%
env = gym.make('MountainCar-v0')

# %%
env.action_space
# Out:
# Discrete(3)

# %% [markdown]
# ## Espacio de Acciones
#
# Hay 3 acciones discretas determinísticas:
#
# | Num | Observación          | Valor | Unidad       |
# |-----|----------------------|-------|--------------|
# | 0   | Acelerar a la izquierda | Inf   | posición (m) |
# | 1   | No acelerar              | Inf   | posición (m) |
# | 2   | Acelerar a la derecha    | Inf   | posición (m) |

# %%
# env = gym.make('MountainCar-v0', render_mode='human')
print(env.observation_space.shape)
# Out:
# (2,)

# %% [markdown]
# ## Espacio de Observación
#
# La observación es un ndarray con forma (2,), donde los elementos corresponden a lo siguiente:
#
# | Num | Observación                    | Mínimo | Máximo | Unidad        |
# |-----|--------------------------------|--------|--------|---------------|
# | 0   | posición del coche a lo largo del eje x | -Inf   | Inf    | posición (m) |
# | 1   | velocidad del coche             | -Inf   | Inf    | velocidad (m) |

# %%
import numpy as np
np.random.choice(np.array([1,2,3]))
# Out:
# 2

# %%
# import gym
env = gym.make('MountainCar-v0', render_mode='human')
for i_episode in range(5):
    # Reset del entorno
    print("Intento", i_episode)
    observation = env.reset()
    for t in range(10000):
        if t % 10 == 0:
            print("Accion", t)
            print("Observación", observation)
        # Visualizar ejercicio
        env.render()
        # Print del estado
        # print(observation)
        # Guarda en la variable action una de las acciones posibles elegida al azar
        action = env.action_space.sample()
        # Ejecuta esa acción, lo que nos devuelve, un nuevo estado, una recompensa, booleana /
        # que nos indica que ha alcanzado su objetivo e info debug
        observation, reward, done, truncated, info = env.step(action)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            break
env.close()
# Out:
# Intento 0
# Accion 0
# Observación (array([-0.4051285,  0.       ], dtype=float32), {})
# Accion 10
# Observación [-0.47890562 -0.01203407]
# Accion 20
# Observación [-0.57957006 -0.00764396]
# Accion 30
# Observación [-0.60061854  0.00179697]
# Accion 40
# Observación [-0.5500049   0.00729403]
# Accion 50
# Observación [-0.4474477   0.01210013]
# Accion 60
# Observación [-0.3682431   0.00323534]
# Accion 70
# Observación [-0.41069743 -0.01046402]
# Accion 80
# Observación [-0.5354203  -0.01393251]
# Accion 90
# Observación [-0.6855771  -0.01424696]
# Accion 100
# Observación [-0.72969323  0.0025903 ]
# Accion 110
# Observación [-0.60050213  0.01810904]
# Accion 120
# Observación [-0.42937222  0.01599427]
# Accion 130
# Observación [-0.3090412   0.00473213]
# Accion 140
# Observación [-0.35148486 -0.01099429]
# Accion 150
# Observación [-0.52403754 -0.01935487]
# Accion 160
# Observación [-0.70041937 -0.01520159]
# Accion 170
# Observación [-0.7800869  -0.00164175]
# Accion 180
# Observación [-0.70259106  0.01445609]
# Accion 190
# Observación [-0.49487463  0.02316798]
# Accion 200
# Observación [-0.3215342   0.01165825]
# Accion 210
# Observación [-0.28115115 -0.00344938]
# Accion 220
# Observación [-0.39225748 -0.01666359]
# Accion 230
# Observación [-0.58374697 -0.02238987]
# Accion 240
# Observación [-0.7598816 -0.0106655]
# Accion 250
# Observación [-0.7664995   0.00756953]
# Accion 260
# Observación [-0.6133937   0.02160886]
# Accion 270
# Observación [-0.38992015  0.01977518]
# Accion 280
# Observación [-0.24294494  0.01031919]
# Accion 290
# Observación [-0.24778692 -0.00798758]
# Accion 300
# Observación [-0.42187667 -0.0224821 ]
# Accion 310
# Observación [-0.6735547  -0.02583545]
# Accion 320
# Observación [-0.84767264 -0.01153115]
# Accion 330
# Observación [-0.8496547   0.00886397]
# Accion 340
# Observación [-0.6499088   0.02561681]
# Accion 350
# Observación [-0.3900535   0.02427799]
# Accion 360
# Observación [-0.2067596   0.00967721]
# Accion 370
# Observación [-0.22419457 -0.01104737]
# Accion 380
# Observación [-0.42274022 -0.0262558 ]
# Accion 390
# Observación [-0.6709064  -0.02305694]
# Accion 400
# Observación [-0.8483639  -0.01191238]
# Accion 410
# Observación [-0.839701    0.01032328]
# Accion 420
# Observación [-0.6160927   0.02793117]
# Accion 430
# Observación [-0.34917653  0.02378276]
# Accion 440
# Observación [-0.19589038  0.00551704]
# Accion 450
# Observación [-0.27218208 -0.01645768]
# Accion 460
# Observación [-0.5165364  -0.02806655]
# Accion 470
# Observación [-0.79097    -0.02246931]
# Accion 480
# Observación [-0.9240709  -0.00533127]
# Accion 490
# Observación [-0.8192368   0.02212992]
# Accion 500
# Observación [-0.5396655   0.03142337]
# Accion 510
# Observación [-0.24479827  0.02801559]
# Accion 520
# Observación [-0.08587994  0.00699387]
# Accion 530
# Observación [-0.15433381 -0.01485744]
# Accion 540
# Observación [-0.40523386 -0.03045647]
# Accion 550
# Observación [-0.7120785  -0.02670256]
# Accion 560
# Observación [-0.87841916 -0.00730994]
# Accion 570
# Observación [-0.8131516   0.01504424]
# Accion 580
# Observación [-0.60545695  0.02198231]
# Accion 590
# Observación [-0.38925478  0.01952037]
# Accion 600
# Observación [-0.2752619   0.00240752]
# Accion 610
# Observación [-0.33142063 -0.01175046]
# Accion 620
# Observación [-0.51259255 -0.02340534]
# Accion 630
# Observación [-0.7376361  -0.01857672]
# Accion 640
# Observación [-0.83696336 -0.00238238]
# Accion 650
# Observación [-0.77320117  0.01516897]
# Accion 660
# Observación [-0.5417276   0.02611165]
# Accion 670
# Observación [-0.3222487  0.0143362]
# Accion 680
# Observación [-0.27533063 -0.00404214]
# Accion 690
# Observación [-0.37618047 -0.01488276]
# Accion 700
# Observación [-0.5703594  -0.01970354]
# Accion 710
# Observación [-0.7260813  -0.01169593]
# Accion 720
# Observación [-0.75113934  0.00504606]
# Accion 730
# Observación [-0.6305727   0.01694952]
# Accion 740
# Observación [-0.4722286   0.01451562]
# Accion 750
# Observación [-0.35663563  0.00758573]
# Accion 760
# Observación [-0.3483993  -0.00419743]
# Accion 770
# Observación [-0.45161635 -0.01512959]
# Accion 780
# Observación [-0.6152747  -0.01496167]
# Accion 790
# Observación [-0.69082576 -0.00200861]
# Accion 800
# Observación [-0.63057894  0.01093   ]
# Accion 810
# Observación [-0.48150548  0.01511785]
# Accion 820
# Observación [-0.39568076  0.00443883]
# Accion 830
# Observación [-0.4381033  -0.01162387]
# Accion 840
# Observación [-0.55292517 -0.01004946]
# Accion 850
# Observación [-0.6265742  -0.00487659]
# Accion 860
# Observación [-6.4115256e-01  3.4250214e-04]
# Accion 870
# Observación [-0.6158514   0.00341317]
# Accion 880
# Observación [-0.5439675   0.00923274]
# Accion 890
# Observación [-0.41708016  0.0116061 ]
# Accion 900
# Observación [-0.33709022  0.00392108]
# Accion 910
# Observación [-0.35853404 -0.00732636]
# Accion 920
# Observación [-0.46851954 -0.01415345]
# Accion 930
# Observación [-0.6048553  -0.01148479]
# Accion 940
# Observación [-0.6777434  -0.00368244]
# Accion 950
# Observación [-0.65041476  0.008217  ]
# Accion 960
# Observación [-0.53752434  0.01305656]
# Accion 970
# Observación [-0.39006948  0.01318115]
# Accion 980
# Observación [-0.35620686 -0.00571185]
# Accion 990
# Observación [-0.46295598 -0.01289844]
# Accion 1000
# Observación [-0.61434543 -0.01435668]
# Accion 1010
# Observación [-6.854639e-01  4.677393e-04]
# Accion 1020
# Observación [-0.63103145  0.01000399]
# Accion 1030
# Observación [-0.51573825  0.01222708]
# Accion 1040
# Observación [-0.4210923  0.0071475]
# Accion 1050
# Observación [-0.39410776 -0.00082278]
# Accion 1060
# Observación [-0.4735194  -0.01239752]
# Accion 1070
# Observación [-0.62344617 -0.01628394]
# Accion 1080
# Observación [-0.7197286  -0.00433086]
# Accion 1090
# Observación [-0.6792638   0.01013164]
# Accion 1100
# Observación [-0.52984375  0.01710496]
# Accion 1110
# Observación [-0.37431377  0.01298576]
# Accion 1120
# Observación [-0.33625785 -0.0037919 ]
# Accion 1130
# Observación [-0.446213   -0.01537293]
# Accion 1140
# Observación [-0.60337824 -0.0136518 ]
# Accion 1150
# Observación [-0.7152206  -0.00574088]
# Accion 1160
# Observación [-0.710403    0.00531864]
# Accion 1170
# Observación [-0.6012302   0.01368516]
# Accion 1180
# Observación [-0.43714955  0.01503882]
# Accion 1190
# Observación [-0.33411786  0.00595575]
# Accion 1200
# Observación [-0.38098958 -0.01100098]
# Accion 1210
# Observación [-0.5329041 -0.0155747]
# Accion 1220
# Observación [-0.6764581  -0.01193674]
# Accion 1230
# Observación [-7.3189247e-01  3.7897786e-04]
# Accion 1240
# Observación [-0.6572993   0.01352033]
# Accion 1250
# Observación [-0.47347507  0.01838707]
# Accion 1260
# Observación [-0.33393055  0.00953166]
# Accion 1270
# Observación [-0.30079302 -0.00462688]
# Accion 1280
# Observación [-0.42131236 -0.01616791]
# Accion 1290
# Observación [-0.5937137  -0.01580007]
# Accion 1300
# Observación [-0.73096555 -0.01101902]
# Accion 1310
# Observación [-0.76810205  0.00320624]
# Accion 1320
# Observación [-0.6546776   0.01754977]
# Accion 1330
# Observación [-0.47246927  0.01709596]
# Accion 1340
# Observación [-0.32984668  0.01241918]
# Accion 1350
# Observación [-0.2984124  -0.00500015]
# Accion 1360
# Observación [-0.4270736  -0.01754036]
# Accion 1370
# Observación [-0.60456717 -0.01784511]
# Accion 1380
# Observación [-0.7281124  -0.00521559]
# Accion 1390
# Observación [-0.6882938  0.0120296]
# Accion 1400
# Observación [-0.49862963  0.02142407]
# Accion 1410
# Observación [-0.31016606  0.01607811]
# Accion 1420
# Observación [-0.24124864 -0.00025131]
# Accion 1430
# Observación [-0.36262554 -0.01989165]
# Accion 1440
# Observación [-0.5841411  -0.02027716]
# Accion 1450
# Observación [-0.7273585  -0.00842703]
# Accion 1460
# Observación [-0.7189101   0.00963822]
# Accion 1470
# Observación [-0.5382268   0.02052973]
# Accion 1480
# Observación [-0.34901473  0.01493894]
# Accion 1490
# Observación [-0.29460335 -0.00078888]
# Accion 1500
# Observación [-0.3827077  -0.01497922]
# Accion 1510
# Observación [-0.5595299  -0.01758354]
# Accion 1520
# Observación [-0.7055076  -0.01064383]
# Accion 1530
# Observación [-0.73873407  0.00396894]
# Accion 1540
# Observación [-0.60829     0.02016221]
# Accion 1550
# Observación [-0.3841961   0.02218591]
# Accion 1560
# Observación [-0.22340083  0.00886056]
# Accion 1570
# Observación [-0.24599165 -0.01208994]
# Accion 1580
# Observación [-0.46644703 -0.02520322]
# Accion 1590
# Observación [-0.7031301  -0.01800053]
# Accion 1600
# Observación [-0.8167992  -0.00563063]
# Accion 1610
# Observación [-0.7476452  0.0159036]
# Accion 1620
# Observación [-0.5131978   0.02703216]
# Accion 1630
# Observación [-0.28248292  0.01826664]
# Accion 1640
# Observación [-2.0464633e-01  1.3534754e-04]
# Accion 1650
# Observación [-0.3440262 -0.0220616]
# Accion 1660
# Observación [-0.60083497 -0.02593667]
# Accion 1670
# Observación [-0.8080306  -0.01429221]
# Accion 1680
# Observación [-0.84153354  0.00708767]
# Accion 1690
# Observación [-0.663098    0.02496178]
# Accion 1700
# Observación [-0.3724053   0.02772126]
# Accion 1710
# Observación [-0.16285944  0.01357598]
# Accion 1720
# Observación [-0.16545746 -0.01007774]
# Accion 1730
# Observación [-0.37276453 -0.02727371]
# Accion 1740
# Observación [-0.66343415 -0.02773833]
# Accion 1750
# Observación [-0.82996213 -0.00684096]
# Accion 1760
# Observación [-0.7929265   0.01203004]
# Accion 1770
# Observación [-0.58683926  0.02412482]
# Accion 1780
# Observación [-0.35238498  0.01857449]
# Accion 1790
# Observación [-0.23074892  0.00212035]
# Accion 1800
# Observación [-0.31004968 -0.01394588]
# Accion 1810
# Observación [-0.5097111  -0.02340016]
# Accion 1820
# Observación [-0.71352136 -0.01406734]
# Accion 1830
# Observación [-0.7631424   0.00357422]
# Accion 1840
# Observación [-0.63774866  0.0204945 ]
# Accion 1850
# Observación [-0.44147515  0.01938131]
# Accion 1860
# Observación [-0.2978006   0.00821242]
# Accion 1870
# Observación [-0.3098669  -0.00998595]
# Accion 1880
# Observación [-0.45697337 -0.01589542]
# Accion 1890
# Observación [-0.6172195  -0.01764265]
# Accion 1900
# Observación [-0.7194118  -0.00468757]
# Accion 1910
# Observación [-0.71710676  0.00556072]
# Accion 1920
# Observación [-0.600145    0.01629745]
# Accion 1930
# Observación [-0.43428814  0.01420146]
# Accion 1940
# Observación [-0.38010082 -0.00317508]
# Accion 1950
# Observación [-0.44782373 -0.00994395]
# Accion 1960
# Observación [-0.5666758  -0.01379963]
# Accion 1970
# Observación [-0.6924266  -0.00695148]
# Accion 1980
# Observación [-0.6719856   0.00846115]
# Accion 1990
# Observación [-0.5288192  0.017034 ]
# Accion 2000
# Observación [-0.38691986  0.01127466]
# Accion 2010
# Observación [-0.35717908 -0.00336507]
# Accion 2020
# Observación [-0.4297524  -0.01156233]
# Accion 2030
# Observación [-0.57312727 -0.01592357]
# Accion 2040
# Observación [-0.6749673  -0.00532978]
# Accion 2050
# Observación [-0.6701809  0.0061718]
# Accion 2060
# Observación [-0.57011455  0.01192757]
# Accion 2070
# Observación [-0.41899988  0.01659003]
# Accion 2080
# Observación [-0.29864675  0.00666966]
# Accion 2090
# Observación [-0.31224838 -0.00730494]
# Accion 2100
# Observación [-0.4810417  -0.02174197]
# Accion 2110
# Observación [-0.67663497 -0.01611034]
# Accion 2120
# Observación [-0.78146404 -0.00337988]
# Accion 2130
# Observación [-0.7148766   0.01307413]
# Accion 2140
# Observación [-0.5342228   0.01935121]
# Accion 2150
# Observación [-0.36858812  0.01443642]
# Accion 2160
# Observación [-0.30367258 -0.00145312]
# Accion 2170
# Observación [-0.3583142  -0.01076344]
# Accion 2180
# Observación [-0.5051624  -0.01855944]
# Accion 2190
# Observación [-0.6483392  -0.01068854]
# Accion 2200
# Observación [-0.6929301  -0.00078761]
# Accion 2210
# Observación [-0.63687694  0.00912886]
# Accion 2220
# Observación [-0.50476646  0.01426502]
# Accion 2230
# Observación [-0.39320707  0.00558375]
# Accion 2240
# Observación [-0.39765313 -0.00427252]
# Accion 2250
# Observación [-0.4909828  -0.01203321]
# Accion 2260
# Observación [-0.5949316  -0.00874965]
# Accion 2270
# Observación [-0.64780843 -0.00349067]
# Accion 2280
# Observación [-0.63804466  0.00483466]
# Accion 2290
# Observación [-0.5445783   0.01278749]
# Accion 2300
# Observación [-0.44042376  0.00635135]
# Accion 2310
# Observación [-0.4018     0.0016596]
# Accion 2320
# Observación [-0.42505026 -0.0070553 ]
# Accion 2330
# Observación [-0.5226545  -0.01246324]
# Accion 2340
# Observación [-0.6233903  -0.00780172]
# Accion 2350
# Observación [-0.6750136  -0.00141267]
# Accion 2360
# Observación [-0.66688037  0.00470576]
# Accion 2370
# Observación [-0.5418028  0.0147191]
# Accion 2380
# Observación [-0.3969126   0.00978093]
# Accion 2390
# Observación [-0.3608714   0.00090104]
# Accion 2400
# Observación [-0.41041824 -0.00900592]
# Accion 2410
# Observación [-0.5353283  -0.01443775]
# Accion 2420
# Observación [-0.6331031  -0.00575551]
# Accion 2430
# Observación [-0.64214784  0.00201319]
# Accion 2440
# Observación [-0.5573759   0.01151528]
# Accion 2450
# Observación [-0.442751   0.0111177]
# Accion 2460
# Observación [-0.35436082  0.00379571]
# Accion 2470
# Observación [-0.3962706  -0.01205218]
# Accion 2480
# Observación [-0.5544089  -0.01540148]
# Accion 2490
# Observación [-0.68471575 -0.01055192]
# Accion 2500
# Observación [-0.7205254   0.00393315]
# Accion 2510
# Observación [-0.60272294  0.01706282]
# Accion 2520
# Observación [-0.40793523  0.01731874]
# Accion 2530
# Observación [-0.32429826  0.00242221]
# Accion 2540
# Observación [-0.37527585 -0.00979982]
# Accion 2550
# Observación [-0.5051238  -0.01576887]
# Accion 2560
# Observación [-0.64960504 -0.0110883 ]
# Accion 2570
# Observación [-0.687867   0.0010072]
# Accion 2580
# Observación [-0.6198672   0.01021759]
# Accion 2590
# Observación [-0.47116408  0.01667488]
# Accion 2600
# Observación [-0.3364976   0.01011783]
# Accion 2610
# Observación [-0.33498898 -0.00811804]
# Accion 2620
# Observación [-0.47394753 -0.01676604]
# Accion 2630
# Observación [-0.6568816  -0.01720141]
# Accion 2640
# Observación [-0.7603395  -0.00368981]
# Accion 2650
# Observación [-0.7120919   0.00996144]
# Accion 2660
# Observación [-0.55275023  0.0200072 ]
# Accion 2670
# Observación [-0.36414593  0.01559662]
# Accion 2680
# Observación [-2.8919995e-01  2.4553460e-06]
# Accion 2690
# Observación [-0.37128443 -0.01136456]
# Accion 2700
# Observación [-0.5455514  -0.02042122]
# Accion 2710
# Observación [-0.6884234  -0.01051167]
# Accion 2720
# Observación [-0.71634024  0.00396985]
# Accion 2730
# Observación [-0.60013866  0.01472336]
# Accion 2740
# Observación [-0.44508374  0.0163302 ]
# Accion 2750
# Observación [-0.31756887  0.01012412]
# Accion 2760
# Observación [-0.28436482 -0.00186287]
# Accion 2770
# Observación [-0.3796702  -0.01423029]
# Accion 2780
# Observación [-0.5667926  -0.01884606]
# Accion 2790
# Observación [-0.7308758  -0.01394749]
# Accion 2800
# Observación [-8.0784279e-01  2.3348235e-04]
# Accion 2810
# Observación [-0.7028355   0.01938823]
# Accion 2820
# Observación [-0.47440892  0.02197813]
# Accion 2830
# Observación [-0.30470377  0.01232143]
# Accion 2840
# Observación [-0.29309714 -0.00816304]
# Accion 2850
# Observación [-0.4508672  -0.01911538]
# Accion 2860
# Observación [-0.63860476 -0.0181981 ]
# Accion 2870
# Observación [-0.7759868  -0.00705413]
# Accion 2880
# Observación [-0.7723594   0.00664324]
# Accion 2890
# Observación [-0.62201023  0.02013785]
# Accion 2900
# Observación [-0.42302483  0.01873161]
# Accion 2910
# Observación [-0.2908247   0.00761649]
# Accion 2920
# Observación [-0.32310787 -0.01143559]
# Accion 2930
# Observación [-0.5188749  -0.02319767]
# Accion 2940
# Observación [-0.7155416  -0.01560088]
# Accion 2950
# Observación [-0.8117876  -0.00395984]
# Accion 2960
# Observación [-0.75528985  0.01240956]
# Accion 2970
# Observación [-0.54324925  0.02583295]
# Accion 2980
# Observación [-0.31165263  0.01934673]
# Accion 2990
# Observación [-0.22014971  0.00146317]
# Accion 3000
# Observación [-0.32781684 -0.01971996]
# Accion 3010
# Observación [-0.5675305  -0.02636299]
# Accion 3020
# Observación [-0.8014052  -0.01727225]
# Accion 3030
# Observación [-8.8172382e-01  5.5572565e-04]
# Accion 3040
# Observación [-0.76097775  0.02093441]
# Accion 3050
# Observación [-0.47904983  0.02935104]
# Accion 3060
# Observación [-0.22531393  0.02057471]
# Accion 3070
# Observación [-0.11165668  0.00144073]
# Accion 3080
# Observación [-0.2273902  -0.02115345]
# Accion 3090
# Observación [-0.5105081  -0.03044992]
# Accion 3100
# Observación [-0.80598736 -0.02451027]
# Accion 3110
# Observación [-0.94583285 -0.00355424]
# Accion 3120
# Observación [-0.87221897  0.01685332]
# Accion 3130
# Observación [-0.6254004   0.03047516]
# Accion 3140
# Observación [-0.29359457  0.0310146 ]
# Accion 3150
# Observación [-0.09680574  0.01123056]
# Accion 3160
# Observación [-0.12811917 -0.01381528]
# Accion 3170
# Observación [-0.3874618  -0.03255274]
# Accion 3180
# Observación [-0.7240469  -0.03019109]
# Accion 3190
# Observación [-0.9323442  -0.01358913]
# Accion 3200
# Observación [-0.93728054  0.01146333]
# Accion 3210
# Observación [-0.6810915   0.03640142]
# Accion 3220
# Observación [-0.26639986  0.04056032]
# Accion 3230
# Observación [0.05646994 0.02276964]
# Accion 3240
# Observación [ 0.1352964  -0.00370824]
# Accion 3250
# Observación [-0.03597036 -0.02975405]
# Accion 3260
# Observación [-0.47519106 -0.05346069]
# Accion 3270
# Observación [-0.97437084 -0.0402974 ]
# Accion 3280
# Observación [-1.1942703  0.0044879]
# Accion 3290
# Observación [-1.0040878   0.03143181]
# Accion 3300
# Observación [-0.5857912   0.04812012]
# Accion 3310
# Observación [-0.13724929  0.03910773]
# Accion 3320
# Observación [0.10538363 0.01172678]
# Accion 3330
# Observación [ 0.07519099 -0.01388063]
# Accion 3340
# Observación [-0.18102868 -0.03525707]
# Accion 3350
# Observación [-0.6191191  -0.04460153]
# Accion 3360
# Observación [-1.01425    -0.03178584]
# Accion 3370
# Observación [-1.1987581  0.0012419]
# Accion 3380
# Observación [-1.0283792   0.02797099]
# Accion 3390
# Observación [-0.6558759   0.04463242]
# Accion 3400
# Observación [-0.19157857  0.04215261]
# Accion 3410
# Observación [0.08666302 0.01514449]
# Accion 3420
# Observación [ 0.11500099 -0.00537325]
# Accion 3430
# Observación [-0.04233008 -0.02575097]
# Accion 3440
# Observación [-0.41931635 -0.0445284 ]
# Accion 3450
# Observación [-0.81710124 -0.03251743]
# Accion 3460
# Observación [-1.0223297  -0.00945578]
# Accion 3470
# Observación [-0.9666522   0.02045273]
# Accion 3480
# Observación [-0.65957105  0.03722699]
# Accion 3490
# Observación [-0.3071451   0.03013544]
# Accion 3500
# Observación [-0.11881881  0.01008884]
# Accion 3510
# Observación [-0.16458276 -0.01533525]
# Accion 3520
# Observación [-0.40943176 -0.03385174]
# Accion 3530
# Observación [-0.78007996 -0.03400356]
# Accion 3540
# Observación [-1.0203722  -0.01375839]
# Accion 3550
# Observación [-1.0486385   0.01020915]
# Accion 3560
# Observación [-0.81998867  0.03302842]
# Accion 3570
# Observación [-0.39492422  0.04277442]
# Accion 3580
# Observación [-0.05958994  0.02105062]
# Accion 3590
# Observación [ 0.00604938 -0.00287935]
# Accion 3600
# Observación [-0.15208273 -0.02439004]
# Accion 3610
# Observación [-0.51707196 -0.0420551 ]
# Accion 3620
# Observación [-0.9158347  -0.03070937]
# Accion 3630
# Observación [-1.1242658  -0.01120657]
# Accion 3640
# Observación [-1.1066276   0.01094229]
# Accion 3650
# Observación [-0.8623949   0.03534458]
# Accion 3660
# Observación [-0.43312654  0.04567979]
# Accion 3670
# Observación [-0.06076916  0.02935335]
# Accion 3680
# Observación [0.09357846 0.0047095 ]
# Accion 3690
# Observación [ 0.0068798  -0.01960325]
# Accion 3700
# Observación [-0.30539584 -0.03823604]
# Accion 3710
# Observación [-0.7458363  -0.04383178]
# Accion 3720
# Observación [-1.0861732  -0.02274766]
# Accion 3730
# Observación [-1.1647898   0.00314475]
# Accion 3740
# Observación [-0.9868537   0.02850998]
# Accion 3750
# Observación [-0.5895758   0.04488046]
# Accion 3760
# Observación [-0.18222156  0.0362533 ]
# Accion 3770
# Observación [0.06261163 0.01316476]
# Accion 3780
# Observación [ 0.04755069 -0.01314722]
# Accion 3790
# Observación [-0.22690976 -0.03611426]
# Accion 3800
# Observación [-0.65544367 -0.04359795]
# Accion 3810
# Observación [-1.0149119  -0.02462553]
# Accion 3820
# Observación [-1.1054258   0.00216164]
# Accion 3830
# Observación [-0.9394505   0.02793274]
# Accion 3840
# Observación [-0.55826163  0.04233355]
# Accion 3850
# Observación [-0.16995963  0.03222125]
# Accion 3860
# Observación [0.02905164 0.01106328]
# Accion 3870
# Observación [ 0.00522269 -0.01375883]
# Accion 3880
# Observación [-0.23754351 -0.03343954]
# Accion 3890
# Observación [-0.6453112  -0.04192786]
# Accion 3900
# Observación [-0.97975    -0.02479972]
# Accion 3910
# Observación [-1.0911980e+00  4.9706632e-05]
# Accion 3920
# Observación [-0.95490026  0.02590389]
# Accion 3930
# Observación [-0.57917506  0.04341633]
# Accion 3940
# Observación [-0.16681351  0.03602092]
# Accion 3950
# Observación [0.06814567 0.01176511]
# Accion 3960
# Observación [ 0.04140304 -0.01352894]
# Accion 3970
# Observación [-0.24147765 -0.03732045]
# Accion 3980
# Observación [-0.67777276 -0.04367794]
# Accion 3990
# Observación [-1.015917   -0.02606433]
# Accion 4000
# Observación [-1.1109474   0.00168347]
# Accion 4010
# Observación [-0.96102536  0.02646885]
# Accion 4020
# Observación [-0.57344407  0.04717218]
# Accion 4030
# Observación [-0.13893077  0.03785202]
# Accion 4040
# Observación [0.09516575 0.01243087]
# Accion 4050
# Observación [ 0.08437554 -0.0132108 ]
# Accion 4060
# Observación [-0.19273388 -0.0405287 ]
# Accion 4070
# Observación [-0.6586328  -0.04685966]
# Accion 4080
# Observación [-1.0220368  -0.02563765]
# Accion 4090
# Observación [-1.1443706e+00 -1.0935953e-03]
# Accion 4100
# Observación [-1.0096011   0.02341685]
# Accion 4110
# Observación [-0.6492505   0.04371928]
# Accion 4120
# Observación [-0.20657966  0.04138117]
# Accion 4130
# Observación [0.10564548 0.0215987 ]
# Accion 4140
# Observación [0.20836951 0.00276514]
# Accion 4150
# Observación [ 0.1256874  -0.01826414]
# Accion 4160
# Observación [-0.1811148  -0.04247235]
# Accion 4170
# Observación [-0.6751406  -0.04986627]
# Accion 4180
# Observación [-1.0750293  -0.02842404]
# Accion 4190
# Observación [-1.1942703  0.0044879]
# Accion 4200
# Observación [-1.0276152   0.02732784]
# Accion 4210
# Observación [-0.64344364  0.04469154]
# Accion 4220
# Observación [-0.21137372  0.03801939]
# Accion 4230
# Observación [0.05831971 0.01529616]
# Accion 4240
# Observación [ 0.08216319 -0.00781137]
# Accion 4250
# Observación [-0.14133108 -0.03439293]
# Accion 4260
# Observación [-0.5875601  -0.04914306]
# Accion 4270
# Observación [-0.99859804 -0.03136289]
# Accion 4280
# Observación [-1.1564213  -0.00388048]
# Accion 4290
# Observación [-1.0730991   0.01816628]
# Accion 4300
# Observación [-0.7576201   0.04127567]
# Accion 4310
# Observación [-0.2821897   0.04803271]
# Accion 4320
# Observación [0.08169378 0.02638854]
# Accion 4330
# Observación [0.21563967 0.00537272]
# Accion 4340
# Observación [ 0.15809229 -0.01497879]
# Accion 4350
# Observación [-0.09955451 -0.03502176]
# Accion 4360
# Observación [-0.55645114 -0.05190887]
# Accion 4370
# Observación [-0.9799202  -0.03257546]
# Accion 4380
# Observación [-1.1954511  -0.01228981]
# Accion 4390
# Observación [-1.0968055   0.02095157]
# Accion 4400
# Observación [-0.7646977   0.04332697]
# Accion 4410
# Observación [-0.28776413  0.04604019]
# Accion 4420
# Observación [0.04982629 0.02159449]
# Accion 4430
# Observación [1.4745748e-01 9.3464092e-05]
# Accion 4440
# Observación [ 0.04970204 -0.01826845]
# Accion 4450
# Observación [-0.27956238 -0.04365621]
# Accion 4460
# Observación [-0.7332604  -0.04446043]
# Accion 4470
# Observación [-1.0600523 -0.020824 ]
# Accion 4480
# Observación [-1.1480331e+00  5.6505197e-04]
# Accion 4490
# Observación [-0.99787253  0.02705237]
# Accion 4500
# Observación [-0.59946024  0.04806939]
# Accion 4510
# Observación [-0.1683222   0.03738546]
# Accion 4520
# Observación [0.08244105 0.01417156]
# Accion 4530
# Observación [ 0.07359583 -0.01174388]
# Accion 4540
# Observación [-0.19515371 -0.03805329]
# Accion 4550
# Observación [-0.65147936 -0.04794542]
# Accion 4560
# Observación [-1.0486494  -0.02958235]
# Accion 4570
# Observación [-1.1977581  0.0022419]
# Accion 4580
# Observación [-1.0529767   0.02482775]
# Accion 4590
# Observación [-0.6918094  0.0456296]
# Accion 4600
# Observación [-0.23968177  0.03986349]
# Accion 4610
# Observación [0.02594314 0.01769942]
# Accion 4620
# Observación [ 0.05641586 -0.00786609]
# Accion 4630
# Observación [-0.15645729 -0.03245078]
# Accion 4640
# Observación [-0.5854201  -0.04676592]
# Accion 4650
# Observación [-0.97834253 -0.02847358]
# Accion 4660
# Observación [-1.1268326  -0.00275991]
# Accion 4670
# Observación [-1.0137312   0.02287001]
# Accion 4680
# Observación [-0.6602546   0.04460792]
# Accion 4690
# Observación [-0.20644107  0.04052977]
# Accion 4700
# Observación [0.07446107 0.01671607]
# Accion 4710
# Observación [ 0.11663278 -0.00492525]
# Accion 4720
# Observación [-0.0714243  -0.02933144]
# Accion 4730
# Observación [-0.47758088 -0.04812549]
# Accion 4740
# Observación [-0.9340656  -0.03801464]
# Accion 4750
# Observación [-1.1737983  -0.01263641]
# Accion 4760
# Observación [-1.1342485   0.01510629]
# Accion 4770
# Observación [-0.86222774  0.0374357 ]
# Accion 4780
# Observación [-0.40428156  0.04459316]
# Accion 4790
# Observación [-0.02884197  0.03003339]
# Accion 4800
# Observación [0.10868569 0.00256811]
# Accion 4810
# Observación [ 0.00258477 -0.02161696]
# Accion 4820
# Observación [-0.34247595 -0.0457475 ]
# Accion 4830
# Observación [-0.80342036 -0.0427426 ]
# Accion 4840
# Observación [-1.1240617  -0.02146584]
# Accion 4850
# Observación [-1.1905282   0.00574203]
# Accion 4860
# Observación [-0.974922    0.03381832]
# Accion 4870
# Observación [-0.52467394  0.05018855]
# Accion 4880
# Observación [-0.10305566  0.03483009]
# Accion 4890
# Observación [0.10520758 0.01030172]
# Accion 4900
# Observación [ 0.06282348 -0.01831304]
# Accion 4910
# Observación [-0.252705   -0.04308729]
# Accion 4920
# Observación [-0.7186185  -0.04422183]
# Accion 4930
# Observación [-1.0222645  -0.01924961]
# Accion 4940
# Observación [-1.0836657   0.00563902]
# Accion 4950
# Observación [-0.8740457   0.03210923]
# Accion 4960
# Observación [-0.4584441   0.04573992]
# Accion 4970
# Observación [-0.09831202  0.02369841]
# Accion 4980
# Observación [ 0.01034064 -0.00105886]
# Accion 4990
# Observación [-0.12919557 -0.02579201]
# Accion 5000
# Observación [-0.5216129 -0.0481966]
# Accion 5010
# Observación [-0.96576214 -0.03558931]
# Accion 5020
# Observación [-1.1763716  -0.01118207]
# Accion 5030
# Observación [-1.1452676   0.01479098]
# Accion 5040
# Observación [-0.84888554  0.0430456 ]
# Accion 5050
# Observación [-0.3605486  0.0494247]
# Accion 5060
# Observación [0.0612498  0.03361799]
# Accion 5070
# Observación [0.274      0.01138279]
# Accion 5080
# Observación [ 0.31612152 -0.0019508 ]
# Accion 5090
# Observación [ 0.2152012  -0.01923809]
# Accion 5100
# Observación [-0.09198559 -0.04242539]
# Accion 5110
# Observación [-0.6390873  -0.06107673]
# Accion 5120
# Observación [-1.1473027  -0.03904632]
# Accion 5130
# Observación [-1.1096774   0.01954345]
# Accion 5140
# Observación [-0.80078363  0.04135079]
# Accion 5150
# Observación [-0.31560868  0.04881272]
# Accion 5160
# Observación [0.05758251 0.02896819]
# Accion 5170
# Observación [0.23091653 0.00688192]
# Accion 5180
# Observación [ 0.18657275 -0.01349   ]
# Accion 5190
# Observación [-0.10453655 -0.04007729]
# Accion 5200
# Observación [-0.60450923 -0.05317689]
# Accion 5210
# Observación [-1.0804225  -0.03992561]
# Accion 5220
# Observación [-1.1373284   0.01874812]
# Accion 5230
# Observación [-0.8441395   0.03895406]
# Accion 5240
# Observación [-0.39650455  0.04636443]
# Accion 5250
# Observación [-0.02605775  0.026404  ]
# Accion 5260
# Observación [0.12034245 0.00401227]
# Accion 5270
# Observación [ 0.04718142 -0.01769057]
# Accion 5280
# Observación [-0.24223027 -0.03646303]
# Accion 5290
# Observación [-0.6649575  -0.04215396]
# Accion 5300
# Observación [-0.990498   -0.02110537]
# Accion 5310
# Observación [-1.071683    0.00380162]
# Accion 5320
# Observación [-0.86938065  0.03224954]
# Accion 5330
# Observación [-0.45442852  0.04464145]
# Accion 5340
# Observación [-0.08698194  0.02848225]
# Accion 5350
# Observación [0.07206138 0.00179228]
# Accion 5360
# Observación [-0.03839067 -0.02093159]
# Accion 5370
# Observación [-0.3663161 -0.0420168]
# Accion 5380
# Observación [-0.78914815 -0.03956008]
# Accion 5390
# Observación [-1.0810773  -0.01866768]
# Accion 5400
# Observación [-1.1058103   0.00979344]
# Accion 5410
# Observación [-0.86411136  0.03417765]
# Accion 5420
# Observación [-0.42834756  0.04769611]
# Accion 5430
# Observación [-0.05278519  0.02803008]
# Accion 5440
# Observación [ 0.07919511 -0.00064756]
# Accion 5450
# Observación [-0.06952358 -0.0263519 ]
# Accion 5460
# Observación [-0.4202533  -0.04155024]
# Accion 5470
# Observación [-0.8409569  -0.03728083]
# Accion 5480
# Observación [-1.0632415  -0.01056311]
# Accion 5490
# Observación [-1.0287502   0.01437776]
# Accion 5500
# Observación [-0.7353921   0.04087955]
# Accion 5510
# Observación [-0.27989158  0.04331622]
# Accion 5520
# Observación [0.03204168 0.01884512]
# Accion 5530
# Observación [ 0.09316328 -0.00340692]
# Accion 5540
# Observación [-0.090475   -0.03001062]
# Accion 5550
# Observación [-0.49788082 -0.04676167]
# Accion 5560
# Observación [-0.9395838  -0.03676241]
# Accion 5570
# Observación [-1.150297   -0.01023243]
# Accion 5580
# Observación [-1.1144476   0.01252096]
# Accion 5590
# Observación [-0.8527152   0.03886221]
# Accion 5600
# Observación [-0.40205982  0.04682855]
# Accion 5610
# Observación [-0.01214602  0.02875567]
# Accion 5620
# Observación [0.13765109 0.00361701]
# Accion 5630
# Observación [ 0.05461448 -0.01876603]
# Accion 5640
# Observación [-0.24548516 -0.03853369]
# Accion 5650
# Observación [-0.66946083 -0.04172806]
# Accion 5660
# Observación [-0.9896984  -0.02373406]
# Accion 5670
# Observación [-1.0781915  0.0031632]
# Accion 5680
# Observación [-0.92564857  0.0259323 ]
# Accion 5690
# Observación [-0.5548525   0.04413632]
# Accion 5700
# Observación [-0.13061975  0.03691243]
# Accion 5710
# Observación [0.10372999 0.01347791]
# Accion 5720
# Observación [ 0.08856645 -0.01198522]
# Accion 5730
# Observación [-0.19108061 -0.03928265]
# Accion 5740
# Observación [-0.66319156 -0.04765663]
# Accion 5750
# Observación [-1.025113   -0.02623064]
# Accion 5760
# Observación [-1.1434548e+00  2.9572326e-04]
# Accion 5770
# Observación [-0.9744502  0.0288472]
# Accion 5780
# Observación [-0.5741234   0.04667106]
# Accion 5790
# Observación [-0.12874258  0.03803959]
# Accion 5800
# Observación [0.11885203 0.0126762 ]
# Accion 5810
# Observación [ 0.1349943  -0.00705022]
# Accion 5820
# Observación [-0.09092426 -0.03427725]
# Accion 5830
# Observación [-0.5689153 -0.0540971]
# Accion 5840
# Observación [-1.0666392  -0.04213032]
# Accion 5850
# Observación [-1.1585425   0.01364396]
# Accion 5860
# Observación [-0.8823141   0.04199252]
# Accion 5870
# Observación [-0.39404902  0.05169004]
# Accion 5880
# Observación [0.03640459 0.03293904]
# Accion 5890
# Observación [0.25049323 0.01183729]
# Accion 5900
# Observación [ 0.25279874 -0.00754118]
# Accion 5910
# Observación [ 0.05213302 -0.02964095]
# Accion 5920
# Observación [-0.36919218 -0.0506061 ]
# Accion 5930
# Observación [-0.8642278  -0.04457223]
# Accion 5940
# Observación [-1.1718178  -0.01858192]
# Accion 5950
# Observación [-1.1299984   0.01542614]
# Accion 5960
# Observación [-0.8695482   0.03379314]
# Accion 5970
# Observación [-0.46246976  0.04321846]
# Accion 5980
# Observación [-0.0942798   0.02751493]
# Accion 5990
# Observación [0.06623217 0.00778603]
# Accion 6000
# Observación [ 0.02074903 -0.01669985]
# Accion 6010
# Observación [-0.26572937 -0.03708138]
# Accion 6020
# Observación [-0.71258706 -0.0431865 ]
# Accion 6030
# Observación [-1.0405042  -0.02424033]
# Accion 6040
# Observación [-1.1482028  -0.00177317]
# Accion 6050
# Observación [-1.0188098   0.02464627]
# Accion 6060
# Observación [-0.6480794   0.04616968]
# Accion 6070
# Observación [-0.1806682   0.04210826]
# Accion 6080
# Observación [0.11524232 0.01807918]
# Accion 6090
# Observación [ 0.17208584 -0.00313805]
# Accion 6100
# Observación [ 0.03169923 -0.02319539]
# Accion 6110
# Observación [-0.34903485 -0.04847912]
# Accion 6120
# Observación [-0.84258777 -0.04598363]
# Accion 6130
# Observación [-1.1833469 -0.0222471]
# Accion 6140
# Observación [-1.0764724   0.02506132]
# Accion 6150
# Observación [-0.67686427  0.04674952]
# Accion 6160
# Observación [-0.20480394  0.04131213]
# Accion 6170
# Observación [0.08659162 0.01947267]
# Accion 6180
# Observación [ 0.16311063 -0.0022674 ]
# Accion 6190
# Observación [ 0.00958947 -0.0256461 ]
# Accion 6200
# Observación [-0.35231337 -0.04659956]
# Accion 6210
# Observación [-0.8126627  -0.03964815]
# Accion 6220
# Observación [-1.0887281  -0.01628914]
# Accion 6230
# Observación [-1.1304349   0.00597849]
# Accion 6240
# Observación [-0.95627785  0.02767733]
# Accion 6250
# Observación [-0.572345    0.04381359]
# Accion 6260
# Observación [-0.1703342   0.03204218]
# Accion 6270
# Observación [0.01095008 0.005893  ]
# Accion 6280
# Observación [-0.06248938 -0.01806328]
# Accion 6290
# Observación [-0.3725084  -0.03645524]
# Accion 6300
# Observación [-0.73285973 -0.0323264 ]
# Accion 6310
# Observación [-0.9665262  -0.01496176]
# Accion 6320
# Observación [-0.966058    0.01162614]
# Accion 6330
# Observación [-0.7257019   0.03509176]
# Accion 6340
# Observación [-0.36818922  0.03503602]
# Accion 6350
# Observación [-0.10206818  0.01642702]
# Accion 6360
# Observación [-0.08429578 -0.00892413]
# Accion 6370
# Observación [-0.29590517 -0.02860122]
# Accion 6380
# Observación [-0.64081293 -0.0339345 ]
# Accion 6390
# Observación [-0.8841578  -0.01360555]
# Accion 6400
# Observación [-0.9076316   0.00940258]
# Accion 6410
# Observación [-0.7184158  0.0273103]
# Accion 6420
# Observación [-0.39711186  0.03312101]
# Accion 6430
# Observación [-0.14867342  0.01530334]
# Accion 6440
# Observación [-0.1285278  -0.00807916]
# Accion 6450
# Observación [-0.32607353 -0.02845334]
# Accion 6460
# Observación [-0.63302857 -0.02860257]
# Accion 6470
# Observación [-0.8798267  -0.01808554]
# Accion 6480
# Observación [-0.93960094  0.00313665]
# Accion 6490
# Observación [-0.7937017   0.02323268]
# Accion 6500
# Observación [-0.47410765  0.03475731]
# Accion 6510
# Observación [-0.16333398  0.02514525]
# Accion 6520
# Observación [-0.07280429 -0.00266165]
# Accion 6530
# Observación [-0.23639892 -0.02561624]
# Accion 6540
# Observación [-0.55329305 -0.03305116]
# Accion 6550
# Observación [-0.82449675 -0.01951783]
# Accion 6560
# Observación [-9.1746062e-01 -6.3968735e-04]
# Accion 6570
# Observación [-0.79710567  0.02124055]
# Accion 6580
# Observación [-0.524236   0.0292474]
# Accion 6590
# Observación [-0.26773283  0.01932312]
# Accion 6600
# Observación [-0.16852126  0.00112589]
# Accion 6610
# Observación [-0.28185967 -0.02038745]
# Accion 6620
# Observación [-0.567207   -0.03218587]
# Accion 6630
# Observación [-0.839299   -0.01986254]
# Accion 6640
# Observación [-0.9166877   0.00346506]
# Accion 6650
# Observación [-0.74521166  0.02844484]
# Accion 6660
# Observación [-0.4118647   0.03494703]
# Accion 6670
# Observación [-0.12529059  0.0201938 ]
# Accion 6680
# Observación [-0.0697223  -0.00707184]
# Accion 6690
# Observación [-0.2566562  -0.02774242]
# Accion 6700
# Observación [-0.6421721  -0.04201813]
# Accion 6710
# Observación [-0.9886356  -0.02584749]
# Accion 6720
# Observación [-1.1266453  -0.00410706]
# Accion 6730
# Observación [-1.0272057   0.01948987]
# Accion 6740
# Observación [-0.70175594  0.04332942]
# Accion 6750
# Observación [-0.23278978  0.04510303]
# Accion 6760
# Observación [0.08745614 0.02059876]
# Accion 6770
# Observación [ 0.16321908 -0.00215356]
# Accion 6780
# Observación [ 0.02465213 -0.02635245]
# Accion 6790
# Observación [-0.37940204 -0.04888289]
# Accion 6800
# Observación [-0.88498354 -0.04600166]
# Accion 6810
# Observación [-1.193256   -0.01895044]
# Accion 6820
# Observación [-1.1183095   0.01779837]
# Accion 6830
# Observación [-0.81158966  0.04177452]
# Accion 6840
# Observación [-0.3179858   0.04854433]
# Accion 6850
# Observación [0.09488006 0.03060615]
# Accion 6860
# Observación [0.3102268  0.01460162]
# Accion 6870
# Observación [ 0.34846553 -0.00238786]
# Accion 6880
# Observación [ 0.22477505 -0.0203704 ]
# Accion 6890
# Observación [-0.10232556 -0.04537263]
# Accion 6900
# Observación [-0.6448033  -0.05735893]
# Accion 6910
# Observación [-1.1473294  -0.04128121]
# Accion 6920
# Observación [-1.1057025   0.02054688]
# Accion 6930
# Observación [-0.8037083   0.04036818]
# Accion 6940
# Observación [-0.3264064   0.04724121]
# Accion 6950
# Observación [0.03630326 0.02569221]
# Accion 6960
# Observación [0.16997775 0.00333646]
# Accion 6970
# Observación [ 0.08365241 -0.01715174]
# Accion 6980
# Observación [-0.21955745 -0.0412543 ]
# Accion 6990
# Observación [-0.70021623 -0.04857747]
# Accion 7000
# Observación [-1.0657302  -0.02460872]
# Accion 7010
# Observación [-1.1893677e+00 -7.4080465e-04]
# Accion 7020
# Observación [-1.0629874   0.02486249]
# Accion 7030
# Observación [-0.6720193   0.04738376]
# Accion 7040
# Observación [-0.19379994  0.04355217]
# Accion 7050
# Observación [0.09173299 0.01758469]
# Accion 7060
# Observación [ 0.13259383 -0.00648221]
# Accion 7070
# Observación [-0.0512877  -0.02966539]
# Accion 7080
# Observación [-0.50107855 -0.05444778]
# Accion 7090
# Observación [-0.9709441  -0.03716823]
# Accion 7100
# Observación [-1.2  0. ]
# Accion 7110
# Observación [-1.0787808   0.02334423]
# Accion 7120
# Observación [-0.7383243   0.04214879]
# Accion 7130
# Observación [-0.27543655  0.04345642]
# Accion 7140
# Observación [0.05440084 0.02277858]
# Accion 7150
# Observación [ 0.14137657 -0.00265848]
# Accion 7160
# Observación [-0.02774356 -0.02661627]
# Accion 7170
# Observación [-0.4153405  -0.04783664]
# Accion 7180
# Observación [-0.86628836 -0.03986218]
# Accion 7190
# Observación [-1.126753   -0.01374566]
# Accion 7200
# Observación [-1.1472715  0.0089503]
# Accion 7210
# Observación [-0.9392973   0.03051664]
# Accion 7220
# Observación [-0.52519006  0.04724567]
# Accion 7230
# Observación [-0.10710298  0.03202369]
# Accion 7240
# Observación [0.06501427 0.00536133]
# Accion 7250
# Observación [-0.0428621  -0.02336918]
# Accion 7260
# Observación [-0.40496844 -0.04346255]
# Accion 7270
# Observación [-0.82471216 -0.03825549]
# Accion 7280
# Observación [-1.0807227  -0.01477404]
# Accion 7290
# Observación [-1.1021223   0.00677922]
# Accion 7300
# Observación [-0.8970791   0.03038093]
# Accion 7310
# Observación [-0.512869    0.04335159]
# Accion 7320
# Observación [-0.11668654  0.02996007]
# Accion 7330
# Observación [0.03431853 0.00329472]
# Accion 7340
# Observación [-0.08970448 -0.02357724]
# Accion 7350
# Observación [-0.43330073 -0.04104202]
# Accion 7360
# Observación [-0.8157572  -0.03276736]
# Accion 7370
# Observación [-1.0186962 -0.0077306]
# Accion 7380
# Observación [-0.96803576  0.01411725]
# Accion 7390
# Observación [-0.6978519   0.03694093]
# Accion 7400
# Observación [-0.34231517  0.03053939]
# Accion 7410
# Observación [-0.1534308  0.0100416]
# Accion 7420
# Observación [-0.1626562  -0.01081084]
# Accion 7430
# Observación [-0.38797042 -0.02878091]
# Accion 7440
# Observación [-0.68674916 -0.02770183]
# Accion 7450
# Observación [-0.86630195 -0.00825448]
# Accion 7460
# Observación [-0.8195551   0.01402866]
# Accion 7470
# Observación [-0.5828254   0.02896126]
# Accion 7480
# Observación [-0.2760095   0.02811537]
# Accion 7490
# Observación [-0.13582483  0.00333659]
# Accion 7500
# Observación [-0.25077838 -0.02351492]
# Accion 7510
# Observación [-0.5799642 -0.0359186]
# Accion 7520
# Observación [-0.8868125  -0.02409214]
# Accion 7530
# Observación [-1.0001242e+00 -1.2145515e-04]
# Accion 7540
# Observación [-0.85038704  0.0267779 ]
# Accion 7550
# Observación [-0.5036859   0.03915635]
# Accion 7560
# Observación [-0.15623498  0.02751721]
# Accion 7570
# Observación [-0.01798585  0.00231189]
# Accion 7580
# Observación [-0.10175605 -0.017466  ]
# Accion 7590
# Observación [-0.3973129  -0.03875811]
# Accion 7600
# Observación [-0.77060086 -0.03250259]
# Accion 7610
# Observación [-0.97901213 -0.01082763]
# Accion 7620
# Observación [-0.9606664   0.01382082]
# Accion 7630
# Observación [-0.6772065   0.03915174]
# Accion 7640
# Observación [-0.24074528  0.0412315 ]
# Accion 7650
# Observación [0.08553237 0.02393541]
# Accion 7660
# Observación [0.2221249  0.00598884]
# Accion 7670
# Observación [ 0.20912904 -0.01026939]
# Accion 7680
# Observación [-0.0560088  -0.03921422]
# Accion 7690
# Observación [-0.5658671  -0.05581458]
# Accion 7700
# Observación [-1.0758216  -0.04180935]
# Accion 7710
# Observación [-1.1504631   0.01468675]
# Accion 7720
# Observación [-0.8583919   0.04296848]
# Accion 7730
# Observación [-0.33879262  0.05101694]
# Accion 7740
# Observación [0.09531462 0.03349721]
# Accion 7750
# Observación [0.34994587 0.01829309]
# Accion 7760
# Observación [0.48033175 0.00756245]
# Episode finished after 7763 timesteps
# Intento 1
# Accion 0
# Observación (array([-0.59948,  0.     ], dtype=float32), {})
# Accion 10
# Observación [-0.56363934  0.00690297]
# Accion 20
# Observación [-0.48552474  0.00712315]
# Accion 30
# Observación [-0.43788162  0.00345972]
# Accion 40
# Observación [-0.4259478   0.00066672]
# Accion 50
# Observación [-0.47978508 -0.00822232]
# Accion 60
# Observación [-0.60220784 -0.01259419]
# Accion 70
# Observación [-0.6545754   0.00178127]
# Accion 80
# Observación [-0.6079399   0.00821483]
# Accion 90
# Observación [-0.53277045  0.00571821]
# Accion 100
# Observación [-0.4897909   0.00486187]
# Accion 110
# Observación [-0.48192403 -0.00351888]
# Accion 120
# Observación [-0.5375164  -0.00577833]
# Accion 130
# Observación [-0.5407902  0.0040491]
# Accion 140
# Observación [-0.4953864   0.00385536]
# Accion 150
# Observación [-0.45876458  0.00336846]
# Accion 160
# Observación [-0.45658684 -0.00085424]
# Accion 170
# Observación [-0.49227822 -0.00487429]
# Accion 180
# Observación [-0.5358233  -0.00463857]
# Accion 190
# Observación [-0.55636066 -0.00199901]
# Accion 200
# Observación [-0.576666    0.00254008]
# Accion 210
# Observación [-0.52072865  0.00471673]
# Accion 220
# Observación [-0.45578656  0.00650558]
# Accion 230
# Observación [-0.45562997 -0.00415717]
# Accion 240
# Observación [-0.52742165 -0.0068312 ]
# Accion 250
# Observación [-0.5860228  -0.00437563]
# Accion 260
# Observación [-0.60758424 -0.00063838]
# Accion 270
# Observación [-0.5941404   0.00236067]
# Accion 280
# Observación [-0.5348896   0.00682866]
# Accion 290
# Observación [-0.47028738  0.00762341]
# Accion 300
# Observación [-0.43249515  0.00204118]
# Accion 310
# Observación [-0.43889505 -0.0017738 ]
# Accion 320
# Observación [-0.49137127 -0.00880985]
# Accion 330
# Observación [-0.58974755 -0.00770406]
# Accion 340
# Observación [-0.6521736  -0.00454056]
# Accion 350
# Observación [-0.62043005  0.00969917]
# Accion 360
# Observación [-0.5197791   0.00961244]
# Accion 370
# Observación [-0.43635026  0.00634126]
# Accion 380
# Observación [-0.39678153  0.00144798]
# Accion 390
# Observación [-0.43751812 -0.01032668]
# Accion 400
# Observación [-0.5439061  -0.01015617]
# Accion 410
# Observación [-0.6479172  -0.01026592]
# Accion 420
# Observación [-0.6748508   0.00339243]
# Accion 430
# Observación [-0.6204945  0.006922 ]
# Accion 440
# Observación [-0.5245595   0.01332544]
# Accion 450
# Observación [-0.3972577   0.00878397]
# Accion 460
# Observación [-0.3813039  -0.00481031]
# Accion 470
# Observación [-0.4888455  -0.01429355]
# Accion 480
# Observación [-0.6353398  -0.01383595]
# Accion 490
# Observación [-0.7049305  -0.00073448]
# Accion 500
# Observación [-0.6503291   0.00808623]
# Accion 510
# Observación [-0.5398223   0.01310438]
# Accion 520
# Observación [-0.4101588   0.00973221]
# Accion 530
# Observación [-0.3598074   0.00137017]
# Accion 540
# Observación [-0.391879   -0.00695076]
# Accion 550
# Observación [-0.4683399  -0.00711935]
# Accion 560
# Observación [-0.5793225  -0.00960423]
# Accion 570
# Observación [-0.6532932  -0.00372726]
# Accion 580
# Observación [-0.6534616   0.00434942]
# Accion 590
# Observación [-0.5889001  0.0090531]
# Accion 600
# Observación [-0.4725991   0.01003632]
# Accion 610
# Observación [-0.4258317   0.00109185]
# Accion 620
# Observación [-0.44391218 -0.00486283]
# Accion 630
# Observación [-0.5038541  -0.00802072]
# Accion 640
# Observación [-0.5785749  -0.00568747]
# Accion 650
# Observación [-0.5840144  0.0020004]
# Accion 660
# Observación [-0.52658653  0.00910966]
# Accion 670
# Observación [-0.4172399   0.01072799]
# Accion 680
# Observación [-0.35400286  0.00237503]
# Accion 690
# Observación [-0.36929566 -0.00590423]
# Accion 700
# Observación [-0.47847828 -0.01405587]
# Accion 710
# Observación [-0.63082373 -0.01532993]
# Accion 720
# Observación [-0.7210902 -0.0029599]
# Accion 730
# Observación [-0.6805132   0.01056934]
# Accion 740
# Observación [-0.53199595  0.01751128]
# Accion 750
# Observación [-0.38103366  0.01166994]
# Accion 760
# Observación [-0.33416483 -0.00201768]
# Accion 770
# Observación [-0.43324378 -0.01504511]
# Accion 780
# Observación [-0.60587955 -0.01582179]
# Accion 790
# Observación [-0.7172126  -0.00673201]
# Accion 800
# Observación [-0.7163553   0.00671652]
# Accion 810
# Observación [-0.5757248   0.01765975]
# Accion 820
# Observación [-0.4069204   0.01582206]
# Accion 830
# Observación [-0.30458358  0.0024519 ]
# Accion 840
# Observación [-0.363717   -0.00968804]
# Accion 850
# Observación [-0.5085983  -0.01484046]
# Accion 860
# Observación [-0.6357851 -0.0093116]
# Accion 870
# Observación [-0.6753193   0.00173886]
# Accion 880
# Observación [-0.6095391   0.01016429]
# Accion 890
# Observación [-0.48175275  0.01459614]
# Accion 900
# Observación [-0.35665724  0.01007949]
# Accion 910
# Observación [-0.34372318 -0.0072121 ]
# Accion 920
# Observación [-0.45709863 -0.01383355]
# Accion 930
# Observación [-0.59964705 -0.01290104]
# Accion 940
# Observación [-0.6779037  -0.00204916]
# Accion 950
# Observación [-0.647243    0.00662305]
# Accion 960
# Observación [-0.53755426  0.01241134]
# Accion 970
# Observación [-0.3980698  0.0127217]
# Accion 980
# Observación [-0.3174982   0.00245821]
# Accion 990
# Observación [-0.3861816  -0.01501981]
# Accion 1000
# Observación [-0.54964066 -0.01579147]
# Accion 1010
# Observación [-0.6721107  -0.01046151]
# Accion 1020
# Observación [-0.71979654  0.00143516]
# Accion 1030
# Observación [-0.650727    0.01082851]
# Accion 1040
# Observación [-0.50998855  0.01250617]
# Accion 1050
# Observación [-0.3912745   0.01029354]
# Accion 1060
# Observación [-0.35839733 -0.00322379]
# Accion 1070
# Observación [-0.45860165 -0.01458696]
# Accion 1080
# Observación [-0.5993955  -0.01464928]
# Accion 1090
# Observación [-0.68987507 -0.00464902]
# Accion 1100
# Observación [-0.6420206  0.009601 ]
# Accion 1110
# Observación [-0.49715835  0.0159862 ]
# Accion 1120
# Observación [-0.39754942  0.00284837]
# Accion 1130
# Observación [-0.40173954 -0.00475056]
# Accion 1140
# Observación [-0.48340374 -0.00813837]
# Accion 1150
# Observación [-0.55715567 -0.00664319]
# Accion 1160
# Observación [-0.6169969  -0.00299174]
# Accion 1170
# Observación [-0.61187917  0.00409358]
# Accion 1180
# Observación [-0.5569326   0.00491604]
# Accion 1190
# Observación [-0.5040751   0.00454854]
# Accion 1200
# Observación [-0.44768628  0.00738893]
# Accion 1210
# Observación [-4.0732035e-01  7.8795965e-05]
# Accion 1220
# Observación [-0.45343763 -0.00843298]
# Accion 1230
# Observación [-0.57356304 -0.01396671]
# Accion 1240
# Observación [-0.6661551  -0.00675322]
# Accion 1250
# Observación [-0.71567965 -0.00156974]
# Accion 1260
# Observación [-0.67840874  0.0095875 ]
# Accion 1270
# Observación [-0.5370382   0.01673735]
# Accion 1280
# Observación [-0.39087537  0.00944276]
# Accion 1290
# Observación [-0.39287093 -0.00601982]
# Accion 1300
# Observación [-0.4843505  -0.01210641]
# Accion 1310
# Observación [-0.60802    -0.00858305]
# Accion 1320
# Observación [-0.63235813  0.00433229]
# Accion 1330
# Observación [-0.5641243   0.00831797]
# Accion 1340
# Observación [-0.48460332  0.00776229]
# Accion 1350
# Observación [-0.4468904   0.00133592]
# Accion 1360
# Observación [-0.45494846 -0.00452038]
# Accion 1370
# Observación [-0.51569337 -0.0057491 ]
# Accion 1380
# Observación [-0.5659682  -0.00357678]
# Accion 1390
# Observación [-5.8794194e-01 -3.4731926e-04]
# Accion 1400
# Observación [-0.60321087 -0.00325541]
# Accion 1410
# Observación [-0.62051123 -0.00064355]
# Accion 1420
# Observación [-0.5931806   0.00615198]
# Accion 1430
# Observación [-0.5204703   0.00801839]
# Accion 1440
# Observación [-0.4694849   0.00172285]
# Accion 1450
# Observación [-0.46572834 -0.00158921]
# Accion 1460
# Observación [-0.52366245 -0.00823993]
# Accion 1470
# Observación [-0.5940217  -0.00458888]
# Accion 1480
# Observación [-0.60713655  0.00135812]
# Accion 1490
# Observación [-0.57269824  0.00238575]
# Accion 1500
# Observación [-0.53462017  0.00491157]
# Accion 1510
# Observación [-0.48096055  0.00604426]
# Accion 1520
# Observación [-0.47336832 -0.00286038]
# Accion 1530
# Observación [-0.510837   -0.00450632]
# Accion 1540
# Observación [-0.55503035 -0.00506003]
# Accion 1550
# Observación [-0.60238934 -0.00402923]
# Accion 1560
# Observación [-0.59484476  0.00184096]
# Accion 1570
# Observación [-0.55626315  0.00618193]
# Accion 1580
# Observación [-0.5024049   0.00587091]
# Accion 1590
# Observación [-0.4707445   0.00417926]
# Accion 1600
# Observación [-0.44480345 -0.00086141]
# Accion 1610
# Observación [-0.5014248  -0.00935795]
# Accion 1620
# Observación [-0.587026   -0.00701703]
# Accion 1630
# Observación [-0.5920679   0.00356743]
# Accion 1640
# Observación [-0.5431563  0.0052392]
# Accion 1650
# Observación [-0.4553443   0.00997746]
# Accion 1660
# Observación [-0.38925785  0.00219149]
# Accion 1670
# Observación [-0.41721427 -0.00635804]
# Accion 1680
# Observación [-0.49897745 -0.00969475]
# Accion 1690
# Observación [-0.59257704 -0.0071757 ]
# Accion 1700
# Observación [-0.6382138  -0.00228694]
# Accion 1710
# Observación [-0.6166842   0.00596668]
# Accion 1720
# Observación [-0.5456186   0.00876325]
# Accion 1730
# Observación [-0.47787744  0.00703762]
# Accion 1740
# Observación [-0.4280922   0.00262629]
# Accion 1750
# Observación [-0.44445807 -0.00322221]
# Accion 1760
# Observación [-0.50623214 -0.00737447]
# Accion 1770
# Observación [-0.56921506 -0.0063639 ]
# Accion 1780
# Observación [-0.6127915  -0.00228622]
# Accion 1790
# Observación [-0.61493826  0.00161628]
# Accion 1800
# Observación [-0.5705121   0.00618234]
# Accion 1810
# Observación [-0.4934919  0.0069702]
# Accion 1820
# Observación [-0.44966564  0.00081803]
# Accion 1830
# Observación [-0.49389723 -0.00993129]
# Accion 1840
# Observación [-0.60520077 -0.01147834]
# Accion 1850
# Observación [-6.6201240e-01  1.8372676e-04]
# Accion 1860
# Observación [-0.6080225   0.00794035]
# ...
# Accion 6790
# Observación [-0.19561814 -0.00690184]
# Accion 6800
# Observación [-0.33771205 -0.0191233 ]
# Accion 6810
# Observación [-0.6081664  -0.03042409]
# Accion 6820
# Observación [-0.835079   -0.01775651]
# Accion 6830
# Observación [-0.89646417  0.00312473]
# Accion 6840
# Observación [-0.77447814  0.02000629]
# Accion 6850
# Observación [-0.5120284  0.0301885]
# Accion 6860
# Observación [-0.2745482   0.01685646]
# Accion 6870
# Observación [-0.206821  -0.0003942]
# Accion 6880
# Observación [-0.30824307 -0.01925345]
# Accion 6890
# Observación [-0.580721   -0.03054841]
# Accion 6900
# Observación [-0.80044734 -0.01351643]
# Accion 6910
# Observación [-0.8073434   0.00792638]
# Accion 6920
# Observación [-0.65685266  0.01939389]
# Accion 6930
# Observación [-0.4422137   0.02121706]
# Accion 6940
# Observación [-0.28697577  0.00758169]
# Accion 6950
# Observación [-0.27538547 -0.00351162]
# Accion 6960
# Observación [-0.39579707 -0.02000773]
# Accion 6970
# Observación [-0.58793706 -0.01574497]
# Accion 6980
# Observación [-0.7190043  -0.00942233]
# Accion 6990
# Observación [-7.4847895e-01  7.2549441e-04]
# Accion 7000
# Observación [-0.6576107   0.01338914]
# Accion 7010
# Observación [-0.49815524  0.01607511]
# Accion 7020
# Observación [-0.35657197  0.00898242]
# Accion 7030
# Observación [-0.36121947 -0.00667291]
# Accion 7040
# Observación [-0.486667   -0.01717348]
# Accion 7050
# Observación [-0.63991517 -0.01260267]
# Accion 7060
# Observación [-0.71538174 -0.00214268]
# Accion 7070
# Observación [-0.67609036  0.00891722]
# Accion 7080
# Observación [-0.5533029   0.01547667]
# Accion 7090
# Observación [-0.3904356   0.01503155]
# Accion 7100
# Observación [-0.3136482   0.00129782]
# Accion 7110
# Observación [-0.37933064 -0.01224801]
# Accion 7120
# Observación [-0.5488366  -0.01746367]
# Accion 7130
# Observación [-0.7159723  -0.01169147]
# Accion 7140
# Observación [-0.73496735  0.00526031]
# Accion 7150
# Observación [-0.62605494  0.01640297]
# Accion 7160
# Observación [-0.4091072  0.0232562]
# Accion 7170
# Observación [-0.24157444  0.01126248]
# Accion 7180
# Observación [-0.244226   -0.00928685]
# Accion 7190
# Observación [-0.42753986 -0.02272208]
# Accion 7200
# Observación [-0.6864455  -0.02420258]
# Accion 7210
# Observación [-0.8240354  -0.00376438]
# Accion 7220
# Observación [-0.74728566  0.0148586 ]
# Accion 7230
# Observación [-0.5282951   0.02653984]
# Accion 7240
# Observación [-0.2883278   0.01960257]
# Accion 7250
# Observación [-0.19297832 -0.00065556]
# Accion 7260
# Observación [-0.31508186 -0.02175136]
# Accion 7270
# Observación [-0.6128111  -0.03371888]
# Accion 7280
# Observación [-0.8816482  -0.01763907]
# Accion 7290
# Observación [-0.9392221   0.00370471]
# Accion 7300
# Observación [-0.77070343  0.0244309 ]
# Accion 7310
# Observación [-0.47540265  0.0309989 ]
# Accion 7320
# Observación [-0.21983795  0.01872328]
# Accion 7330
# Observación [-0.16668734 -0.00375255]
# Accion 7340
# Observación [-0.3232929  -0.02427508]
# Accion 7350
# Observación [-0.6201579  -0.02941092]
# Accion 7360
# Observación [-0.8461164  -0.01606913]
# Accion 7370
# Observación [-0.88644797  0.00491148]
# Accion 7380
# Observación [-0.7401527   0.02292158]
# Accion 7390
# Observación [-0.46356425  0.02767059]
# Accion 7400
# Observación [-0.24234362  0.01570797]
# Accion 7410
# Observación [-0.19563648 -0.00474435]
# Accion 7420
# Observación [-0.35313037 -0.02487087]
# Accion 7430
# Observación [-0.6883479  -0.03694595]
# Accion 7440
# Observación [-0.9413082  -0.01404424]
# Accion 7450
# Observación [-0.9617735   0.00721989]
# Accion 7460
# Observación [-0.75440794  0.03009911]
# Accion 7470
# Observación [-0.42844835  0.03223976]
# Accion 7480
# Observación [-0.16677837  0.01579973]
# Accion 7490
# Observación [-0.11307743 -0.00645584]
# Accion 7500
# Observación [-0.29134196 -0.02576898]
# Accion 7510
# Observación [-0.5966919  -0.03183484]
# Accion 7520
# Observación [-0.8312431  -0.01447455]
# Accion 7530
# Observación [-0.8424155   0.01051324]
# Accion 7540
# Observación [-0.6256332   0.02947546]
# Accion 7550
# Observación [-0.29282266  0.03097367]
# Accion 7560
# Observación [-0.08516867  0.01000544]
# Accion 7570
# Observación [-0.11305816 -0.01430627]
# Accion 7580
# Observación [-0.38713712 -0.03351172]
# Accion 7590
# Observación [-0.75574106 -0.03436039]
# Accion 7600
# Observación [-1.0019943  -0.01589824]
# Accion 7610
# Observación [-1.0228565   0.01105921]
# Accion 7620
# Observación [-0.81230104  0.02951074]
# Accion 7630
# Observación [-0.44409886  0.04073031]
# Accion 7640
# Observación [-0.10264636  0.0255949 ]
# Accion 7650
# Observación [-0.0079078  -0.00315059]
# Accion 7660
# Observación [-0.19889562 -0.03131701]
# Accion 7670
# Observación [-0.58699566 -0.0422895 ]
# Accion 7680
# Observación [-0.94358087 -0.02676834]
# Accion 7690
# Observación [-1.0950382  -0.00305665]
# Accion 7700
# Observación [-0.9912099   0.02278838]
# Accion 7710
# Observación [-0.63379467  0.04346576]
# Accion 7720
# Observación [-0.20136803  0.0382054 ]
# Accion 7730
# Observación [0.05110223 0.01335206]
# Accion 7740
# Observación [ 0.04720422 -0.01306566]
# Accion 7750
# Observación [-0.20504883 -0.03628862]
# Accion 7760
# Observación [-0.658164   -0.04868813]
# Accion 7770
# Observación [-1.0363704  -0.02819197]
# Accion 7780
# Observación [-1.1733176  -0.00396084]
# Accion 7790
# Observación [-1.1065754   0.01657517]
# Accion 7800
# Observación [-0.8267893   0.03762633]
# Accion 7810
# Observación [-0.39165494  0.04433348]
# Accion 7820
# Observación [-0.02648512  0.02724869]
# Accion 7830
# Observación [0.13663541 0.00796302]
# Accion 7840
# Observación [ 0.07521205 -0.01516851]
# Accion 7850
# Observación [-0.21047573 -0.03934008]
# Accion 7860
# Observación [-0.67512625 -0.04559901]
# Accion 7870
# Observación [-1.0326726  -0.02576956]
# Accion 7880
# Observación [-1.1894743  -0.00661007]
# Accion 7890
# Observación [-1.1114966   0.01658537]
# Accion 7900
# Observación [-0.7883964  0.0432942]
# Accion 7910
# Observación [-0.29986626  0.04635408]
# Accion 7920
# Observación [0.06842783 0.02708853]
# Accion 7930
# Observación [ 0.18593828 -0.0004931 ]
# Accion 7940
# Observación [ 0.05006997 -0.02502997]
# Accion 7950
# Observación [-0.33359942 -0.04655773]
# Accion 7960
# Observación [-0.8085609  -0.04358154]
# Accion 7970
# Observación [-1.1326903  -0.02220424]
# Accion 7980
# Observación [-1.1610413   0.01139019]
# Accion 7990
# Observación [-0.9245483  0.0338258]
# Accion 8000
# Observación [-0.5115647   0.04443973]
# Accion 8010
# Observación [-0.13204044  0.03026416]
# Accion 8020
# Observación [0.05001076 0.00672929]
# Accion 8030
# Observación [-0.02973265 -0.02006489]
# Accion 8040
# Observación [-0.37014216 -0.0410976 ]
# Accion 8050
# Observación [-0.81752104 -0.04059063]
# Accion 8060
# Observación [-1.1050192  -0.01711061]
# Accion 8070
# Observación [-1.1567538  0.004759 ]
# Accion 8080
# Observación [-0.99399966  0.02620826]
# Accion 8090
# Observación [-0.6324329   0.04183473]
# Accion 8100
# Observación [-0.2276633   0.03630379]
# Accion 8110
# Observación [0.01967419 0.01393119]
# Accion 8120
# Observación [ 0.01242273 -0.01389057]
# Accion 8130
# Observación [-0.24065848 -0.03455456]
# Accion 8140
# Observación [-0.64966047 -0.04182107]
# Accion 8150
# Observación [-0.98673475 -0.02649664]
# Accion 8160
# Observación [-1.1081762e+00  2.9089564e-04]
# Accion 8170
# Observación [-0.967044    0.02610105]
# Accion 8180
# Observación [-0.58222336  0.04400748]
# Accion 8190
# Observación [-0.16665033  0.03577181]
# Accion 8200
# Observación [0.08191022 0.01355162]
# Accion 8210
# Observación [ 0.10686861 -0.00706418]
# Accion 8220
# Observación [-0.08658306 -0.02858182]
# Accion 8230
# Observación [-0.49969038 -0.04748274]
# Accion 8240
# Observación [-0.9470087  -0.03700925]
# Accion 8250
# Observación [-1.1631724  -0.00856641]
# Accion 8260
# Observación [-1.1315325   0.01184233]
# Accion 8270
# Observación [-0.89378214  0.0343625 ]
# Accion 8280
# Observación [-0.45968327  0.04541818]
# Accion 8290
# Observación [-0.05712657  0.03195881]
# Accion 8300
# Observación [0.13101241 0.00760393]
# Accion 8310
# Observación [ 0.08848806 -0.01354499]
# Accion 8320
# Observación [-0.19087197 -0.03985853]
# Accion 8330
# Observación [-0.6546173  -0.04771632]
# Accion 8340
# Observación [-1.0376348  -0.02942577]
# Accion 8350
# Observación [-1.190388  -0.0053549]
# Accion 8360
# Observación [-1.1190114   0.01778235]
# Accion 8370
# Observación [-0.8016722   0.04366066]
# Accion 8380
# Observación [-0.31128705  0.04990399]
# Accion 8390
# Observación [0.06932285 0.02885866]
# Accion 8400
# Observación [0.21235271 0.0017789 ]
# Accion 8410
# Observación [ 0.08628719 -0.02273248]
# Accion 8420
# Observación [-0.27171332 -0.04734641]
# Accion 8430
# Observación [-0.77257675 -0.04712816]
# Accion 8440
# Observación [-1.1449691 -0.0283203]
# Accion 8450
# Observación [-1.1505412   0.01398602]
# Accion 8460
# Observación [-0.87240297  0.03731168]
# Accion 8470
# Observación [-0.45226792  0.0423683 ]
# Accion 8480
# Observación [-0.08448534  0.0292311 ]
# Accion 8490
# Observación [0.06380989 0.00347584]
# Accion 8500
# Observación [-0.03922611 -0.01930282]
# Accion 8510
# Observación [-0.36135626 -0.04051378]
# Accion 8520
# Observación [-0.78236717 -0.0384225 ]
# Accion 8530
# Observación [-1.0489496  -0.01583316]
# Accion 8540
# Observación [-1.0663253   0.00904663]
# Accion 8550
# Observación [-0.856021    0.03132502]
# Accion 8560
# Observación [-0.45405763  0.04329145]
# Accion 8570
# Observación [-0.10806502  0.02440248]
# Accion 8580
# Observación [0.0111554 0.0007056]
# Accion 8590
# Observación [-0.11684269 -0.02307828]
# Accion 8600
# Observación [-0.46207812 -0.04114244]
# Accion 8610
# Observación [-0.83569163 -0.02988623]
# Accion 8620
# Observación [-0.9786284  -0.00286299]
# Accion 8630
# Observación [-0.8760077   0.02105429]
# Accion 8640
# Observación [-0.55855274  0.0369174 ]
# Accion 8650
# Observación [-0.20626906  0.02982381]
# Accion 8660
# Observación [-0.04514803  0.00556698]
# Accion 8670
# Observación [-0.13127594 -0.02095298]
# Accion 8680
# Observación [-0.44854587 -0.03808134]
# Accion 8690
# Observación [-0.8010114  -0.03068877]
# Accion 8700
# Observación [-0.9996623  -0.00818791]
# Accion 8710
# Observación [-0.95026535  0.01752424]
# Accion 8720
# Observación [-0.6689493   0.03517907]
# Accion 8730
# Observación [-0.2918659   0.03421921]
# Accion 8740
# Observación [-0.08146366  0.01214913]
# Accion 8750
# Observación [-0.10650969 -0.01428194]
# Accion 8760
# Observación [-0.371129   -0.03295988]
# Accion 8770
# Observación [-0.70033956 -0.02900624]
# Accion 8780
# Observación [-0.8954318  -0.01071336]
# Accion 8790
# Observación [-0.8655007   0.01394663]
# Accion 8800
# Observación [-0.6407633   0.02773807]
# Accion 8810
# Observación [-0.36210245  0.02262718]
# Accion 8820
# Observación [-0.22449303  0.00533243]
# Accion 8830
# Observación [-0.31985512 -0.02003321]
# Accion 8840
# Observación [-0.58721644 -0.0286227 ]
# Accion 8850
# Observación [-0.816273   -0.01628547]
# Accion 8860
# Observación [-0.8694044   0.00259786]
# Accion 8870
# Observación [-0.7196284   0.02491119]
# Accion 8880
# Observación [-0.44860253  0.02631448]
# Accion 8890
# Observación [-0.2407953   0.01260181]
# Accion 8900
# Observación [-0.23075289 -0.00815849]
# Accion 8910
# Observación [-0.4314438  -0.02938621]
# Accion 8920
# Observación [-0.7285046  -0.02832749]
# Accion 8930
# Observación [-0.9235802  -0.00969537]
# Accion 8940
# Observación [-0.9030843   0.01079363]
# Accion 8950
# Observación [-0.6941778   0.03012219]
# Accion 8960
# Observación [-0.39902738  0.02664259]
# Accion 8970
# Observación [-0.19513176  0.01304411]
# Accion 8980
# Observación [-0.18114594 -0.00663151]
# Accion 8990
# Observación [-0.35594982 -0.02489001]
# Accion 9000
# Observación [-0.6444009  -0.02776051]
# Accion 9010
# Observación [-0.85488915 -0.01418917]
# Accion 9020
# Observación [-0.9057258  0.0031344]
# Accion 9030
# Observación [-0.73402095  0.02659805]
# Accion 9040
# Observación [-0.42020166  0.03171544]
# Accion 9050
# Observación [-0.20105775  0.01172769]
# Accion 9060
# Observación [-0.18101439 -0.00474844]
# Accion 9070
# Observación [-0.32699472 -0.02285245]
# Accion 9080
# Observación [-0.6298544  -0.03263839]
# Accion 9090
# Observación [-0.89620423 -0.01866838]
# Accion 9100
# Observación [-0.95488524  0.00303904]
# Accion 9110
# Observación [-0.7856322  0.0272998]
# Accion 9120
# Observación [-0.4434512   0.03644177]
# Accion 9130
# Observación [-0.17096435  0.01756234]
# Accion 9140
# Observación [-0.09159841 -0.00077082]
# Accion 9150
# Observación [-0.23882163 -0.02550052]
# Accion 9160
# Observación [-0.5399275  -0.03114885]
# Accion 9170
# Observación [-0.7957554  -0.02129393]
# Accion 9180
# Observación [-0.90254956 -0.00118424]
# Accion 9190
# Observación [-0.7957792   0.02037127]
# Accion 9200
# Observación [-0.53479433  0.03091285]
# Accion 9210
# Observación [-0.25208294  0.02098159]
# Accion 9220
# Observación [-0.17915995 -0.00152883]
# Accion 9230
# Observación [-0.30979025 -0.02007297]
# Accion 9240
# Observación [-0.59127545 -0.03205998]
# Accion 9250
# Observación [-0.8663717 -0.0212987]
# Accion 9260
# Observación [-0.9294696   0.00474629]
# Accion 9270
# Observación [-0.7612726   0.02613374]
# Accion 9280
# Observación [-0.40878358  0.03844344]
# Accion 9290
# Observación [-0.0996086   0.02217887]
# Accion 9300
# Observación [-0.01191753 -0.00154241]
# Accion 9310
# Observación [-0.17412125 -0.0268691 ]
# Accion 9320
# Observación [-0.5488123 -0.0428078]
# Accion 9330
# Observación [-0.90595114 -0.02525077]
# Accion 9340
# Observación [-1.0532521  -0.00587111]
# Accion 9350
# Observación [-1.010543    0.01511201]
# Accion 9360
# Observación [-0.71646094  0.03893704]
# Accion 9370
# Observación [-0.28992438  0.03899567]
# Accion 9380
# Observación [0.00194528 0.01999881]
# Accion 9390
# Observación [ 0.05450968 -0.00572241]
# Accion 9400
# Observación [-0.16387747 -0.0342775 ]
# Accion 9410
# Observación [-0.6042326  -0.04889597]
# Accion 9420
# Observación [-1.0409086  -0.03413682]
# Accion 9430
# Observación [-1.1855023   0.00676141]
# Accion 9440
# Observación [-0.9707891   0.03096101]
# Accion 9450
# Observación [-0.54840684  0.04791228]
# Accion 9460
# Observación [-0.12550426  0.03416447]
# Accion 9470
# Observación [0.06200001 0.00658924]
# Accion 9480
# Observación [-0.01041812 -0.01809774]
# Accion 9490
# Observación [-0.3476279  -0.04505223]
# Accion 9500
# Observación [-0.84121996 -0.04798525]
# Accion 9510
# Observación [-1.2  0. ]
# Accion 9520
# Observación [-1.0387366   0.02860003]
# Accion 9530
# Observación [-0.63402367  0.04907671]
# Accion 9540
# Observación [-0.18378203  0.03686865]
# Accion 9550
# Observación [0.08333124 0.01782075]
# Accion 9560
# Observación [ 0.1478609  -0.00128641]
# Accion 9570
# Observación [ 0.01737513 -0.02388576]
# Accion 9580
# Observación [-0.3714973 -0.0485888]
# Accion 9590
# Observación [-0.8818099  -0.04611215]
# Accion 9600
# Observación [-1.1977581  0.0022419]
# Accion 9610
# Observación [-1.0433965   0.02494525]
# Accion 9620
# Observación [-0.6342954   0.05162182]
# Accion 9630
# Observación [-0.13489561  0.04248626]
# Accion 9640
# Observación [0.14168827 0.01528787]
# Accion 9650
# Observación [ 0.15355262 -0.00958933]
# Accion 9660
# Observación [-0.09011251 -0.03662078]
# Accion 9670
# Observación [-0.54527956 -0.04880415]
# Accion 9680
# Observación [-0.98122597 -0.03697309]
# Accion 9690
# Observación [-1.1796274  -0.00762772]
# Accion 9700
# Observación [-1.129714    0.01447809]
# Accion 9710
# Observación [-0.8331159   0.04163926]
# Accion 9720
# Observación [-0.3607617   0.04635946]
# Accion 9730
# Observación [0.01594244 0.02899972]
# Accion 9740
# Observación [0.18641806 0.00572358]
# Accion 9750
# Observación [ 0.1412197 -0.0116642]
# Accion 9760
# Observación [-0.11372191 -0.03685739]
# Accion 9770
# Observación [-0.5749515  -0.05062846]
# Accion 9780
# Observación [-0.98899764 -0.03146141]
# Accion 9790
# Observación [-1.1699235  -0.00701855]
# Accion 9800
# Observación [-1.1302283   0.01234457]
# Accion 9810
# Observación [-0.85967433  0.03970837]
# Accion 9820
# Observación [-0.39562342  0.04771883]
# Accion 9830
# Observación [-0.01781393  0.0275546 ]
# Accion 9840
# Observación [0.1458675 0.0074127]
# Accion 9850
# Observación [ 0.09776717 -0.01334392]
# Accion 9860
# Observación [-0.18418667 -0.03864526]
# Accion 9870
# Observación [-0.6592963  -0.04849327]
# Accion 9880
# Observación [-1.0551561  -0.03189795]
# Accion 9890
# Observación [-1.1724406   0.01105846]
# Accion 9900
# Observación [-0.9151301  0.0383811]
# Accion 9910
# Observación [-0.47844303  0.04553678]
# Accion 9920
# Observación [-0.08290683  0.03118127]
# Accion 9930
# Observación [0.08702722 0.00551205]
# Accion 9940
# Observación [ 0.00210656 -0.02282386]
# Accion 9950
# Observación [-0.3730803  -0.04729997]
# Accion 9960
# Observación [-0.85843843 -0.04218397]
# Accion 9970
# Observación [-1.161779   -0.02121381]
# Accion 9980
# Observación [-1.1293416   0.01709324]
# Accion 9990
# Observación [-0.81197727  0.04204997]

# %%
gym.__version__
# Out:
# '1.3.0'
