# %% [markdown]
# ### Pyspark Handling Missing Values
# - Eliminar columnas
# - Eliminar Filas
# - Parámetros para el Dropping
# - Imputar valores nulos con la media, la mediana y la moda

# %% [markdown]
# #### CREAMOS LA SESIÓN

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('Practise').getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[21], line 2
#       1 from pyspark.sql import SparkSession
# ----> 2 spark = SparkSession.builder.appName('Practise').getOrCreate()
#
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\sql\session.py:562, in SparkSession.Builder.getOrCreate(self)
#     560     session = SparkSession(sc, options=self._options)
#     561 else:
# --> 562     module = SparkSession._get_j_spark_session_module(session._jvm)
#     563     module.applyModifiableSettings(session._jsparkSession, self._options)
#     564 return session
#
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\sql\session.py:673, in SparkSession._get_j_spark_session_module(jvm)
#     671 @staticmethod
#     672 def _get_j_spark_session_module(jvm: "JVMView") -> "JavaObject":
# --> 673     return getattr(getattr(jvm, "org.apache.spark.sql.classic.SparkSession$"), "MODULE$")
#
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\java_gateway.py:1752, in JVMView.__getattr__(self, name)
#    1749 if name == UserHelpAutoCompletion.KEY:
#    1750     return UserHelpAutoCompletion()
# -> 1752 answer = self._gateway_client.send_command(
#    1753     proto.REFLECTION_COMMAND_NAME +
#    1754     proto.REFL_GET_UNKNOWN_SUB_COMMAND_NAME + name + "\n" + self._id +
#    1755     "\n" + proto.END_COMMAND_PART)
#    1756 if answer == proto.SUCCESS_PACKAGE:
#    1757     return JavaPackage(name, self._gateway_client, jvm_id=self._id)
#
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\java_gateway.py:1036, in GatewayClient.send_command(self, command, retry, binary)
#    1015 def send_command(self, command, retry=True, binary=False):
#    1016     """Sends a command to the JVM. This method is not intended to be
#    1017        called directly by Py4J users. It is usually called by
#    1018        :class:`JavaMember` instances.
#    (...)
#    1034      if `binary` is `True`.
#    1035     """
# -> 1036     connection = self._get_connection()
#    1037     try:
#    1038         response = connection.send_command(command)
#
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\clientserver.py:284, in JavaClient._get_connection(self)
#     281     pass
#     283 if connection is None or connection.socket is None:
# --> 284     connection = self._create_new_connection()
#     285 return connection
#
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\clientserver.py:291, in JavaClient._create_new_connection(self)
#     287 def _create_new_connection(self):
#     288     connection = ClientServerConnection(
#     289         self.java_parameters, self.python_parameters,
#     290         self.gateway_property, self)
# --> 291     connection.connect_to_java_server()
#     292     self.set_thread_connection(connection)
#     293     return connection
#
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\clientserver.py:438, in ClientServerConnection.connect_to_java_server(self)
#     435 if self.ssl_context:
#     436     self.socket = self.ssl_context.wrap_socket(
#     437         self.socket, server_hostname=self.java_address)
# --> 438 self.socket.connect((self.java_address, self.java_port))
#     439 self.stream = self.socket.makefile("rb")
#     440 self.is_connected = True
#
# ConnectionRefusedError: [WinError 10061] No se puede establecer una conexión ya que el equipo de destino denegó expresamente dicha conexión

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://LAPTOP-2VAG1POF:4042">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practise</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# #### CARGAMOS EL DATAFRAME

# %%
df_pyspark = spark.read.csv('data/test2.csv', header=True, inferSchema=True)
df_pyspark.show()
# Out:
# +---------+----+----------+------+
# |     Name| age|Experience|Salary|
# +---------+----+----------+------+
# |    Krish|  31|        10| 30000|
# |Sudhanshu|  30|         8| 25000|
# |    Sunny|  29|         4| 20000|
# |     Paul|  24|         3| 20000|
# |   Harsha|  21|         1| 15000|
# |  Shubham|  23|         2| 18000|
# |   Mahesh|NULL|      NULL| 40000|
# |     NULL|  34|        10| 38000|
# |     NULL|  36|      NULL|  NULL|
# +---------+----+----------+------+

# %%
df_pyspark.show()
# Out:
# +---------+----+----------+------+
# |     Name| age|Experience|Salary|
# +---------+----+----------+------+
# |    Krish|  31|        10| 30000|
# |Sudhanshu|  30|         8| 25000|
# |    Sunny|  29|         4| 20000|
# |     Paul|  24|         3| 20000|
# |   Harsha|  21|         1| 15000|
# |  Shubham|  23|         2| 18000|
# |   Mahesh|NULL|      NULL| 40000|
# |     NULL|  34|        10| 38000|
# |     NULL|  36|      NULL|  NULL|
# +---------+----+----------+------+

# %%
df_pyspark_2 = df_pyspark.na.drop()
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\clientserver.py:527, in ClientServerConnection.send_command(self, command)
#     526 try:
# --> 527     self.socket.sendall(command.encode("utf-8"))
#     528 except Exception as e:
#
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
#
# During handling of the above exception, another exception occurred:
#
# Py4JNetworkError                          Traceback (most recent call last)
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\java_gateway.py:1038, in GatewayClient.send_command(self, command, retry, binary)
#    1037 try:
# -> 1038     response = connection.send_command(command)
#    1039     if binary:
#
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\clientserver.py:530, in ClientServerConnection.send_command(self, command)
#     529     logger.info("Error while sending or receiving.", exc_info=True)
# --> 530     raise Py4JNetworkError(
#     531         "Error while sending", e, proto.ERROR_ON_SEND)
#     533 try:
#
# Py4JNetworkError: Error while sending
#
# During handling of the above exception, another exception occurred:
#
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df_pyspark_2 = df_pyspark.na.drop()
#
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\sql\classic\dataframe.py:1859, in DataFrameNaFunctions.drop(self, how, thresh, subset)
#    1853 def drop(
#    1854     self,
#    1855     how: str = "any",
#    1856     thresh: Optional[int] = None,
#    1857     subset: Optional[Union[str, Tuple[str, ...], List[str]]] = None,
#    1858 ) -> ParentDataFrame:
# -> 1859     return self.df.dropna(how=how, thresh=thresh, subset=subset)
#
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\sql\classic\dataframe.py:1254, in DataFrame.dropna(self, how, thresh, subset)
#    1251 if thresh is None:
#    1252     thresh = len(subset) if how == "any" else 1
# -> 1254 return DataFrame(self._jdf.na().drop(thresh, self._jseq(subset)), self.sparkSession)
#
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\java_gateway.py:1361, in JavaMember.__call__(self, *args)
#    1354 args_command, temp_args = self._build_args(*args)
#    1356 command = proto.CALL_COMMAND_NAME +\
#    1357     self.command_header +\
#    1358     args_command +\
#    1359     proto.END_COMMAND_PART
# -> 1361 answer = self.gateway_client.send_command(command)
#    1362 return_value = get_return_value(
#    1363     answer, self.gateway_client, self.target_id, self.name)
#    1365 for temp_arg in temp_args:
#
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\java_gateway.py:1057, in GatewayClient.send_command(self, command, retry, binary)
#    1055         retry = False
#    1056     logging.info("Exception while sending command.", exc_info=True)
# -> 1057     response = self.send_command(command, retry, binary=binary)
#    1058 else:
#    1059     logging.exception(
#    1060         "Exception while sending command.")
#
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\java_gateway.py:1036, in GatewayClient.send_command(self, command, retry, binary)
#    1015 def send_command(self, command, retry=True, binary=False):
#    1016     """Sends a command to the JVM. This method is not intended to be
#    1017        called directly by Py4J users. It is usually called by
#    1018        :class:`JavaMember` instances.
#    (...)
#    1034      if `binary` is `True`.
#    1035     """
# -> 1036     connection = self._get_connection()
#    1037     try:
#    1038         response = connection.send_command(command)
#
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\clientserver.py:284, in JavaClient._get_connection(self)
#     281     pass
#     283 if connection is None or connection.socket is None:
# --> 284     connection = self._create_new_connection()
#     285 return connection
#
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\clientserver.py:291, in JavaClient._create_new_connection(self)
#     287 def _create_new_connection(self):
#     288     connection = ClientServerConnection(
#     289         self.java_parameters, self.python_parameters,
#     290         self.gateway_property, self)
# --> 291     connection.connect_to_java_server()
#     292     self.set_thread_connection(connection)
#     293     return connection
#
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\clientserver.py:438, in ClientServerConnection.connect_to_java_server(self)
#     435 if self.ssl_context:
#     436     self.socket = self.ssl_context.wrap_socket(
#     437         self.socket, server_hostname=self.java_address)
# --> 438 self.socket.connect((self.java_address, self.java_port))
#     439 self.stream = self.socket.makefile("rb")
#     440 self.is_connected = True
#
# ConnectionRefusedError: [WinError 10061] No se puede establecer una conexión ya que el equipo de destino denegó expresamente dicha conexión

# %%
df_pyspark_2.show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %% [markdown]
# La función drop() tiene varios parámetros, entre ellos "how", con valores "any" y "all".
# - how = 'any' elimina la columna si uno de los valores es nulo (any por defecto)
# - how = 'all' elimina la columna si todos los valores son nulos
#
# Otro parámetro es "thresh". Por ejemplo: thresh = 2, significa que se mantienen las filas con al menos 2 valores NO NULOS.

# %%
df_pyspark.na.drop(how = 'any', thresh = 2).show()
# Out:
# +---------+----+----------+------+
# |     Name| age|Experience|Salary|
# +---------+----+----------+------+
# |    Krish|  31|        10| 30000|
# |Sudhanshu|  30|         8| 25000|
# |    Sunny|  29|         4| 20000|
# |     Paul|  24|         3| 20000|
# |   Harsha|  21|         1| 15000|
# |  Shubham|  23|         2| 18000|
# |   Mahesh|NULL|      NULL| 40000|
# |     NULL|  34|        10| 38000|
# +---------+----+----------+------+

# %%
df_pyspark.na.drop(how = 'any', thresh = 3).show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# |     NULL| 34|        10| 38000|
# +---------+---+----------+------+

# %%
df_pyspark.na.drop(how = 'any', thresh = 1).show()
# Out:
# +---------+----+----------+------+
# |     Name| age|Experience|Salary|
# +---------+----+----------+------+
# |    Krish|  31|        10| 30000|
# |Sudhanshu|  30|         8| 25000|
# |    Sunny|  29|         4| 20000|
# |     Paul|  24|         3| 20000|
# |   Harsha|  21|         1| 15000|
# |  Shubham|  23|         2| 18000|
# |   Mahesh|NULL|      NULL| 40000|
# |     NULL|  34|        10| 38000|
# |     NULL|  36|      NULL|  NULL|
# +---------+----+----------+------+

# %%
df_pyspark.show()
# Out:
# +---------+----+----------+------+
# |     Name| age|Experience|Salary|
# +---------+----+----------+------+
# |    Krish|  31|        10| 30000|
# |Sudhanshu|  30|         8| 25000|
# |    Sunny|  29|         4| 20000|
# |     Paul|  24|         3| 20000|
# |   Harsha|  21|         1| 15000|
# |  Shubham|  23|         2| 18000|
# |   Mahesh|NULL|      NULL| 40000|
# |     NULL|  34|        10| 38000|
# |     NULL|  36|      NULL|  NULL|
# +---------+----+----------+------+

# %% [markdown]
# El último parámetro es "subset". Con este, podemos decirle que elimine las columnas con valores nulos en una columna determinada.

# %%
df_pyspark.na.drop(how = 'any', subset = ['Experience']).show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# |     NULL| 34|        10| 38000|
# +---------+---+----------+------+

# %% [markdown]
# RELLENAR MISSING VALUES

# %%
df_pyspark.show()
# Out:
# +---------+----+----------+------+
# |     Name| age|Experience|Salary|
# +---------+----+----------+------+
# |    Krish|  31|        10| 30000|
# |Sudhanshu|  30|         8| 25000|
# |    Sunny|  29|         4| 20000|
# |     Paul|  24|         3| 20000|
# |   Harsha|  21|         1| 15000|
# |  Shubham|  23|         2| 18000|
# |   Mahesh|NULL|      NULL| 40000|
# |     NULL|  34|        10| 38000|
# |     NULL|  36|      NULL|  NULL|
# +---------+----+----------+------+

# %%
df_pyspark.na.fill('Missing Value').show() 

# también se podría poner df_pyspark.fillna().
# Solo rellenará las columnas que comparten el tipo de valor. Si lo que queremos introducir es un string, solo lo sustituirá en aquellas
# columnas que sean string. Esto es igual con las columnas numéricas.
# Out:
# +-------------+----+----------+------+
# |         Name| age|Experience|Salary|
# +-------------+----+----------+------+
# |        Krish|  31|        10| 30000|
# |    Sudhanshu|  30|         8| 25000|
# |        Sunny|  29|         4| 20000|
# |         Paul|  24|         3| 20000|
# |       Harsha|  21|         1| 15000|
# |      Shubham|  23|         2| 18000|
# |       Mahesh|NULL|      NULL| 40000|
# |Missing Value|  34|        10| 38000|
# |Missing Value|  36|      NULL|  NULL|
# +-------------+----+----------+------+

# %%
# Distintos tipos en las columnas seleccionadas.

df_pyspark.na.fill({'Name':'Missing Value', 'Experience':10}).show()
# Out:
# +-------------+----+----------+------+
# |         Name| age|Experience|Salary|
# +-------------+----+----------+------+
# |        Krish|  31|        10| 30000|
# |    Sudhanshu|  30|         8| 25000|
# |        Sunny|  29|         4| 20000|
# |         Paul|  24|         3| 20000|
# |       Harsha|  21|         1| 15000|
# |      Shubham|  23|         2| 18000|
# |       Mahesh|NULL|        10| 40000|
# |Missing Value|  34|        10| 38000|
# |Missing Value|  36|        10|  NULL|
# +-------------+----+----------+------+

# %% [markdown]
# #### IMPUTAR VALORES

# %% [markdown]
# Podemos sustituir los valores por el valor medio, mediana... de la siguiente forma:

# %%
from pyspark.ml.feature import Imputer

# %%
imputer_mean = Imputer(inputCols=['age', 'Experience', 'Salary'],
                    outputCols = ['{}_imputed'.format(c) for c in ['age', 'Experience', 'Salary']]
                    ).setStrategy('mean')
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 imputer_mean = Imputer(inputCols=['age', 'Experience', 'Salary'],
#       2                     outputCols = ['{}_imputed'.format(c) for c in ['age', 'Experience', 'Salary']]
#       3                     ).setStrategy('mean')
#
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\__init__.py:115, in keyword_only.<locals>.wrapper(self, *args, **kwargs)
#     113     raise TypeError("Method %s forces keyword arguments." % func.__name__)
#     114 self._input_kwargs = kwargs
# --> 115 return func(self, **kwargs)
#
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\ml\feature.py:2156, in Imputer.__init__(self, strategy, missingValue, inputCols, outputCols, inputCol, outputCol, relativeError)
#    2151 """
#    2152 __init__(self, \\*, strategy="mean", missingValue=float("nan"), inputCols=None, \
#    2153          outputCols=None, inputCol=None, outputCol=None, relativeError=0.001):
#    2154 """
#    2155 super(Imputer, self).__init__()
# -> 2156 self._java_obj = self._new_java_obj("org.apache.spark.ml.feature.Imputer", self.uid)
#    2157 kwargs = self._input_kwargs
#    2158 self.setParams(**kwargs)
#
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\ml\util.py:396, in try_remote_return_java_class.<locals>.wrapped(java_class, *args)
#     394     return java_class
#     395 else:
# --> 396     return f(java_class, *args)
#
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\ml\wrapper.py:102, in JavaWrapper._new_java_obj(java_class, *args)
#     100 java_obj = _jvm()
#     101 for name in java_class.split("."):
# --> 102     java_obj = getattr(java_obj, name)
#     103 java_args = [_py2java(sc, arg) for arg in args]
#     104 return java_obj(*java_args)
#
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\java_gateway.py:1752, in JVMView.__getattr__(self, name)
#    1749 if name == UserHelpAutoCompletion.KEY:
#    1750     return UserHelpAutoCompletion()
# -> 1752 answer = self._gateway_client.send_command(
#    1753     proto.REFLECTION_COMMAND_NAME +
#    1754     proto.REFL_GET_UNKNOWN_SUB_COMMAND_NAME + name + "\n" + self._id +
#    1755     "\n" + proto.END_COMMAND_PART)
#    1756 if answer == proto.SUCCESS_PACKAGE:
#    1757     return JavaPackage(name, self._gateway_client, jvm_id=self._id)
#
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\java_gateway.py:1036, in GatewayClient.send_command(self, command, retry, binary)
#    1015 def send_command(self, command, retry=True, binary=False):
#    1016     """Sends a command to the JVM. This method is not intended to be
#    1017        called directly by Py4J users. It is usually called by
#    1018        :class:`JavaMember` instances.
#    (...)
#    1034      if `binary` is `True`.
#    1035     """
# -> 1036     connection = self._get_connection()
#    1037     try:
#    1038         response = connection.send_command(command)
#
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\clientserver.py:284, in JavaClient._get_connection(self)
#     281     pass
#     283 if connection is None or connection.socket is None:
# --> 284     connection = self._create_new_connection()
#     285 return connection
#
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\clientserver.py:291, in JavaClient._create_new_connection(self)
#     287 def _create_new_connection(self):
#     288     connection = ClientServerConnection(
#     289         self.java_parameters, self.python_parameters,
#     290         self.gateway_property, self)
# --> 291     connection.connect_to_java_server()
#     292     self.set_thread_connection(connection)
#     293     return connection
#
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\clientserver.py:438, in ClientServerConnection.connect_to_java_server(self)
#     435 if self.ssl_context:
#     436     self.socket = self.ssl_context.wrap_socket(
#     437         self.socket, server_hostname=self.java_address)
# --> 438 self.socket.connect((self.java_address, self.java_port))
#     439 self.stream = self.socket.makefile("rb")
#     440 self.is_connected = True
#
# ConnectionRefusedError: [WinError 10061] No se puede establecer una conexión ya que el equipo de destino denegó expresamente dicha conexión

# %%
imputer_mean.fit(df_pyspark).transform(df_pyspark).show()
