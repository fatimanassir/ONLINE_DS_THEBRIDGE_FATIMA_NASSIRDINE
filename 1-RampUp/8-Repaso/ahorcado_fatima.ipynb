# %% [markdown]
# ## Juego del Ahorcado
# El funcionamiento es que vaya mostrando por pantalla ```_ _ _ _ _``` las rayas bajas correspondientes al número de letras que tiene la palabra a adivinar. El usuario deberá insertar una letra y, si esa letra existe, se mostrará o mostrarán las letras acertadas ```S _ S _ _```.
#
# Si falla, se mostrará el número de errores que lleva y, si lleva 6 errores, entonces se mostrará "Fin del juego".
# Encapsúlalo en una función.

# %%
# definimos la palabra mediante funcion input.

palabra_clave = input("introduce una palabra").lower() # lo paso todo a menúsculas.
print(len(palabra_clave))


# creamos una lista "_"que representan las letras que contiene la palabra_clave.

lista_palabra_clave = ["_", "_", "_", "_", "_"]
print(lista_palabra_clave)


errore = 0
# Out:
# 5
# ['_', '_', '_', '_', '_']

# %%
#pedimos la letra al usuario. 

letra = input("introduce una letra: ").lower() # lo paso todo a menusculas por sea caso.
print(letra)
# Out:
# s

# %%
# ver si letra esta en la palabra_clave.

if letra in palabra_clave:
    print("la letra esta en la palabra")
else:
    print("la letra no esta")
# Out:
# la letra esta en la palabra

# %%
#actualizar mi lista lista_palabra_clave.
for i, caracter in enumerate(palabra_clave):
    if caracter in palabra_clave:
        lista_palabra_clave [i] = caracter
    print(lista_palabra_clave)
# Out:
# ['c', '_', '_', '_', '_']
# ['c', 'l', '_', '_', '_']
# ['c', 'l', 'a', '_', '_']
# ['c', 'l', 'a', 's', '_']
# ['c', 'l', 'a', 's', 'e']

# %%
# bucle while:

errores = 0
max_errores = 6
while errores > 6 and "_" in lista_palabra_clave:
    letra = input("introduce una letra: ").lower()
    
    for i, caracter in enumerate(palabra_clave):
        if caracter in palabra_clave:
        lista_palabra_clave [i] = caracter
    print(lista_palabra_clave)
    
    #bueno hasta aqui llego, no me da pa mas!
