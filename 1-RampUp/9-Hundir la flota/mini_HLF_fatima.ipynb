# %% [markdown]
# ## Mini Hundir la Flota
# #### Primeros pasos
# Vamos a empezar a programar trozos de código que nos servirán para el HLF:
#
# * Crear un Tablero como una lista de listas de 10x10 que contenga caracteres espacio: " "
# * Insertar dos barcos sustituyendo en el Tablero los espacios en blanco por el caracter "B":
#     * Uno de 4 casillas en horizontal: casillas [1][0], [1][1], [1][2], [1][3]
#     * Uno de 3 casillas en vertical:   casillas [3][3], [4][3], [5][3]
# * Escribir una celda de código separada de las anteriores para simular que el usuario está efectuando un disparo:
#     *  Solicite al usuario dos coordenadas `i,j` mediante dos inputs
#     *  Compruebe si esas coordenadas están ocupada por una casilla barco (que haya una en "B")
#         * Si hay una "B":
#             * Cambiar el contenido de esa posición por una "x"
#             * Imprimir por pantalla el texto "Tocado en posición `i,j`"
#         * Si hay un " ":
#             * Cambiar el contenido de esa posición por una "o"
#             * Imprimir por pantalla el texto "Agua"
#     * Imprimir por pantalla el Tablero
# * Para comprobar que funciona bien la celda de disparar ejecutarla varias veces metiendo distintas coordenadas
#
# ### Bonus
# * En la celda de disparar, si el usuario acierta a tocar un barco, vuelve a disparar
# * Resuélvelo con funciones:
#     * Una para solicitar una coordenada válida a la que llamarás dos veces, una par i y otra par j
#     * Una `disparar` que devuelva `True` si el usuario ha acertado o `False` si no.

# %%
import time

# %%
# Crear tablero mediante funcion.
def tablero_10x10():
    '''
    nos crea y devuelve tablero 10x10 con espacio (" ").
    '''
    tablero = []
    for i in range(10):
        fila = []
        for j in range(10):
            fila.append(" ")
        tablero.append(fila)
    return tablero

tablero = tablero_10x10()

#Mostrar tablero:
for fila in tablero:
    print(fila)
# Out:
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']

# %%
# Posicionar los barcos
#Barco horizontal: Uno de 4 casillas en horizontal: casillas [1][0], [1][1], [1][2], [1][3]
tablero[1][0] = "B"
tablero[1][1] = "B"
tablero[1][2] = "B"
tablero[1][3] = "B"

#Barco vertical: Uno de 3 casillas en vertical:   casillas [3][3], [4][3], [5][3]
tablero[3][3] = "B"
tablero[4][3] = "B"
tablero[5][3] = "B"

# printeo el tablero: # recomendable definir funcion imprimir tablero, para llamar a la funcion cada vez.
for fila in tablero:
    print(fila)
# Out:
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# ['B', 'B', 'B', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']

# %%
# Pedir coordinadas (i, j) & hace validaciones.

def pedir_coordinadas():
    '''Pide coordinadas(i,j), el usuario debe ingresar numero de 0-9.
     La función continúa solicitando entradas (i, j) hasta que el usuario proporcione
    números enteros válidos en el rango 0-9 para ambos, fila y columna. (else /except: captura entras no numericas.)
    Si las entradas son validas, return coordinadas (i,j) '''
    while True:
        try:
            i = int(input("Introduce numero del 0-9 en fila: "))
            j = int(input("Introduce numero del 0-9 columna: "))
        except ValueError:
            print("Entradas no válidas, por favor, introduce numeros enteros entre 0-9")
            continue # ignore todo lo que viene después en el ciclo actual y vuelva a preguntar por las coordenadas(i, j) desde el principio.
        
        if 0 <= i < 10 and 0 <= j < 10:
            print(f"Coordenadas válidas ingresadas: ({i}, {j})")
            return (i, j)
        else:
            print("coordinadas fuera del tablero, intentalo otra vez")

# %%
# funcion para disparar.

def disparar(tablero, i, j):
    ''' 
    simula un disparo en el tablero.
    comprueba la posicion (i, j):
    -Si hay barco ("B"): muestra un mensaje de "tocado...
    -Si no hay barco: marca la posición como agua ("o") y muestra "Agua".
    "'''
    if tablero [i][j] == "B":
        tablero[i][j] = "x"
        print(f"Tocado en posición: {i}, {j}")
        return True
    elif tablero [i][j] == " ":
        tablero[i][j] = "o"
        print("Agua")
        return False
    else: # cuando el usuario introduce coordinadas ya usadas, o cuando las coordinadas no aciertan el disparo
        print(f"Ya disparaste en {i},{j}")
        return Noneh

# %%
  # Funcion para mostrar el tablero.
  def mostrar_tablero(tablero):
      """
      Muestra el tablero en pantalla de manera legible.
      Args:
      tablero (list of list): Matriz 2D que representa el tablero.
      """
      for fila in tablero:
          print(fila)

# %%
# turno del jugador:
while True:
    i, j = pedir_coordinadas() # pide ambas coordenadas a la vez.

    resultado= disparar(tablero, i, j) # llamo a la función disparar
    if resultado: # repite turno si acierta el disparo.
        print("vuelve a disparar")
        continue # vuelve al inicio del while.
    else:
        # Si da agua, turno termina
        print("Turno terminado, siguiente disparo.")
        break # sale del bucle
# Out:
# Coordenadas válidas ingresadas: (8, 9)
# Agua
# Turno terminado, siguiente disparo.
