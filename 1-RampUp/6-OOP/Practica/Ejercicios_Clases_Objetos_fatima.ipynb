# %% [markdown]
# ![imagen](./img/ejercicios.png)
#
# # Ejercicios Clases y Objetos

# %% [markdown]
# ## Ejercicio 1
# Somos una empresa que tiene varias tiendas de electrodomésticos. Necesitamos un programa para manejar las tiendas, ver las ventas que han tenido, cuántos empleados hay, etc... Para ello vamos a modelizar la tienda en una clase, que tendrá las siguientes características:
# * Nombre clase: "Tienda"
# * Atributos comunes:
#     * Tipo: "Electrodomésticos"
#     * Abierta: True
# * Atributos propios de cada tienda:
#     * Nombre - String
#     * Dirección - String
#     * Número de empleados - int
#     * Ventas últimos 3 meses - Lista de 3 numeros
# * Método para calcular las ventas de todos los meses, que devuelva un número con todas las ventas.
# * Método que calcula la media de ventas de los últimos meses, por empleado
# * Método que devuelve en un string el nombre de la tienda, junto con su dirección.
# * Método que obtiene las ventas del último mes.
# * Método para dar una proyección de las ventas en caso de haber invertido X dinero en marketing en esa tienda. Siendo X el parámetro de entrada. Si X es menor de 1000, las ventas de los ultimos 3 meses hubiesen sido de (1.2 x ventas), si es mayor o igual de 1000, las ventas hubiesen sido de (1.5 x venta). El método reescribe el atributo de ventas en los últimos 3 meses, y además devuelve las ventas con el aumento.
#
# Se pide:
# 1. Implementar la clase "Tienda"
# 2. Crear tres tiendas con datos inventados
# 3. Comprueba en al menos una de ellas, todo lo implementado en la clase tienda (sus atributos, media de ventas, ventas/empleado...)
# 3. Calcular las ventas del último mes de todas las tiendas. Para ello usa el bucle `for`
# 4. Imprime por pantalla los nombres de las tiendas cuya dirección lleve el string "Avenida"
# 5. Seguro que ya has hecho este apartado... Documenta la clase :)

# %%
#definicion de la Clase Tienda.

class Tienda: 
    #definimos los atributos comunesa todas las tiendas:
    Tipo = "electrodomésticos"
    Abierta = True
    #definimos atributos propios de cada tienda
    def __init__(self, nombre: str, direccion: str, empleados: int, ventas_ultimos_3meses: list):
        self.nombre = nombre
        self.direccion = direccion
        self.empleados = empleados
        self.ventas_ultimos_3meses = ventas_ultimos_3meses

# %%
# le asigno el valor a los atributos de cada tienda( tienda1, tienda2 y tienda3)
tienda1= Tienda("tienda1", "direcion1", 5, [1.5, 5.0, 2.5])
print(tienda1)

tienda2= Tienda("tienda2", "direcion2", 2, [1.5, 17, 4])
print(tienda2)

tienda3= Tienda("tienda3", "direcion3", 7, [1.5, 17, 4])
print(tienda3)

# Saco la variable lista tiendas, para hacer el ejercicio 1.4 con el bucle for.
lista_tiendas = [tienda1, tienda2, tienda3]
print(lista_tiendas)
# Out:
# ...
# [<__main__.Tienda object at 0x000001F98F22CE50>, <__main__.Tienda object at 0x000001F98F22D550>, <__main__.Tienda object at 0x000001F98EC97510>]

# %%
# compruebo si en la tienda1: tiene asignaados todos sus atributos.
print(tienda1.nombre)
print(tienda1.direccion)
print(tienda1.empleados)
print(tienda1.ventas_ultimos_3meses)
# Out:
# tienda1
# direcion1
# 5
# [1.5, 5.0, 2.5]

# %%
#Definicion del Metodo ventas totales.
class Tienda: 
    #definimos los atributos comunesa todas las tiendas:
    Tipo = "electrodomésticos"
    Abierta = True
    #definimos atributos propios de cada tienda
    def __init__(self, nombre: str, direccion: str, empleados: int, ventas_ultimos_3meses: list):
        self.nombre = nombre
        self.direccion = direccion 
        self.empleados = empleados
        self.ventas_ultimos_3meses = ventas_ultimos_3meses
        
    #definimos metodo para calcular ventas de todos los meses:
    def ventas_totales(self):
        return sum(self.ventas_ultimos_3meses)

# %%
# para sacar las Ventas Totales de tienda1:
print( tienda1.ventas_totales())
# Out:
# 9.0

# %%
#Definicion Metodo Media de ventas.
class Tienda: 
    #definimos los atributos comunesa todas las tiendas:
    Tipo = "electrodomésticos"
    Abierta = True
    
    #definimos atributos propios de cada tienda
    def __init__(self, nombre: str, direccion: str, empleados: int, ventas_ultimos_3meses: list):
        self.nombre = nombre
        self.direccion = direccion 
        self.empleados = empleados
        self.ventas_ultimos_3meses = ventas_ultimos_3meses
        
    #definimos el metodo para sacar la media de ventas.
    def media_ventas(self):
        return sum(self.ventas_ultimos_3meses) / 3

# %%
# Media de Ventas totales de tienda1:
print(tienda1.media_ventas())
# Out:
# 3.0

# %%
# Definicion Metodo media de ventas por empleado.
class Tienda: 
    #definimos los atributos comunesa todas las tiendas:
    Tipo = "electrodomésticos"
    Abierta = True
    #definimos atributos propios de cada tienda
    def __init__(self, nombre: str, direccion: str, empleados: int, ventas_ultimos_3meses: list):
        self.nombre = nombre
        self.direccion = direccion 
        self.empleados = empleados
        self.ventas_ultimos_3meses = ventas_ultimos_3meses
    #definimos el metodo para sacar la media de ventas de los ultimos meses por empleado.
    def ventas_por_empleado (self):
        return sum(self.ventas_ultimos_3meses) / self.empleados

# %%
#Media de ventas totales por empleado de tienda1:
print(tienda1.ventas_por_empleado())
# Out:
# 1.8

# %%
# Definicion Metodo string nombre & direccion.
class Tienda: 
    #definimos los atributos comunesa todas las tiendas:
    Tipo = "electrodomésticos"
    Abierta = True
    #definimos atributos propios de cada tienda
    def __init__(self, nombre: str, direccion: str, empleados: int, ventas_ultimos_3meses: list):
        self.nombre = nombre
        self.direccion = direccion 
        self.empleados = empleados
        self.ventas_ultimos_3meses = ventas_ultimos_3meses
    #definimos el metodo para sacar nombre & direccion.
    def nombre_direccion (self):
        return (f"el nombre de la tienda es , {self.nombre}, y su direccion es {self.direccion}")

# %%
#para sacar el nombre y la direccion de la tienda1:
print(tienda1.nombre_direccion())
# Out:
# el nombre de la tienda es , tienda1, y su direccion es direcion1

# %%
# Definicion Metodo Ventas del Ultimo Mes.
class Tienda: 
    #definimos los atributos comunesa todas las tiendas:
    Tipo = "electrodomésticos"
    Abierta = True
    #definimos atributos propios de cada tienda
    def __init__(self, nombre: str, direccion: str, empleados: int, ventas_ultimos_3meses: list):
        self.nombre = nombre
        self.direccion = direccion 
        self.empleados = empleados
        self.ventas_ultimos_3meses = ventas_ultimos_3meses
        
    #definimos el metodo para ventas del ultimo MES.
    def ventas_ultimo_mes(self):
        return self.ventas_ultimos_3meses[-1] # bueno he metido [-1] paraque me devuelva el ultimo valor de la lista, que corresponde a ventas del ultimo mes.

# %%
#ventas del ultimo mes
for tienda in lista_tiendas:
    print("ventas del ultimo mes de", tienda.nombre, " ", tienda.ventas_ultimo_mes())
# Out:
# ventas del ultimo mes de tienda1   2.5
# ventas del ultimo mes de tienda2   4
# ventas del ultimo mes de tienda3   4

# %%
for tienda in lista_tiendas:
    if "Avenida" in tienda.direccion:
        print(tienda.nombre)
    else:
        print("la tienda con nombre,", tienda.nombre,", no tiene nombre Avenida en direccion.")
# Out:
# la tienda con nombre, tienda1 , no tiene nombre Avenida en direccion.
# la tienda con nombre, tienda2 , no tiene nombre Avenida en direccion.
# la tienda con nombre, tienda3 , no tiene nombre Avenida en direccion.

# %%
# Definicion Metodo proyecccion de ventas.
class Tienda: 
    #definimos los atributos comunesa todas las tiendas:
    Tipo = "electrodomésticos"
    Abierta = True
    #definimos atributos propios de cada tienda
    def __init__(self, nombre: str, direccion: str, empleados: int, ventas_ultimos_3meses: list):
        self.nombre = nombre
        self.direccion = direccion 
        self.empleados = empleados
        self.ventas_ultimos_3meses = ventas_ultimos_3meses
        
    #definimos la proyeccion de ventas.
    def proyeccion_ventas(self):
        if inversion < 1000:
         
    
    ## NO SE HACER ESTE APARTADO !!

# %% [markdown]
# ## Ejercicio 2
# En este ejercicio vamos a implementar una clase *Perro* en Python. La clase tiene las siguientes características:
# * Cosas que sabemos seguro que tiene un perro
#     * Tiene 4 patas
#     * 2 orejas
#     * 2 ojos
#     * Una velocidad de 0. Por defecto, el perro está parado
# * Cuando se inicialice:
#     * El perro será de una determinada raza
#     * Por defecto tendrá pelo "Marrón", a no ser que se diga lo contrario.
#     * Por defecto no tendrá dueño, a no ser que se diga lo contrario.
#
# * Dispondrá también de un método llamado andar, que tiene un argumento de entrada (aumento_velocidad). Este valor se le sumará a la velocidad que ya llevaba el perro.
# * Necesita otro método (parar), donde pondremos la velocidad a 0.
# * Otro método llamado "ladrar", que tendrá un argumento de entrada, y la salida será el siguiente string: "GUAU!" + el argumento de entrada.
#
#
# Se pide:
# * Implementa la clase *Perro*
# * Crea un objeto de tipo *Perro*, sin dueño
# * Comprueba que están bien todos sus atributos
# * Prueba que ande, y comprueba su velocidad
# * Páralo
# * Documenta la clase *Perro*

# %%
#definicion de la Clase Perro.

class Perro: 
    #definimos los atributos comunes:
    Patas = 4
    Orejas = 2
    Velocidad = 0
    '''
    Clase que representa un perro.
    Contiene atributos comunes a todos los perros
    y métodos que definen su comportamiento.
    """

    # Atributos de clase (comunes a todos los perros)
    Patas = 4
    Orejas = 2

    # Constructor: se ejecuta al crear un nuevo objeto Perro
    def __init__(self, raza: str, pelo: str = "marron", dueno: bool = False):
        """
        Inicializa un objeto Perro.

        :param raza: Raza del perro
        :param pelo: Color del pelo (por defecto "marron")
        :param dueno: Indica si tiene dueño (True/False)
        """
        self.raza = raza
        self.pelo = pelo
        self.dueno = dueno
        self.velocidad = 0  # Atributo propio de cada perro

    def andar(self, aumento_velocidad: int):
        """
        Aumenta la velocidad del perro.

        :param aumento_velocidad: Cantidad que se suma a la velocidad actual
        :return: Velocidad actualizada
        """
        self.velocidad += aumento_velocidad
        return self.velocidad

    def parar(self):
        """
        Detiene al perro estableciendo la velocidad en 0.

        :return: Velocidad actual (0)
        """
        self.velocidad = 0
        return self.velocidad

    def ladrar(self, mensaje: str):
        """
        Hace que el perro ladre junto con un mensaje.

        :param mensaje: Texto adicional después de 'guau'
        :return: Cadena con el ladrido
        """
        return "guau " + mensaje
        '''
    
    #definimos atributos propios de cada perro:
    def __init__(self, raza: str, pelo: "marron", dueno: False):
        self.raza = raza
        self.pelo = pelo
        self.dueno = dueno
        
    #Método andar con argumento de entrada "aumento_velocidad. este valor se le sumara la la "
    def andar(self.aumento_velocidad):
        self.velocidad = aumento_velocidad + self.velocidad
        return self.velocidad #
    #metodo parar con velocidad 0          
    def parar(self):
        self.velocidad = 0
        return self.velocidad
    
    #metodo ladrar
    def ladrar(self, arg):
        return"guau" + " " + arg #añodp espacio apra que me separe guar del arg
# Out:
#   Cell In[6], line 68
#     def andar(self.aumento_velocidad):
#                   ^
# SyntaxError: invalid syntax

# %%
# le asigno el valor a los atributos de clase Perro.
perro1 = Perro("chihuahua", "marron", False)
print(perro1)

perro2 = Perro("caniche", "marron", False)
print(perro2)

perro3 = Perro("Pastor aleman", "marron", True)
print(perro3)

# %%
print(perro1.raza)
print(perro1.pelo)
print(perro1.dueno)
print()
print(perro2.raza)
print(perro2.pelo)
print(perro2.dueno)
print()
print(perro3.raza)
print(perro3.pelo)
print(perro3.dueno)
# Out:
# chihuahua
# marron
# False
#
# caniche
# marron
# False
#
# Pastor aleman
# marron
# True
