# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics II

# %% [markdown]
# ## Ejercicio 1
# * Crea dos variables numericas: un `int` y un `float`
# * Comprueba sus tipos
# * Sumalas en otra nueva
# * ¿De qué tipo es la nueva variable?
# * Elimina las variables creadas

# %%
var_int = 10
var_float = 10.6
print(type(var_int))
print(type(var_float))
var_suma = var_int + var_float
print(var_suma)
print(type(var_suma))
# Out:
# <class 'int'>
# <class 'float'>
# 20.6
# <class 'float'>

# %%
var_suma = var_int + var_float
prin(del var_suma)
# Out:
#   Cell In[12], line 2
#     prin(del var_suma)
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Ejercicio 2
# Escribe un programa para pasar de grados a radianes. Hay que usar `input`. Recuerda que la conversión se realiza mediante
#
# $$radianes = grados*(pi/180)$$

# %%
grados =(float(input("on grados")))
print(grados)
import math
radianes = grados * (math.pi / 180)
print(radianes)
# Out:
# 100.0
# 1.7453292519943295

# %% [markdown]
# ## Ejercicio 3
# Escribe un programa que calcule el area de un paralelogramo (base x altura). También con `input`

# %%
base = (float(input("introduzca la base del paralelogramo")))
altura = (float(input("introduzca altura el paralelogramo")))
area = base * altura
print("el area de un paralelogramo  de base", base,"y altura", altura,"es de", area)
# Out:
# el area de un paralelogramo  de base 6.3 y altura 7.5 es de 47.25

# %% [markdown]
# ## Ejercicio 4
# Tenemos las siguientes variables:
#
# ```Python
# A = 4
# B = "Text"
# C = 4.1
# ```
#
# Comprueba:
# 1. Si A y B son equivalentes
# 2. Si A y C NO son equivalentes
# 3. Si A es mayor que C
# 4. Si C es menor o igual que A
# 5. Si B NO es equivalente a C

# %%
A = 4
B = "text"
C = 4.1

# %%
print(A == B)
print(A != C)
print(A > C)
print(C <= A)
print(B != C)
# Out:
# False
# True
# False
# False
# True

# %%
A = 4
B = "text"
c = 4.1
if(A == B):
    print("A & B son iguales")
else:
    print("no lo son")

# %% [markdown]
# ## Ejercicio 5
# Crea un programa donde se recojan dos inputs del usuario, y el output del programa sea si esos inputs son iguales o no

# %%
Dato_1 = input("introduzca el nombre de la empresa")
Dato_2 = input("introduzca el domicilio fiscal")
print(Dato_1 == Dato_2)
# Out:
# False

# %% [markdown]
# ## Ejercicio 6
# Mismo programa que en 5, pero en esta ocasión tienen que ser tres inputs y dos salidas. Una de las salidas que nos indique si todos son iguales, y la otra si al menos dos inputs sí que lo son

# %%
Dato_1 = input("introduzca el nombre de la empresa")
Dato_2 = input("introduzca el domicilio fiscal")
Dato_3 = input("introduzca el numero de empleados")
print(Dato_1 == Dato_2 == Dato_3) 
print(("¿hay al menos dos inputs son iguales ", Dato_1 == Dato_2 or Dato_2 == Dato_3 or Dato_3 == Dato_1))
# Out:
# False
# ('¿hay al menos dos inputs son iguales ', False)

# %% [markdown]
# ## Ejercicio 7
# Crea un programa que recoja dos inputs. Tiene que comprobar si su suma es igual, superior o inferior a 10, cada condición por separado

# %%
dato_1 = int(input("introduzca un valor numerico"))
dato_2 = int(input("introduzca segundo valor"))
dato_3 = dato_1 + dato_2
print(dato_3)
print("los datos son iguales", dato_3 == 10)
print("la suma es superior a 10", dato_3 > 10)
print("la suma es inferior a 10", dato_3 < 10)
# Out:
# 16
# los datos son iguales False
# la suma es superior a 10 True
# la suma es inferior a 10 False

# %% [markdown]
# ## Ejercicio 8
# Razona sin ejecutar código el output que obtendremos de las siguientes sentencias
# 1. True and True and False
# 2. not ((True or False) and (True or False))
# 3. (False or False or False or True) and False
# 4. not False and True and not True
#
# Compruébalo después con python

# %% [markdown]
# 1. False # para que sea true en un and todas itenen que ser True.
# 2. not (True) and (True) = False and True = False
# 3. True and False = False
# 4. True and True and False = False

# %% [markdown]
# 1.False ya que and solo es True si todas son True.
# 2.
# 3.False ya que and solo es True si ambas son True
# 4.False ya que and solo es True si todas son True.

# %%
print(True and True and False)
print(not (True or False) and (True or False))
print((False or  False or False or True) and False)
print( not False and True and not True)
# Out:
# False
# False
# False
# False

# %% [markdown]
# ## Ejercicio 9
# Para este ejercicio vamos a poner en práctica [las funciones built in](https://docs.python.org/3/library/functions.html).
#
# 1. Calcula el máximo de la lista: [4, 6, 8, -1]
# 2. Suma todos los elementos de la lista anterior
# 3. Redondea este float a 3 dígitos decimales: 63.451256965
# 4. Valor absoluto de: -74

# %%
mi_lista = [4, 6, 8, -1]
print(max(mi_lista))
# Out:
# 8

# %%
print(sum(mi_lista))
# Out:
# 17

# %%
 A = 63.451256965 
 print(type(A))
 print(round(A, 3))
# Out:
# <class 'float'>
# 63.451

# %%
print(abs(-74))
# Out:
# 74

# %% [markdown]
# ## Ejercicio 10
# Para el siguiente string se pide imprimir por pantalla los siguientes casos
#
#     "Lo primero de todo, cómo están los máquinas"
#
# 1. Pasarlo todo a mayúsculas
# 2. Pasarlo todo a minúsculas
# 3. Pasar a mayúsculas solo las iniciales de las palabras
# 4. Crea una lista dividiendolo por sus espacios
# 5. Sustituye las comas `,` por puntos y comas `;`
# 6. Elimina las `a` minúsculas

# %%
mi_string = "lo primero de todo, cómo están las máquinas"
print(mi_string.upper())
print(mi_string.lower())
print(mi_string.replace("l", "L"))
print(mi_string.title())
print(mi_string.split()) #por defecto separa por el espacio.
print(mi_string.replace(",", ";"))
print(mi_string.replace("a", ""))
# Out:
# LO PRIMERO DE TODO, CÓMO ESTÁN LAS MÁQUINAS
# lo primero de todo, cómo están las máquinas
# Lo primero de todo, cómo están Las máquinas
# Lo Primero De Todo, Cómo Están Las Máquinas
# ['lo', 'primero', 'de', 'todo,', 'cómo', 'están', 'las', 'máquinas']
# lo primero de todo; cómo están las máquinas
# lo primero de todo, cómo están ls máquins

# %% [markdown]
# ## Ejercicio 11
# 1. Crea una lista con 3 elementos numéricos
# 2. Añade un cuarto elemento
# 3. Calcula la suma de todos
# 4. Elimina el segundo elemento de la lista
# 5. Añade otro elemento en la posicion 3 de la lista
# 6. Crea otra lista con 4 elementos y concaténala a la que ya tenías.

# %%
mi_lista = [1, 2, 3]
print(mi_lista.append(4)) # ejecutando esto solo python no hace nada
print(mi_lista)          # ejecutar print para ver el cambio anterior.
print(sum(mi_lista))
print(mi_lista.remove(2)) #el remove(elemento)lo quita de la lista pero no devuelve nada, pop [posiciona]lo ellimina de la lista y devuelve cambios.
print(mi_lista)
print(mi_lista.insert(3,5))
print(mi_lista)
nueva_lista = ["ir", "a", "casa"]
lista_total = mi_lista + nueva_lista
print(lista_total)
# Out:
# None
# [1, 2, 3, 4]
# 10
# None
# [1, 3, 4]
# None
# [1, 3, 4, 5]
# [1, 3, 4, 5, 'ir', 'a', 'casa']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 12
#      10 lista_total = mi_lista + nueva_lista
#      11 print(lista_total)
# ---> 12 print(mi_lista.pop[1])
#
# TypeError: 'builtin_function_or_method' object is not subscriptable
