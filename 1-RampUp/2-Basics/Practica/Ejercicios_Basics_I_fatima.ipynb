# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics I

# %% [markdown]
# ## Ejercicio 0
# Imprime por pantalla esta cita con el siguiente formato
#
# ![imagen](./img/frase_Einstein.PNG)

# %%
mi_cita = "¿Por qué esta magnifica tecnologia científica,\n\tque ahorra trabajo y nos hace la vida mas fácil,\n\t\tos aporta tan poca felicidad?\n\t\t\t la respuesta es está, simplemente; poruqe aún no hemos aprendido a usarla con tino.\n\'Albert Einstein'"
print(mi_cita)
# Out:
# ¿Por qué esta magnifica tecnologia científica,
# 	que ahorra trabajo y nos hace la vida mas fácil,
# 		os aporta tan poca felicidad?
# 			 la respuesta es está, simplemente; poruqe aún no hemos aprendido a usarla con tino.
# 'Albert Einstein'

# %% [markdown]
# ## Ejercicio 1
# 1. Escribe el nombre de la calle de tu domicilio en una variable
# 2. Escribe el numero de la calle en otra
# 3. Ciudad en una tercera
# 4. Codigo postal en la cuarta variable
# 5. Imprime las 4 variables concatenadas por pantalla
# 6. Crea una quinta variable que concatene todas ellas
# 7. Imprímela por pantalla

# %%
domicilio = "Sestao"
calle = "siete"
ciudad = "Bilbao"
codigo_postal = "cuarenta y ocho nueve cero cero"
variables_concatenadas = domicilio +" "+ calle +" "+ ciudad +" "+ codigo_postal
print(variables_concatenadas)
quinta_variable = variables_concatenadas
print(quinta_variable)
# Out:
# Sestao siete Bilbao cuarenta y ocho nueve cero cero
# Sestao siete Bilbao cuarenta y ocho nueve cero cero

# %% [markdown]
# ## Ejercicio 2
# Repite el ejercicio 1, pero pidiendo estos datos al usuario mediante un input(), imprimiendo a continuación la dirección completa

# %%
domicilio = input("Introduzca aqui su domicilio ")
Calle = input("Introduzca aqui el nombre de la calle ")
Ciudad = input("Introduzca aqui la ciudad ")
codigo_postal = input ("introduzca su codigo postal")
direccion_completa = domicilio + " " + calle + " " + ciudad + " " + codigo_postal
print( direccion_completa)
# Out:
# Sestao grpo. Marques de la felicidad Bilbao 48910

# %% [markdown]
# ## Ejercicio 3
# ¿Qué variables están mal escritas y por qué? Realiza primero tu hipótesis y luego ejecuta las variables para comprobarlo. En ese orden :)
#
#
# 1. mi_variable = "Economía"
# 2. otra_var = "Ejercicio
# 3. True = "Ejercicio"
# 4. mi variab1e = "Alpha"
# 5. import = 40
# 6. 81mi_variable = "Agua"
# 7. mi_variable10 = 6

# %%
#la variable 1 esta ok
#la varibles 2 esta mal porque no tiene " de cierre.
#la variable 3 True no puede ir como variable porque es palabra reservada de python.
#la variable 4s palabra mi variable no puede ir con espacio
#la variable 5 esta mal import es palabra reservada.
#la variable 6 esta mal, una variable no puede empezar por numeros
#la variable 7 esta ok
mi_variable = "Economía"
print(mi_variable)
otra_var = "ejercicio"
print (otra_var)
#True = "Ejercicio" no me lo puede ejecutarla.
mi_variable = "Alpha"
print(mi_variable)
#import = 40 no me lo puede ejecutar
# 81mi_variable = "Agua" no me lo puede ejecutar error invalid decimal literal.
mi_variable10 = 6
print(mi_variable10)
# Out:
# Economía
# ejercicio
# Alpha
# 6

# %% [markdown]
# ## Ejercicio 4
# Realiza un conversor de grados Celsius a Fahrenheit. El conversor tiene que recibir el input del usuario y devolver la conversión.
#
# La conversión de grados sigue la siguiente fórmula: F = C × (9 / 5) + 32

# %%
c = int(input("introduzco cualquier numero?"))
f = c * (9/5) + 32
print(f)
# Out:
# 42.8

# %% [markdown]
# ## Ejercicio 5
# Comenta  el Ejercicio 4. Pon un comentario multilinea y haz comentarios de cada linea de código

# %%
''' 
esto no es codigo, es comentario del anterior ejercicio;
lo primero que he hecho es pasar el numero string de la primera variable a int.
y luego ejecutar la variable mediante función print
'''
c = int(input("introduzco cualquier numero?")) # Solicita al usuario que introduzca un número entero
f = c * (9/5) + 32 # Fórmula: Fahrenheit = Celsius * (9/5) + 32
print(f) # Muestra el resultado en pantalla
# Out:
# 42.8
