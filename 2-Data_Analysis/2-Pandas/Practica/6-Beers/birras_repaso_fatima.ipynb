# %% [markdown]
# ![imagen](https://cdn.foodbeast.com/content/wp-content/uploads/2012/03/beer-print-01-selectism.jpg)
#
# # Ejercicio pandas estadística
# Para este ejercicio se ha utilizado [un dataset de un concurso de kaggle](https://www.kaggle.com/nickhould/craft-cans), cuyo reto consiste en predecir el tipo de cerveza en función de sus características (nivel de alcohol, amargura, tamaño...).
#
# # Ejercicio 1
# Importa las librerias que consideres

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Ejercicio 2datasets_beer.csv
# 1. Importa el dataset "datasets_beer.csv"
# 2. Imprime por pantalla los primeros registros.
# 3. ¿Cuáles son sus columnas?
# 4. ¿Qué dimensiones tiene el DataFrame?

# %%
dataset = pd.read_csv("./data/datasets_beers.csv") # ./ data (es la carpeta donde esta el archivo en mi rpa) seguido de el nombre del fichero
dataset
# Out:
#       Unnamed: 0    abv   ibu    id                  name  \
# 0              0  0.050   NaN  1436              Pub Beer
# 1              1  0.066   NaN  2265           Devil's Cup
# 2              2  0.071   NaN  2264   Rise of the Phoenix
# 3              3  0.090   NaN  2263              Sinister
# 4              4  0.075   NaN  2262         Sex and Candy
# ...          ...    ...   ...   ...                   ...
# 2405        2405  0.067  45.0   928             Belgorado
# 2406        2406  0.052   NaN   807         Rail Yard Ale
# 2407        2407  0.055   NaN   620       B3K Black Lager
# 2408        2408  0.055  40.0   145   Silverback Pale Ale
# 2409        2409  0.052   NaN    84  Rail Yard Ale (2009)
#
#                                style  brewery_id  ounces
# 0                American Pale Lager         408    12.0
# 1            American Pale Ale (APA)         177    12.0
# 2                       American IPA         177    12.0
# ...

# %%
dataset.info() # bueno hago esto para ver la info.
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2410 entries, 0 to 2409
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2410 non-null   int64
#  1   abv         2348 non-null   float64
#  2   ibu         1405 non-null   float64
#  3   id          2410 non-null   int64
#  4   name        2410 non-null   str
#  5   style       2405 non-null   str
#  6   brewery_id  2410 non-null   int64
#  7   ounces      2410 non-null   float64
# dtypes: float64(3), int64(3), str(2)
# memory usage: 150.8 KB

# %% [markdown]
# ## Ejercicio 3
# [Elimina la columna "Unnamed: 0"](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html)

# %%
dataset = dataset.drop("Unnamed: 0", axis = 1) #dentro del parentesis pongo el valor que quiero eliminar, y axis = column(1)

# %%
dataset
# Out:
#         abv   ibu    id                  name                           style  \
# 0     0.050   NaN  1436              Pub Beer             American Pale Lager
# 1     0.066   NaN  2265           Devil's Cup         American Pale Ale (APA)
# 2     0.071   NaN  2264   Rise of the Phoenix                    American IPA
# 3     0.090   NaN  2263              Sinister  American Double / Imperial IPA
# 4     0.075   NaN  2262         Sex and Candy                    American IPA
# ...     ...   ...   ...                   ...                             ...
# 2405  0.067  45.0   928             Belgorado                     Belgian IPA
# 2406  0.052   NaN   807         Rail Yard Ale        American Amber / Red Ale
# 2407  0.055   NaN   620       B3K Black Lager                     Schwarzbier
# 2408  0.055  40.0   145   Silverback Pale Ale         American Pale Ale (APA)
# 2409  0.052   NaN    84  Rail Yard Ale (2009)        American Amber / Red Ale
#
#       brewery_id  ounces
# ...

# %% [markdown]
# ## Ejercicio 4
# ¿Cuántas filas y columnas tiene el dataset?

# %%
dataset.info()
#Tiene 2410 filas y 8 columnas.
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2410 entries, 0 to 2409
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   abv         2348 non-null   float64
#  1   ibu         1405 non-null   float64
#  2   id          2410 non-null   int64
#  3   name        2410 non-null   str
#  4   style       2405 non-null   str
#  5   brewery_id  2410 non-null   int64
#  6   ounces      2410 non-null   float64
# dtypes: float64(3), int64(2), str(2)
# memory usage: 131.9 KB

# %%
dataset.shape
# Out:
# (2410, 7)

# %% [markdown]
# ## Ejercicio 5
# ¿De qué tipo son los datos?

# %%
#float64(3 columnas), int64(3 columnas), str(2 columnas.) esto lo saco del ejercicio anterior.

# %% [markdown]
# ## Ejercicio 6
# Obtén en un nuevo DataFrame un resumen con las principales estadísticas de las columnas numéricas: mean, max, count, cuartiles...

# %%
resumen = dataset.describe().T #me devuelve estadísticas de todas las columnas que son numéricas.
resumen
# Out:
#              count         mean         std    min     25%       50%  \
# abv         2348.0     0.059773    0.013542  0.001    0.05     0.056
# ibu         1405.0    42.713167   25.954066  4.000   21.00    35.000
# id          2410.0  1431.113278  752.459975  1.000  808.25  1453.500
# brewery_id  2410.0   231.749793  157.685604  0.000   93.00   205.000
# ounces      2410.0    13.592241    2.352204  8.400   12.00    12.000
#
#                  75%       max
# abv            0.067     0.128
# ibu           64.000   138.000
# id          2075.750  2692.000
# brewery_id   366.000   557.000
# ounces        16.000    32.000

# %% [markdown]
# ## Ejercicio 7
# ¿Cuántas birras hay de cada estilo en este dataset? [Investiga en la documentación de Series](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html) si puedes hacer un conteo de valores.

# %%
# el link no funciona.
dataset['style'].value_counts() #value_count() me dice cuantas veces aparece ese valor.
# Out:
# style
# American IPA                      424
# American Pale Ale (APA)           245
# American Amber / Red Ale          133
# American Blonde Ale               108
# American Double / Imperial IPA    105
#                                  ...
# American Malt Liquor                1
# Grisette                            1
# Flanders Oud Bruin                  1
# Braggot                             1
# Low Alcohol Beer                    1
# Name: count, Length: 99, dtype: int64

# %% [markdown]
# ## Ejercicio 8
# 1. Imprime por pantalla los registros desde el décimo hasta el vigésimo
# 2. De esos registros, imprime por pantalla desde la columna `name` a `ounces`, ambas incluidas
# 3. Quédate con las columnas `abv`, `ibu` y `ounces`, y además quédate sólo con los registros 10 al 20.
# 4. Convierte el resultado del apartado 3 en un array de `numpy`

# %%
df_registros= dataset.iloc[10:21] # pongo 21 para que me inluya el registro 20.
df_registros
# Out:
#       abv   ibu    id                          name                    style  \
# 10  0.072   NaN  2099             Sophomoric Saison   Saison / Farmhouse Ale
# 11  0.073   NaN  2098         Regional Ring Of Fire   Saison / Farmhouse Ale
# 12  0.069   NaN  2097                    Garce Selé   Saison / Farmhouse Ale
# 13  0.085   NaN  1980               Troll Destroyer              Belgian IPA
# 14  0.061  60.0  1979                  Bitter Bitch  American Pale Ale (APA)
# 15  0.060   NaN  2318                   Ginja Ninja                    Cider
# 16  0.060   NaN  2170                 Cherried Away                    Cider
# 17  0.060   NaN  2169                  Rhubarbarian                    Cider
# 18  0.060   NaN  1502                   BrightCider                    Cider
# 19  0.082   NaN  1593   He Said Baltic-Style Porter            Baltic Porter
# 20  0.082   NaN  1592  He Said Belgian-Style Tripel                   Tripel
#
#     brewery_id  ounces
# ...

# %%
df_registros.loc[:,'name':'ounces'] # :todas las filas de df_registros, todas las columnas de 'name'hasta'ounces'
# Out:
#                             name                    style  brewery_id  ounces
# 10             Sophomoric Saison   Saison / Farmhouse Ale         177    12.0
# 11         Regional Ring Of Fire   Saison / Farmhouse Ale         177    12.0
# 12                    Garce Selé   Saison / Farmhouse Ale         177    12.0
# 13               Troll Destroyer              Belgian IPA         177    12.0
# 14                  Bitter Bitch  American Pale Ale (APA)         177    12.0
# 15                   Ginja Ninja                    Cider         154    12.0
# 16                 Cherried Away                    Cider         154    12.0
# 17                  Rhubarbarian                    Cider         154    12.0
# 18                   BrightCider                    Cider         154    12.0
# 19   He Said Baltic-Style Porter            Baltic Porter         368    12.0
# 20  He Said Belgian-Style Tripel                   Tripel         368    12.0

# %%
 x = df_registros.loc[:,['abv','ibu', 'ounces']] # pongo corchetes columna para que me devuelva los valores ['abv','ibu', 'ounces'].
 x # me guardo esto en varaible x porque en el siguiente ejercicio me pide transaformarlo en un array de numpy
# Out:
#       abv   ibu  ounces
# 10  0.072   NaN    12.0
# 11  0.073   NaN    12.0
# 12  0.069   NaN    12.0
# 13  0.085   NaN    12.0
# 14  0.061  60.0    12.0
# 15  0.060   NaN    12.0
# 16  0.060   NaN    12.0
# 17  0.060   NaN    12.0
# 18  0.060   NaN    12.0
# 19  0.082   NaN    12.0
# 20  0.082   NaN    12.0

# %%
arrray = x.to_numpy()
arrray
# Out:
# array([[ 0.072,    nan, 12.   ],
#        [ 0.073,    nan, 12.   ],
#        [ 0.069,    nan, 12.   ],
#        [ 0.085,    nan, 12.   ],
#        [ 0.061, 60.   , 12.   ],
#        [ 0.06 ,    nan, 12.   ],
#        [ 0.06 ,    nan, 12.   ],
#        [ 0.06 ,    nan, 12.   ],
#        [ 0.06 ,    nan, 12.   ],
#        [ 0.082,    nan, 12.   ],
#        [ 0.082,    nan, 12.   ]])

# %% [markdown]
# ## Ejercicio 9
# ¿Cuántas onzas pesan todas las birras del dataset?

# %%
dataset['ounces'].sum() # creo que es así.
# Out:
# np.float64(32757.3)

# %% [markdown]
# ## Ejercicio 10
# El amargor de las cervezas se mide por su nivel de IBUs.
# 1. ¿Cuál es el amargor medio de las cervezas?
# 2. ¿El máximo? ¿Y el mínimo?
# 3. ¿Qué cerveza es la que tiene el amargor máximo? ¿Cuál es la de amargor mínimo?

# %%
df_amargor_medio = dataset['ibu'].mean()
df_amargor_medio
# Out:
# np.float64(42.71316725978647)

# %%
amargor_min =dataset['ibu'].min()
amargor_min
# Out:
# np.float64(4.0)

# %%
amargor_max =dataset['ibu'].max()
amargor_max
# Out:
# np.float64(138.0)

# %%
cerveza_max = df[df['ibu'] == amargor_max]['name'].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 cerveza_max = df[df['ibu'] == amargor_max]['name'].values
#
# NameError: name 'df' is not defined

# %%
#cerveza que tiene amargor Max:
dataset[dataset['ibu'] == amargor_max]['name'].values
# Out:
# <StringArray>
# ['Bitter Bitch Imperial IPA']
# Length: 1, dtype: str

# %%
#otra manera de hacerlo.
dataset.iloc[dataset['ibu'].idxmax()][['name', 'ibu']]
# Out:
# name    Bitter Bitch Imperial IPA
# ibu                         138.0
# Name: 147, dtype: object

# %%
#cerveza que tiene amargor Min:
dataset[dataset['ibu'] == amargor_min]['name'].values
# Out:
# <StringArray>
# [                     'Summer Solstice',
#  'Summer Solstice Cerveza Crema (2009)',
#                'Summer Solstice (2011)']
# Length: 3, dtype: str

# %% [markdown]
# ## Ejercicio 11
# No queda muy claro cuánto de dispar, de dispersa, es la medida de IBU. Mediante estadística descriptiva (una o dos métricas, sin gráficas), razona la dispersión de la variable IBU.

# %%
print(dataset['ibu'].mean())
print(dataset['ibu'].var()) # la varianz es muy elevada, lo qe indica los dfatos estan muy dispersos.
print(dataset['ibu'].std()) # la desviacion tipica es de 25.95 unidades de distancia respecto de la media.
# Out:
# 42.71316725978647
# 673.6135373259929
# 25.954065911259317

# %%
desv_estandar_ibu = dataset['ibu'].std() #con esto saco la desviacion estandar.
desv_estandar_ibu
# Out:
# np.float64(25.954065911259317)

# %% [markdown]
# ## Ejercicio 12
# ¿Existe alguna relación lineal entre las variables numéricas del dataset? Intenta pintar este razonamiento mediante un gráfico

# %%
#primero:selecionamos columnas numericas,esto es importante porque no se puede correlacionar texto con números.
nums= dataset.select_dtypes(include=['float', 'int'])
nums
# Out:
#         abv   ibu    id  brewery_id  ounces
# 0     0.050   NaN  1436         408    12.0
# 1     0.066   NaN  2265         177    12.0
# 2     0.071   NaN  2264         177    12.0
# 3     0.090   NaN  2263         177    12.0
# 4     0.075   NaN  2262         177    12.0
# ...     ...   ...   ...         ...     ...
# 2405  0.067  45.0   928         424    12.0
# 2406  0.052   NaN   807         424    12.0
# 2407  0.055   NaN   620         424    12.0
# 2408  0.055  40.0   145         424    12.0
# 2409  0.052   NaN    84         424    12.0
#
# [2410 rows x 5 columns]

# %%
plt.fugures(figsize=(7, 4))
sns.heatmap(dataset[['abv', 'ibu', 'id', 'brewery_id', 'ounces']].corr(). annot =  True, vmin =)

# %%
#segundo calculamos la correlacion
correlacion= nums.corr() # aqui los valores van de -1 a 1, siendo 1 relacion lineal +, -1 relacion lineal negativa, y 0 no existe relacion lineal.
correlacion
# Out:
#                  abv       ibu        id  brewery_id    ounces
# abv         1.000000  0.670621  0.042811   -0.098632  0.172529
# ibu         0.670621  1.000000  0.000485   -0.004875  0.054691
# id          0.042811  0.000485  1.000000   -0.504030  0.100843
# brewery_id -0.098632 -0.004875 -0.504030    1.000000 -0.133762
# ounces      0.172529  0.054691  0.100843   -0.133762  1.000000

# %%
#por ultimo,para visualizarlo importamos matplotlib y seaborn.
import seaborn as sns
import matplotlib.pyplot as plt
#nose como continuar con esta parte :/.

# %% [markdown]
# ## Ejercicio 13
# Representa el nivel de alcohol (columna `abv`) en un histograma. ¿Se trata de una distribución simétrica o asimétrica?

# %%
import matplotlib.pyplot as plt #libreria para hacer graficos.

# %%
dataset['abv'].hist() #aqui le indico que quiero un i¡histograma para la columna abv.
plt.title('nivel de alcohol histograma')
plt.xlabel('Valores')
plt.ylabel('Frecuencia')
plt.show

# es una distribucion asimetrica.
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Ejercicio 14
# Representa mediante un *boxplot* de `seaborn` la variable `abv`

# %%
dataset['abv'].plot(kind = 'box')
# Out:
# <Axes: >

# %% [markdown]
# ## Ejercicio 15
# 1. ¿Qué estilos son los que tienen en media más alcohol?
# 2. ¿Y los estilos que son en media más amargos?

# %%
dataset.groupby('style')['abv'].mean().sort_values(ascending=False)
#groupby('style') → agrupa las cervezas por estilo
#['abv'] → selecciona la columna de alcohol
#.mean() → calcula el alcohol medio de cada estilo
#.sort_values(ascending=False) → ordena de mayor a menor
# Out:
# style
# English Barleywine        0.107667
# Quadrupel (Quad)          0.104000
# American Barleywine       0.099000
# American Malt Liquor      0.099000
# Russian Imperial Stout    0.097636
#                             ...
# Berliner Weissbier        0.043909
# English Dark Mild Ale     0.041500
# Light Lager               0.040417
# Radler                    0.040333
# Low Alcohol Beer          0.001000
# Name: abv, Length: 99, dtype: float64

# %% [markdown]
# ## Ejercicio 16
# Carga el datasets de cervecerias `datasets_breweries.csv`

# %%
dataset2 = pd.read_csv("./data/datasets_breweries.csv") # ./ data (es la carpeta donde esta el archivo en mi rpa) seguido de el nombre del fichero
dataset2
# Out:
#      Unnamed: 0                           name           city state
# 0             0             NorthGate Brewing     Minneapolis    MN
# 1             1      Against the Grain Brewery     Louisville    KY
# 2             2       Jack's Abby Craft Lagers     Framingham    MA
# 3             3      Mike Hess Brewing Company      San Diego    CA
# 4             4        Fort Point Beer Company  San Francisco    CA
# ..          ...                            ...            ...   ...
# 553         553            Covington Brewhouse      Covington    LA
# 554         554                Dave's Brewfarm         Wilson    WI
# 555         555          Ukiah Brewing Company          Ukiah    CA
# 556         556        Butternuts Beer and Ale  Garrattsville    NY
# 557         557  Sleeping Lady Brewing Company      Anchorage    AK
#
# [558 rows x 4 columns]

# %% [markdown]
# ## Ejercicio 17
# 1. Renombra la columna `Unnamed: 0` como `brewery_id`
# 2. Renombra también la columna `name` por `brewery_name`. ¿Puedes hacer ambos apartados en una sola sentencia?

# %%
df.rename(columns={'Unnamed: 0': 'brewery_id'}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 df.rename(columns={'Unnamed: 0': 'brewery_id'}, inplace=True)
#
# NameError: name 'df' is not defined

# %%
dataset2.rename(columns={'Unnamed: 0':'brewery_id'}, inplace=True)
dataset2
#inplace = True , es para que haga cambios sobre la variable original.
#rename() → cambia el nombre de columnas o índices
#columns={...} → diccionario con nombre antiguo : nombre nuevo
#inplace=True → aplica el cambio directamente al DataFrame
# Out:
#      brewery_id                           name           city state
# 0             0             NorthGate Brewing     Minneapolis    MN
# 1             1      Against the Grain Brewery     Louisville    KY
# 2             2       Jack's Abby Craft Lagers     Framingham    MA
# 3             3      Mike Hess Brewing Company      San Diego    CA
# 4             4        Fort Point Beer Company  San Francisco    CA
# ..          ...                            ...            ...   ...
# 553         553            Covington Brewhouse      Covington    LA
# 554         554                Dave's Brewfarm         Wilson    WI
# 555         555          Ukiah Brewing Company          Ukiah    CA
# 556         556        Butternuts Beer and Ale  Garrattsville    NY
# 557         557  Sleeping Lady Brewing Company      Anchorage    AK
#
# [558 rows x 4 columns]

# %% [markdown]
# ## Ejercicio 18
# Junta los dos datasets que tienes

# %%
dataset3=pd.merge(dataset, dataset2, on='brewery_id', how= 'outer')
# los nana se guardan igual porque el "how" solo afecta a a la clumna de cruce (brewery _id)
dataset3


# beer_breweries = pd.merge(beer, breweries, on= "brewery_id", how= "outer")
# Out:
#         abv   ibu    id                     name_x                    style  \
# 0     0.045  50.0  2692               Get Together             American IPA
# 1     0.049  26.0  2691              Maggie's Leap       Milk / Sweet Stout
# 2     0.048  19.0  2690                 Wall's End        English Brown Ale
# 3     0.060  38.0  2689                    Pumpion              Pumpkin Ale
# 4     0.060  25.0  2688                 Stronghold          American Porter
# ...     ...   ...   ...                        ...                      ...
# 2405  0.049   NaN    52   Heinnieweisse Weissebier               Hefeweizen
# 2406  0.068   NaN    51            Snapperhead IPA             American IPA
# 2407  0.049   NaN    50          Moo Thunder Stout       Milk / Sweet Stout
# 2408  0.043   NaN    49          Porkslap Pale Ale  American Pale Ale (APA)
# 2409  0.049   NaN    30  Urban Wilderness Pale Ale         English Pale Ale
#
# ...

# %%
dataset3.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2410 entries, 0 to 2409
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   abv         2348 non-null   float64
#  1   ibu         1405 non-null   float64
#  2   id          2410 non-null   int64
#  3   name_x      2410 non-null   str
#  4   style       2405 non-null   str
#  5   brewery_id  2410 non-null   int64
#  6   ounces      2410 non-null   float64
#  7   name_y      2410 non-null   str
#  8   city        2410 non-null   str
#  9   state       2410 non-null   str
# dtypes: float64(3), int64(2), str(5)
# memory usage: 188.4 KB

# %% [markdown]
# ## Ejercicio 19
# 1. ¿Cuántos estados diferentes hay?
# 2. ¿Y ciudades diferentes?
# 3. ¿Cuántas cervecerías hay?

# %%
dataset3[['state', 'city', 'brewery_name', 'brewery_id']].nunique() #nunique() cuenta valores únicos en la columna.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 dataset3[['state', 'city', 'brewery_name', 'brewery_id']].nunique() #nunique() cuenta valores únicos en la columna.
#
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4382     if is_iterator(key):
#    4383         key = list(key)
# -> 4384     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4386 # take() does not accept boolean indexers
#    4387 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
dataset3['city'].nunique()
# Out:
# 384

# %%
dataset3['name'].nunique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[103], line 1
# ...

# %% [markdown]
# ## Ejercicio 20
# Agrupa por estado y ciudad, la media, mediana y máximo nivel de alcohol

# %%
dataset3.groupby(['state', 'city' ])['abv'].agg(['mean', 'median', 'max'])
# Out:
#                       mean  median    max
# state city
# AK    Anchorage   0.054200  0.0520  0.063
#       Juneau      0.053000  0.0530  0.053
#       Soldotna    0.058500  0.0580  0.068
#       Talkeetna   0.059500  0.0585  0.065
# AL    Birmingham  0.065400  0.0600  0.093
# ...                    ...     ...    ...
# WI    Wilson      0.055000  0.0550  0.055
# WV    Lewisburg   0.062000  0.0620  0.067
# WY    Jackson     0.054857  0.0520  0.068
#       Pinedale    0.061000  0.0610  0.072
#       Sheridan    0.052833  0.0480  0.070
#
# [401 rows x 3 columns]

# %%
dataset3.head()
# Out:
#      abv  ibu      id                 name                           style  \
# 0  0.050  NaN  1436.0             Pub Beer             American Pale Lager
# 1  0.066  NaN  2265.0          Devil's Cup         American Pale Ale (APA)
# 2  0.071  NaN  2264.0  Rise of the Phoenix                    American IPA
# 3  0.090  NaN  2263.0             Sinister  American Double / Imperial IPA
# 4  0.075  NaN  2262.0        Sex and Candy                    American IPA
#
#    brewery_id  ounces city state
# 0         408    12.0  NaN   NaN
# 1         177    12.0  NaN   NaN
# 2         177    12.0  NaN   NaN
# 3         177    12.0  NaN   NaN
# 4         177    12.0  NaN   NaN

# %% [markdown]
# ## Ejercicio 21
# ¿Cuáles son las cervezas más amargas que se consumen en Indiana, estado = `IN`?

# %%
dataset3['state'].unique()
# Out:
# <StringArray>
# [' MN', ' KY', ' MA', ' CA', ' SC', ' CO', ' MI', ' IN', ' TX', ' AZ', ' MO',
#  ' WI', ' IL', ' VT', ' ME', ' PA', ' KS', ' NY', ' NH', ' GA', ' VA', ' FL',
#  ' MD', ' NC', ' WY', ' OR', ' RI', ' CT', ' OH', ' AK', ' MS', ' AR', ' LA',
#  ' WV', ' UT', ' ID', ' WA', ' OK', ' NE', ' HI', ' IA', ' SD', ' NJ', ' MT',
#  ' DC', ' NV', ' TN', ' NM', ' AL', ' DE', ' ND']
# Length: 51, dtype: str

# %%
dataset3[dataset3['state'] == 'IN']['ibu'].sort_values( ascending=False)
# str.strip() funcion sobre strings que quita los espacios  que haya antes y despues
#no hay datos para indiana.
# Out:
# Series([], Name: ibu, dtype: float64)

# %% [markdown]
# ## Ejercicio 22
# Obtén una tabla con los principales estadísticos del campo `ibu`,  a nivel ciudad

# %%
dataset3.groupby('city')['ibu'].describe()
# Out:
#                 count        mean        std    min     25%    50%     75%  \
# city
# Abingdon          1.0  135.000000        NaN  135.0  135.00  135.0  135.00
# Abita Springs     3.0   27.333333  21.455380   13.0   15.00   17.0   34.50
# Ada               0.0         NaN        NaN    NaN     NaN    NaN     NaN
# Afton             4.0   43.000000  19.899749   22.0   28.00   45.0   60.00
# Airway Heights    0.0         NaN        NaN    NaN     NaN    NaN     NaN
# ...               ...         ...        ...    ...     ...    ...     ...
# Woodinville       4.0   46.750000  18.643587   27.0   39.75   44.0   51.00
# Worcester         1.0   69.000000        NaN   69.0   69.00   69.0   69.00
# Yakima            2.0   54.000000  22.627417   38.0   46.00   54.0   62.00
# Yardley           0.0         NaN        NaN    NaN     NaN    NaN     NaN
# York              4.0   44.250000  22.779742   20.0   35.00   41.0   50.25
#
#                   max
# city
# Abingdon        135.0
# ...

# %% [markdown]
# ## Ejercicio 23
# Consigue en un DataFrame de todas las cervezas en cuyas cervecerías al menos haya una cerveza con un `abv` mínimo 0.07.

# %%
eje23= dataset3[''].loc[dataset3['abv'] >= 0.07].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'dataset3'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[97], line 1
# ...

# %%
dataset3['brewery_name']

# %% [markdown]
# ## Ejercicio 24
# Teniendo en cuenta la media de amargor de todas las cervezas, obtén una tabla con las cervezas cuyos estados tengan una media de amargor en cerveza por encima de la media

# %%
media_amargor = dataset3["ibu"].mean()
media_amargor
# Out:
# np.float64(42.71316725978647)

# %%
# esto es una amscara de lista de estados con true o false esto se aplica aobre el listado de estados
dataset3.groupby('state')['ibu'].mean() > dataset3["ibu"].mean()
# decirle que ahcer despues del groupby: ['ibu].mean()
# Out:
# state
# AK    False
# AL     True
# AR    False
# AZ    False
# CA     True
# CO     True
# CT    False
# DC     True
# DE     True
# FL     True
# GA     True
# HI    False
# IA    False
# ID     True
# IL    False
# IN     True
# KS    False
# KY    False
# LA    False
# MA    False
# MD    False
# ME     True
# MI    False
# MN     True
# MO    False
# MS     True
# MT    False
# NC     True
# ND    False
# NE    False
# NH     True
# NJ     True
# NM     True
# NV     True
# NY     True
# OH     True
# OK    False
# OR     True
# PA    False
# RI    False
# SC    False
# SD    False
# TN    False
# TX    False
# UT     True
# VA     True
# VT    False
# WA     True
# WI    False
# WV     True
# WY    False
# Name: ibu, dtype: bool

# %%
dataset3['state'].unique()[ej24]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 dataset3['state'].unique()[ej24]
#
# NameError: name 'ej24' is not defined
