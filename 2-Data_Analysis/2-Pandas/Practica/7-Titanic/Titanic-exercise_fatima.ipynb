# %% [markdown]
#    #                                                  Titanic Exercise
#
#    ![titanic](https://userscontent2.emaze.com/images/a5f68f37-6349-4065-a1fc-921cbe7401b2/958230111417e36d6b3c67ffd7bc3494.jpeg)
#    #### Practise Pandas

# %% [markdown]
# First of all, import the needed libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. Read in filename and call the variable `titanic`
#     - Explore the `titanic` dataset using `info`, `dtypes` & `describe`

# %%
titanic = pd.read_csv("./data/titanic.csv")
titanic
# ./ data (es la carpeta donde esta el archivo en mi rpa) seguido de nombre del fichero csv.
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.info()
#titac: es de tipo DataFrame
#tiene 1309 filas.
# 14 columnas
#estas son las columnas que tiene valores algunos valores nulos(fare, cabin, embarked, boat, ody, home.dest)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   str
#  3   sex        1309 non-null   str
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   str
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    str
#  10  embarked   1307 non-null   str
#  11  boat       486 non-null    str
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    str
# dtypes: float64(3), int64(4), str(7)
# memory usage: 143.3 KB

# %%
#esto me dice que tipo de datos tengo en cada columna.
titanic.dtypes
# Out:
# pclass         int64
# survived       int64
# name             str
# sex              str
# age          float64
# sibsp          int64
# parch          int64
# ticket           str
# fare         float64
# cabin            str
# embarked         str
# boat             str
# body         float64
# home.dest        str
# dtype: object

# %%
#Me devuelve un resumen estadístico de las Columnas Numéricas de mi DataFrame.
titanic.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881138     0.498854     0.385027
# std       0.837836     0.486055    14.413493     1.041658     0.865560
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %% [markdown]
# 2. Create a separate dataframe with the columns `['name', 'sex', 'age']`, call it `people`
#
# It can be done two ways, do it both!

# %%
#opcion 1:
people1 = titanic.loc[:,['name', 'sex', 'age']]
people1
# Out:
#                                                  name     sex    age
# 0                       Allen, Miss. Elisabeth Walton  female  29.00
# 1                      Allison, Master. Hudson Trevor    male   0.92
# 2                        Allison, Miss. Helen Loraine  female   2.00
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.00
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# ...                                               ...     ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.50
# 1305                            Zabour, Miss. Thamine  female    NaN
# 1306                        Zakarian, Mr. Mapriededer    male  26.50
# 1307                              Zakarian, Mr. Ortin    male  27.00
# 1308                               Zimmerman, Mr. Leo    male  29.00
#
# [1309 rows x 3 columns]

# %%
# Opcion 2:
people2 = titanic[['name', 'sex', 'age']]
people2
# Out:
#                                                  name     sex    age
# 0                       Allen, Miss. Elisabeth Walton  female  29.00
# 1                      Allison, Master. Hudson Trevor    male   0.92
# 2                        Allison, Miss. Helen Loraine  female   2.00
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.00
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# ...                                               ...     ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.50
# 1305                            Zabour, Miss. Thamine  female    NaN
# 1306                        Zakarian, Mr. Mapriededer    male  26.50
# 1307                              Zakarian, Mr. Ortin    male  27.00
# 1308                               Zimmerman, Mr. Leo    male  29.00
#
# [1309 rows x 3 columns]

# %% [markdown]
# 3. Print the output of `people` showing the first three rows and the last four rows, using `append`,`tail` and `head`

# %%
# Mostrar las primeras 3 lineas.
people1.head(3)
# Out:
#                              name     sex    age
# 0   Allen, Miss. Elisabeth Walton  female  29.00
# 1  Allison, Master. Hudson Trevor    male   0.92
# 2    Allison, Miss. Helen Loraine  female   2.00

# %%
# Mostrar las ultimas 4 columnas.
people1.tail(4)
# Out:
#                            name     sex   age
# 1305      Zabour, Miss. Thamine  female   NaN
# 1306  Zakarian, Mr. Mapriededer    male  26.5
# 1307        Zakarian, Mr. Ortin    male  27.0
# 1308         Zimmerman, Mr. Leo    male  29.0

# %%
# He visto por internet que puedo combiar las dos mediante append. 
# Quedaria algo así
people1.head(3).append(people1.tail(4)) # me da error porque "Df.append"no existe en mi version de pandas.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22312\3844351168.py in ?()
#       1 # He visto por internet que puedo combiar las dos mediante append.
#       2 # Quedaria algo así
# ----> 3 people1.head(3).append(people1.tail(4)) # me da error porque "Df.append"no existe en mi version de pandas.
#
# c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
#he usado la pcion de concatenacion apra solucioanarlo.
result = pd.concat([people1.head(3), people1.tail(4)]) 
result # el resultado es otro DataFrame con las primeras 3 filas y las ultimas 4.
# Out:
#                                 name     sex    age
# 0      Allen, Miss. Elisabeth Walton  female  29.00
# 1     Allison, Master. Hudson Trevor    male   0.92
# 2       Allison, Miss. Helen Loraine  female   2.00
# 1305           Zabour, Miss. Thamine  female    NaN
# 1306       Zakarian, Mr. Mapriededer    male  26.50
# 1307             Zakarian, Mr. Ortin    male  27.00
# 1308              Zimmerman, Mr. Leo    male  29.00

# %% [markdown]
# 4. Slice the row from 3 to 9, call it `s_titanic`

# %%
s_titanic = titanic[3:10] # ponga indice 10 para que me incluya el 9.
s_titanic
# Out:
#    pclass  survived                                             name     sex  \
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia, Mr. Ramon    male
#
#     age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# 3  30.0      1      2    113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0      1      2    113781  151.5500  C22 C26        S  NaN    NaN
# 5  48.0      0      0     19952   26.5500      E12        S    3    NaN
# ...

# %%
#Otra opcion UsANDO INDICE ILOC.
s_titanic = titanic.iloc[3:10]
s_titanic
# Out:
#    pclass  survived                                             name     sex  \
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia, Mr. Ramon    male
#
#     age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# 3  30.0      1      2    113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0      1      2    113781  151.5500  C22 C26        S  NaN    NaN
# 5  48.0      0      0     19952   26.5500      E12        S    3    NaN
# ...

# %% [markdown]
# 5. Slice the row from 40 to 63 in reverse order, call it `s_titanic_rev`

# %%
s_titanic_rev = titanic.iloc[40:64].sort_index(ascending = False)
s_titanic_rev
#.sort_index(ascending=False) me invierte el orden de las filas según el índice.
# Out:
#     pclass  survived                                               name  \
# 63       1         1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 62       1         0                        Chaffee, Mr. Herbert Fuller
# 61       1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 60       1         0                      Cavendish, Mr. Tyrell William
# 59       1         1  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
# 58       1         0                             Case, Mr. Howard Brown
# 57       1         1          Carter, Mrs. William Ernest (Lucile Polk)
# 56       1         1                         Carter, Mr. William Ernest
# 55       1         1                          Carter, Miss. Lucile Polk
# 54       1         1                Carter, Master. William Thornton II
# 53       1         0                             Carrau, Mr. Jose Pedro
# 52       1         0                            Carrau, Mr. Francisco M
# ...

# %% [markdown]
# 6. Slice the columns from the starting column to `'parch'`, call it `left_columns`

# %%
left_columns = titanic.loc[:, 'pclass':'parch']
left_columns
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch
# 0     female  29.00      0      0
# ...

# %% [markdown]
# 7. Slice the columns from `'name'` to `'age'`, call it `middle_columns`

# %%
middle_columns = titanic.loc[:, 'name': 'age']
middle_columns
# Out:
#                                                  name     sex    age
# 0                       Allen, Miss. Elisabeth Walton  female  29.00
# 1                      Allison, Master. Hudson Trevor    male   0.92
# 2                        Allison, Miss. Helen Loraine  female   2.00
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.00
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# ...                                               ...     ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.50
# 1305                            Zabour, Miss. Thamine  female    NaN
# 1306                        Zakarian, Mr. Mapriededer    male  26.50
# 1307                              Zakarian, Mr. Ortin    male  27.00
# 1308                               Zimmerman, Mr. Leo    male  29.00
#
# [1309 rows x 3 columns]

# %% [markdown]
# 8. Slice the columns from `'ticket'` to the end, call it `right_columns`

# %%
right_columns = titanic.loc[:, 'ticket':]
right_columns
# Out:
#       ticket      fare    cabin embarked boat   body  \
# 0      24160  211.3375       B5        S    2    NaN
# 1     113781  151.5500  C22 C26        S   11    NaN
# 2     113781  151.5500  C22 C26        S  NaN    NaN
# 3     113781  151.5500  C22 C26        S  NaN  135.0
# 4     113781  151.5500  C22 C26        S  NaN    NaN
# ...      ...       ...      ...      ...  ...    ...
# 1304    2665   14.4542      NaN        C  NaN  328.0
# 1305    2665   14.4542      NaN        C  NaN    NaN
# 1306    2656    7.2250      NaN        C  NaN  304.0
# 1307    2670    7.2250      NaN        C  NaN    NaN
# 1308  315082    7.8750      NaN        S  NaN    NaN
#
#                             home.dest
# 0                        St Louis, MO
# 1     Montreal, PQ / Chesterville, ON
# 2     Montreal, PQ / Chesterville, ON
# 3     Montreal, PQ / Chesterville, ON
# 4     Montreal, PQ / Chesterville, ON
# ...                               ...
# 1304                              NaN
# ...

# %% [markdown]
# 9. What is the name of the oldest person who died in the Titanic? Was he or she travelling alone or had any family travelling with them?

# %% [markdown]
# In order to give an answer to the second question you should find out which columns give you that info. Usually part of your job as a Data Scientist will be get to know the dataset which you are working with. In this case the columns which give you that info are the following:
#         - 'sibsp' Number of Siblings/Spouses Aboard
#         - 'parch' Number of Parents/Children Aboard

# %%
#me filtro por los que no sobrevivieron:
died = titanic[titanic['survived']== 0]

# %%
#creo que esto es así,buscar el max de la columna age:
age_max= died['age'].max() 
print(age_max) # aqui veo que la persona mas mayor tiene 74 años.

# Mostarar el nombre:
oldest_person =died['name'][died['age'] == age_max]
oldest_person #esto me devuelve toda la info sobre la pasajero mas viejo que murió.
# Out:
# 74.0
# 1235    Svensson, Mr. Johan
# Name: name, dtype: str

# %%
# para saber si va acompañado o no hago lo siguiente:

oldest_family = died.loc[died['age'] == age_max, ['sibsp', 'parch']]
oldest_family
# oldest_family = died.loc[died['age'] == age_max, ['sibsp', 'parch']]
oldest_family
#segun los datos que he sacado, la persona mas vieja que murio en el titanic no iba acompañado.
# Out:
#       sibsp  parch
# 1235      0      0

# %% [markdown]
# 10. Create the list of 5 random numbers of rows from 0 to the lenght of the dataframe, call it `rows`
#
# ex. `rows = [3,7,99,52,48]` use `random` library

# %% [markdown]
# This list of numbers are random, could be different.

# %%
import random

# %%
rows = random.sample(range(len(titanic)), k= 5)
rows
#random.sample elige 5 números distintos aleatorios.
# Out:
# [1010, 463, 6, 415, 41]

# %% [markdown]
# 11. Create the list of three column labels, call it `cols`

# %%
cols= titanic[['pclass', 'survived', 'name']].columns.tolist() #.columns → obtiene los nombres de las columnas seleccionadas
cols
# Out:
# ['pclass', 'survived', 'name']

# %% [markdown]
# 12. Use both lists `rows` and `cols` to create a new dataframe

# %%
#no se hacer esto. no me queda muy claro como hacer :(

new_df = titanic[columns =[['pclass', 'survived', 'name']], index=rows]
new_df
# Out:
#   Cell In[12], line 3
#     new_df = titanic[columns =[['pclass', 'survived', 'name']], index=rows]
#                      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %% [markdown]
# 13. Create a boolean array with the condition of being a woman or a man, using the `sex` column, where **female** is True. Call it `array_fe`

# %%
array_fe =(titanic['sex']== 'female').to_numpy()
array_fe
# Out:
# array([ True, False,  True, ..., False, False, False], shape=(1309,))

# %% [markdown]
# 14. Rename the column `"sex"` to `"gender"` and filter the `titanic` dataframe with the boolean array, call it `woman_titanic`

# %%
titanic.rename(columns={'sex':'gender'}, inplace= True)
# titanic

# %%
woman_titanic = (titanic['gender']== 'female').to_numpy()
titanic[woman_titanic] # aqui aplico la amscara al dataframe.
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 2          1         0                     Allison, Miss. Helen Loraine
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
#
#       gender   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# 15. How many woman were younger than 18? Call the variable `minor_wo`

# %%
# women_titanic= titanic[]

# %%
minor_wo = titanic[(titanic['gender'] == 'female') & (titanic['age'] < 18)]#.shape[0] #shape[0] devuelve el numero de filas(mujeres< 18)
minor_wo
#me devuelve 72 mujeres menores de 18.
# Out:
#       pclass  survived                                       name  gender  \
# 2          1         0               Allison, Miss. Helen Loraine  female
# 55         1         1                  Carter, Miss. Lucile Polk  female
# 92         1         1  Dick, Mrs. Albert Adrian (Vera Gillespie)  female
# 159        1         1               Hippach, Miss. Jean Gertrude  female
# 187        1         1                  Lines, Miss. Mary Conover  female
# ...      ...       ...                                        ...     ...
# 1257       3         1                 Touma, Miss. Maria Youssef  female
# 1265       3         0                  Van Impe, Miss. Catharina  female
# 1279       3         0       Vestrom, Miss. Hulda Amanda Adolfina  female
# 1300       3         1    Yasbeck, Mrs. Antoni (Selini Alexander)  female
# 1304       3         0                       Zabour, Miss. Hileni  female
#
#        age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# ...

# %% [markdown]
# 16. How many woman that were less than 18 actually died? Call the variable `dead_wo`

# %%
died_wo = minor_wo[minor_wo['survived'] == 0].shape[0]
died_wo
#hay 22 mujeres menores de 18 que murieron en el titanic.
# Out:
# 22

# %% [markdown]
# 17. Drop rows with *Nan* in `titanic` with `how='any'` and print the shape

# %%
# titanic.info()

# %%
titanic.dropna(how = 'any') # en todas las filas que tengan al menos un NAN.
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, gender, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %%
titanic.dropna(how = 'any').shape
# Out:
# (0, 14)

# %% [markdown]
# 18. Drop rows with *Nan* in `titanic` with `how='all'` and print the shape

# %%
titanic.dropna(how = 'all').shape #aqui "all"me elimina las filas dodne todos los valores son NAN.
# Out:
# (1309, 14)

# %% [markdown]
# Check in [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html) why the shapes are different.

# %% [markdown]
# 19. Drop columns in `titanic` with more than 1000 missing values and print the columns remaining

# %%
titanic.dropna(axis=1, thresh=len(titanic)-1000) #thresh = Número  mínimo de valores NO "NaN" requeridos para conservar la columna.
#thresh=len(titanic)-1000 # aqui me quita las columnas que tengan mas de 1000 nulos.
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#       gender    age  sibsp  parch  ticket      fare embarked boat  \
# ...

# %% [markdown]
# 20. Calculate the ratio of missing values at the `boat` column.

# %%
print((titanic['boat'].isnull().sum() /len(titanic['boat'])))
# Out:
# 0.6287242169595111

# %% [markdown]
# 21.  Group `titanic` by `'pclass'` and aggregate by the columns `age` & `fare`, by `max` and `median` and assign it to `by_class`

# %%
by_class = titanic.groupby('pclass')[['age','fare']].agg(['max', 'median'])
by_class
# Out:
#          age             fare
#          max median       max   median
# pclass
# 1       80.0   39.0  512.3292  60.0000
# 2       70.0   29.0   73.5000  15.0458
# 3       74.0   24.0   69.5500   8.0500

# %% [markdown]
# 22. Print the maximum age in each class from `by_class`

# %%
by_class['age']['max']
# Out:
# pclass
# 1    80.0
# 2    70.0
# 3    74.0
# Name: max, dtype: float64

# %% [markdown]
# 23. Print the median fare in each class from `by_class`

# %%
by_class['fare']['median']
# Out:
# pclass
# 1    60.0000
# 2    15.0458
# 3     8.0500
# Name: median, dtype: float64

# %% [markdown]
# 24. Using [`.pivot_table()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html) to count how many women or men survived by class, call it `counted`.
#
# Don't panic and read the documentation!

# %%
# counted = titanic.pivot_table(values= "survived", index= "gender", columns= "pclass", aggfunc="count")
counted = titanic.pivot_table(values ='survived', index= 'gender', columns= 'pclass', aggfunc ='sum').T
counted
# Out:
# gender  female  male
# pclass
# 1          139    61
# 2           94    25
# 3          106    75

# %% [markdown]
# 25. Add a new column with the sum of survived men and women, call it `counted['total']`

# %%
counted ['total'] = counted.sum(axis = 1).T
counted
# Out:
# gender  female  male  total
# pclass
# 1          139    61    200
# 2           94    25    119
# 3          106    75    181

# %% [markdown]
# 26. Sort `counted` by the `'total'` column. In which class the people survived the most?

# %%
counted.sort_values(by ='total', ascending = False).head(1) #head uno es apra que me saque la primera fila.
# Out:
# gender  female  male  total
# pclass
# 1          139    61    200

# %% [markdown]
# 27. Please, show only the rows using a mask with the following conditions:
#     - They are woman
#     - From third class
#     - Younger than 30
#     - They survived
#
#     ¿How many rows fulfill the condition?

# %%
titanic_mask = titanic[(titanic['gender'] == 'male') & (titanic['pclass'] == 3) & (titanic['age'] < 30) & (titanic['survived'] == 1)]
titanic_mask
# Out:
#       pclass  survived                                             name  \
# 605        3         1                    Abelseth, Mr. Olaus Jorgensen
# 606        3         1         Abrahamsson, Mr. Abraham August Johannes
# 611        3         1                        Aks, Master. Philip Frank
# 613        3         1                      Albimona, Mr. Nassef Cassem
# 630        3         1     Andersson, Mr. August Edvard ("Wennerstrom")
# 641        3         1                Asplund, Master. Edvin Rojj Felix
# 645        3         1                       Asplund, Mr. Johan Charles
# 664        3         1                            Barah, Mr. Hanna Assi
# 693        3         1                              Buckley, Mr. Daniel
# 719        3         1                         Cohen, Mr. Gurshon "Gus"
# 733        3         1            Coutts, Master. Eden Leslie "Neville"
# 734        3         1           Coutts, Master. William Loch "William"
# ...

# %%
titanic[(titanic['gender'] == 'male') & (titanic['pclass'] == 3) & (titanic['age'] < 30) & (titanic['survived'] == 1)].shape
# Out:
# (45, 14)

# %%
len(titanic_mask)
# Out:
# 45

# %% [markdown]
# 28. Now, show only the rows using `.loc` with the following conditions:
#     - They are man
#     - From first class
#     - Older than 50
#     - They died
#
#     ¿How many rows fulfill the condition?

# %%
titanic.loc[(titanic['gender'] == 'male') & (titanic['pclass'] == 1) & (titanic['age'] > 50) & (titanic['survived'] == 0)]
# Out:
#      pclass  survived                            name gender   age  sibsp  \
# 9         1         0         Artagaveytia, Mr. Ramon   male  71.0      0
# 81        1         0    Crosby, Capt. Edward Gifford   male  70.0      1
# 115       1         0               Fortune, Mr. Mark   male  64.0      1
# 135       1         0       Goldschmidt, Mr. George B   male  71.0      0
# 154       1         0      Hays, Mr. Charles Melville   male  55.0      1
# 158       1         0     Hipkins, Mr. William Edward   male  55.0      0
# 174       1         0         Kent, Mr. Edward Austin   male  58.0      0
# 201       1         0         McCarthy, Mr. Timothy J   male  54.0      0
# 205       1         0       Millet, Mr. Francis Davis   male  65.0      0
# 210       1         0      Molson, Mr. Harry Markland   male  55.0      0
# 215       1         0      Newell, Mr. Arthur Webster   male  58.0      0
# 217       1         0    Nicholson, Mr. Arthur Ernest   male  64.0      0
# ...

# %%
titanic.loc[(titanic['gender'] == 'male') & (titanic['pclass'] == 1) & (titanic['age'] > 50) & (titanic['survived'] == 0)].shape
# Out:
# (29, 14)

# %% [markdown]
# 29. Print the uniques values at the column `'name'`

# %%
titanic['name'].unique()
# Out:
# <StringArray>
# [                  'Allen, Miss. Elisabeth Walton',
#                   'Allison, Master. Hudson Trevor',
#                     'Allison, Miss. Helen Loraine',
#             'Allison, Mr. Hudson Joshua Creighton',
#  'Allison, Mrs. Hudson J C (Bessie Waldo Daniels)',
#                              'Anderson, Mr. Harry',
#                'Andrews, Miss. Kornelia Theodosia',
#                           'Andrews, Mr. Thomas Jr',
#    'Appleton, Mrs. Edward Dale (Charlotte Lamson)',
#                          'Artagaveytia, Mr. Ramon',
#  ...
#                              'Yasbeck, Mr. Antoni',
#          'Yasbeck, Mrs. Antoni (Selini Alexander)',
#                             'Youseff, Mr. Gerious',
#                                'Yousif, Mr. Wazli',
#                            'Yousseff, Mr. Gerious',
#                             'Zabour, Miss. Hileni',
#                            'Zabour, Miss. Thamine',
#                        'Zakarian, Mr. Mapriededer',
# ...

# %%
titanic['name'].nunique()
# Out:
# 1307

# %% [markdown]
# 30. Find if was there any `name` repeated at the Titanic?
#
# Hint: There were two people with the same name, who?

# %%
titanic[titanic["name"].duplicated(keep = False)] # no se si esto es así. si lo pongo a false me sale los que cumplen la condiccion.
# Out:
#      pclass  survived                  name  gender   age  sibsp  parch  \
# 725       3         1  Connolly, Miss. Kate  female  22.0      0      0
# 726       3         0  Connolly, Miss. Kate  female  30.0      0      0
# 924       3         0      Kelly, Mr. James    male  34.5      0      0
# 925       3         0      Kelly, Mr. James    male  44.0      0      0
#
#      ticket    fare cabin embarked boat  body home.dest
# 725  370373  7.7500   NaN        Q   13   NaN   Ireland
# 726  330972  7.6292   NaN        Q  NaN   NaN   Ireland
# 924  330911  7.8292   NaN        Q  NaN  70.0       NaN
# 925  363592  8.0500   NaN        S  NaN   NaN       NaN

# %% [markdown]
# 31. Using `matplotlib` find the appropriate visualization to show the distribution of the column `'age'`

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(titanic['age'], bins=30, edgecolor ="black"); # pongo ; apra que no aparezca el codigo.

# %% [markdown]
# 32. Using `matplotlib` find the appropriate plot to visualize the column `'gender'`

# %%
titanic['gender'].unique()

# %%
plt.hist(titanic['gender'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'gender'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ...

# %% [markdown]
# 32b. What if you also plot the column `'gender'` using the function [`countplot`](https://seaborn.pydata.org/generated/seaborn.countplot.html) from the library [`seaborn`](https://seaborn.pydata.org/)?
#
# Remember you have never used `seaborn` before, therefore you should install it before importing it.

# %%
import seaborn as sns

# %%
sns.countplot(titanic, x="gender");
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 sns.countplot(titanic, x="gender");
#
# File c:\Users\tifaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:2631, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2628 elif x is not None and y is not None:
#    2629     raise TypeError("Cannot pass values for both `x` and `y`.")
# -> 2631 p = _CategoricalAggPlotter(
#    2632     data=data,
#    2633     variables=dict(x=x, y=y, hue=hue),
#    2634     order=order,
#    2635     orient=orient,
#    2636     color=color,
#    2637     legend=legend,
#    2638 )
#    2640 if ax is None:
#    2641     ax = plt.gca()
#
# ...

# %% [markdown]
# 33. Using the function [`catplot`](https://seaborn.pydata.org/generated/seaborn.catplot.html) from the library `seaborn`, find out if the hypothesis _"Women are more likely to survive shipwrecks"_ is true or not.
#
# You should get something like this:

# %% [markdown]
# ![catplot](./img/catplotgen.png)

# %%
# titanic[titanic['sex'] == "male"]['survived'].std()

# %%
# titanic[titanic['sex'] == "female"]['survived'].std()

# %%
sns.catplot(titanic, x="gender", y="survived", kind="bar")

# %% [markdown]
# 34. Using [`kdeplot`]("https://seaborn.pydata.org/generated/seaborn.kdeplot.html") from `seaborn` represent those who not survived distributed by age.<>
#
# Hint: First you should "filter" the `titanic` dataset where the column "survived" is 0, indexing the column `"age"` only.
#
# Arguments you should pass to the function:
#
#     - color = "red"
#     - label = "Not Survived"
#     - shade = True
#
# You should get something like this:

# %% [markdown]
# ![kdeplot](./img/kdeplotsur.png)

# %%
titanic[titanic['survived']==0]
# Out:
#       pclass  survived                                             name  \
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 7          1         0                           Andrews, Mr. Thomas Jr
# 9          1         0                          Artagaveytia, Mr. Ramon
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex   age  sibsp  parch    ticket      fare    cabin embarked boat  \
# ...

# %%
sns.kdeplot(titanic[titanic['survived']==0], x="age", color="red", fill=True)
plt.legend(["Not survived"]);
